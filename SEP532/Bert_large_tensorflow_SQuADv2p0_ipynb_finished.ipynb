# %% [markdown]
# <a href="https://colab.research.google.com/github/BrotherKim/Colab/blob/main/SEP532/Bert_large_tensorflow_SQuADv2p0_ipynb_finished.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**BERT Large, Tensorflow, SQUAD 2.0, Cloud TPU**
#
# ---

# %%
import os 
os.environ['BASE_MODEL'] = "uncased_L-24_H-1024_A-16"
os.environ['SQUAD_VERSION'] = "v2.0"

# %% [markdown]
# ### **Change runstime environment to TPU**
#
# > **Runtime** - **Change runtime type** - **TPU**.

# %% [markdown]
# ### **Clone the BERT github repository**
#
#
# > Change Tensorflow version 1.14, and Clone BERT from github repository.

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==1.14
# Out:
# Uninstalling tensorflow-1.14.0:
#   Would remove:
#     /usr/local/bin/freeze_graph
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-1.14.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-1.14.0
# Collecting tensorflow==1.14
#   Using cached https://files.pythonhosted.org/packages/f4/28/96efba1a516cdacc2e2d6d081f699c001d414cc8ca3250e6d59ae657eb2b/tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.12.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.2)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.14.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (3.12.4)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.3.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.32.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.19.5)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.36.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.14.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.0.8)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (2.0.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (56.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (4.0.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.4.1)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-1.14.0

# %%
# !git clone https://github.com/google-research/bert.git
# Out:
# fatal: destination path 'bert' already exists and is not an empty directory.

# %%
ls -l
# Out:
# total 12
# -rw-r--r-- 1 root root  720 May 16 09:06 adc.json
# drwxr-xr-x 5 root root 4096 May 16 09:41 bert/
# drwxr-xr-x 1 root root 4096 May  6 13:44 sample_data/

# %%
cd bert
# Out:
# /content/bert

# %% [markdown]
# ### **BERT repository files**
#
#
# > use ls -l to check the content inside BERT folder, you can see all files related to BERT.

# %%
ls -l
# Out:
# total 2528932
# -rw-r--r-- 1 root root       1323 May 16 09:04 CONTRIBUTING.md
# -rw-r--r-- 1 root root      16475 May 16 09:04 create_pretraining_data.py
# -rw-r--r-- 1 root root    4370528 May 16 09:41 dev-v2.0.json
# -rw-r--r-- 1 root root    4370528 Apr 27 06:03 dev-v2.0.json.1
# -rw-r--r-- 1 root root      10546 May 16 09:41 evaluate-v2.0.py
# -rw-r--r-- 1 root root      13898 May 16 09:04 extract_features.py
# -rw-r--r-- 1 root root        616 May 16 09:04 __init__.py
# -rw-r--r-- 1 root root      11358 May 16 09:04 LICENSE
# -rw-r--r-- 1 root root      37922 May 16 09:04 modeling.py
# -rw-r--r-- 1 root root       9191 May 16 09:04 modeling_test.py
# -rw-r--r-- 1 root root      11242 May 16 09:04 multilingual.md
# -rw-r--r-- 1 root root       6258 May 16 09:04 optimization.py
# -rw-r--r-- 1 root root       1721 May 16 09:04 optimization_test.py
# -rw-r--r-- 1 root root      66488 May 16 09:04 predicting_movie_reviews_with_bert_on_tf_hub.ipynb
# -rw-r--r-- 1 root root     586231 May 16 09:36 predictions.json
# drwxr-xr-x 2 root root       4096 May 16 09:08 __pycache__/
# -rw-r--r-- 1 root root      50519 May 16 09:04 README.md
# -rw-r--r-- 1 root root        110 May 16 09:04 requirements.txt
# -rw-r--r-- 1 root root      34783 May 16 09:04 run_classifier.py
# -rw-r--r-- 1 root root      11426 May 16 09:04 run_classifier_with_tfhub.py
# -rw-r--r-- 1 root root      18667 May 16 09:04 run_pretraining.py
# -rw-r--r-- 1 root root      46532 May 16 09:04 run_squad.py
# -rw-r--r-- 1 root root       4394 May 16 09:04 sample_text.txt
# -rw-r--r-- 1 root root      12257 May 16 09:04 tokenization.py
# -rw-r--r-- 1 root root       4589 May 16 09:04 tokenization_test.py
# -rw-r--r-- 1 root root   42123633 May 16 09:41 train-v2.0.json
# -rw-r--r-- 1 root root   42123633 Apr 27 06:03 train-v2.0.json.1
# drwxr-xr-x 2 root root       4096 May 16 09:36 uncased_L-24_H-1024_A-16/
# -rw-r--r-- 1 root root 1247797031 Nov  1  2018 uncased_L-24_H-1024_A-16.zip
# -rw-r--r-- 1 root root 1247797031 Nov  1  2018 uncased_L-24_H-1024_A-16.zip.1

# %% [markdown]
# ### **Download the BERT PRETRAINED MODEL**
#
#
# BERT Pretrained Model List :
#
#
# *   [BERT-Large, Uncased (Whole Word Masking)](https://storage.googleapis.com/bert_models/2019_05_30/wwm_uncased_L-24_H-1024_A-16.zip) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   [BERT-Large, Cased (Whole Word Masking)](https://storage.googleapis.com/bert_models/2019_05_30/wwm_cased_L-24_H-1024_A-16.zip) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   [BERT-Base, Uncased](https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip) : 12-layer, 768-hidden, 12-heads, 110M parameters
# *   [BERT-Large, Uncased](https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-24_H-1024_A-16.zip) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   [BERT-Base, Cased](https://storage.googleapis.com/bert_models/2018_10_18/cased_L-12_H-768_A-12.zip): 12-layer, 768-hidden, 12-heads , 110M parameters
# *   [BERT-Large, Cased](https://storage.googleapis.com/bert_models/2018_10_18/cased_L-24_H-1024_A-16.zip) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   [BERT-Base, Multilingual Cased (New, recommended)](https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.zip) : 104 languages, 12-layer, 768-hidden, 12-heads, 110M parameters
# *   [BERT-Base, Multilingual Uncased (Orig, not recommended) (Not recommended, use Multilingual Cased instead)](https://storage.googleapis.com/bert_models/2018_11_03/multilingual_L-12_H-768_A-12.zip) : 102 languages, 12-layer, 768-hidden, 12-heads, 110M parameters
# *   [BERT-Base, Chinese](https://storage.googleapis.com/bert_models/2018_11_03/chinese_L-12_H-768_A-12.zip) : Chinese Simplified and Traditional, 12-layer, 768-hidden, 12-heads, 110M parameters
#
# BERT has release **BERT-Base** and **BERT-Large** models. Uncased means that the text has been lowercased before WordPiece tokenization, e.g., John Smith becomes john smith, whereas Cased means that the true case and accent markers are preserved.
#
# **When using a cased model, make sure to pass --do_lower=False at the time of training.**
#
# You can download any model of your choice. We have used **BERT-Large-Uncased Model.**

# %%
# !wget https://storage.googleapis.com/bert_models/2018_10_18/$BASE_MODEL.zip
#!wget https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# Out:
# --2021-05-16 09:41:56--  https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-24_H-1024_A-16.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.152.128, 172.253.119.128, 108.177.111.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.152.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1247797031 (1.2G) [application/zip]
# Saving to: ‘uncased_L-24_H-1024_A-16.zip.2’
#
# uncased_L-24_H-1024 100%[===================>]   1.16G   159MB/s    in 9.3s
#
# 2021-05-16 09:42:05 (128 MB/s) - ‘uncased_L-24_H-1024_A-16.zip.2’ saved [1247797031/1247797031]

# %%
# Unzip the pretrained model
# !unzip $BASE_MODEL.zip
# Out:
# Archive:  uncased_L-24_H-1024_A-16.zip
#   inflating: uncased_L-24_H-1024_A-16/bert_model.ckpt.meta
#   inflating: uncased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001
#   inflating: uncased_L-24_H-1024_A-16/vocab.txt
#   inflating: uncased_L-24_H-1024_A-16/bert_model.ckpt.index
#   inflating: uncased_L-24_H-1024_A-16/bert_config.json

# %% [markdown]
# ### **Set up your TPU environment**
# *   Verify that you are connected to a TPU device
# *   You will get know your TPU Address that is used at time of fine-tuning
# *   Perform Google Authentication to access your bucket
# *   Upload your credentials to TPU to access your GCS bucket

# %%
import datetime
import json
import os
import pprint
import random
import string
import sys
import tensorflow as tf

assert 'COLAB_TPU_ADDR' in os.environ, 'ERROR: Not connected to a TPU runtime; please see the first cell in this notebook for instructions!'
TPU_ADDRESS = 'grpc://' + os.environ['COLAB_TPU_ADDR']
#print('TPU address is => ', TPU_ADDRESS)

from google.colab import auth
auth.authenticate_user()
with tf.Session(TPU_ADDRESS) as session:
  print('TPU devices:')
  pprint.pprint(session.list_devices())

  # Upload credentials to TPU.
  with open('/content/adc.json', 'r') as f:
    auth_info = json.load(f)
  tf.contrib.cloud.configure_gcs(session, credentials=auth_info)
  # Now credentials are set for all future sessions on this TPU.

os.environ['TPU_ADDRESS'] = TPU_ADDRESS
print('TPU address is => ', os.environ['TPU_ADDRESS'])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 7083097472625579399),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 8089406073955703999),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 2167548018548191701),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 18290112712340330980),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 4995293251164992983),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 8439450137861903232),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 8541139261453635616),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 997763994145710658),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 4012767469566432147),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 17575888693165224612),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 8574506519853984390)]
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# TPU address is =>  grpc://10.45.3.186:8470

# %% [markdown]
# ### **Download the SQUAD Dataset**

# %%
#Download the SQUAD train and dev dataset
# !gsutil cp gs://bk_bert_squad_v2p0/squad_eval/evaluate-${SQUAD_VERSION}.py .
# !gsutil cp gs://bk_bert_squad_v2p0/squad_eval/train-${SQUAD_VERSION}.json .
# !gsutil cp gs://bk_bert_squad_v2p0/squad_eval/dev-${SQUAD_VERSION}.json .
# Out:
# Copying gs://bk_bert_squad_v2p0/squad_eval/evaluate-v2.0.py...
# / [1 files][ 10.3 KiB/ 10.3 KiB]
# Operation completed over 1 objects/10.3 KiB.
# Copying gs://bk_bert_squad_v2p0/squad_eval/train-v2.0.json...
# - [1 files][ 40.2 MiB/ 40.2 MiB]
# Operation completed over 1 objects/40.2 MiB.
# Copying gs://bk_bert_squad_v2p0/squad_eval/dev-v2.0.json...
# / [1 files][  4.2 MiB/  4.2 MiB]
# Operation completed over 1 objects/4.2 MiB.

# %% [markdown]
# ### **Create output directory**
#
#
# > Need to create a output directory at GCS (Google Cloud Storage) bucket, where you will get your fine_tuned model after training completion. For that you need to provide your BUCKET name and OUPUT DIRECTORY name.
#
# > Also need to move Pre-trained Model at GCS (Google Cloud Storage) bucket, as Local File System is not Supported on TPU. If you don't move your pretrained model to TPU you may face an error.

# %%
BUCKET = 'bk_bert_squad_v2p0' #@param {type:"string"}
assert BUCKET, '*** Must specify an existing GCS bucket name ***'
output_dir_name = os.environ['BASE_MODEL'] + '_out' #@param {type:"string"}

os.environ['BUCKET_NAME'] = 'gs://{}'.format(BUCKET)
os.environ['OUTPUT_DIR'] = 'gs://{}/{}'.format(BUCKET,output_dir_name)
tf.gfile.MakeDirs(os.environ['OUTPUT_DIR'])
print('***** Model output directory: {} *****'.format(os.environ['OUTPUT_DIR']))
# Out:
# ***** Model output directory: gs://bk_bert_squad_v2p0/uncased_L-24_H-1024_A-16_out *****

# %% [markdown]
# ### **Move Pretrained Model to GCS Bucket**
#
#
# > Need to move Pre-trained Model at GCS (Google Cloud Storage) bucket, as Local File System is not Supported on TPU. If you don't move your pretrained model to TPU you may face the error.
#
#
#
# > The **gsutil** **mv** command allows you to move data between your local file system and the cloud, move data within the cloud, and move data between cloud storage providers.

# %%
# !gsutil mv /content/bert/$BASE_MODEL $BUCKET_NAME
# Out:
# Copying file:///content/bert/uncased_L-24_H-1024_A-16/bert_config.json [Content-Type=application/json]...
# Removing file:///content/bert/uncased_L-24_H-1024_A-16/bert_config.json...
# Copying file:///content/bert/uncased_L-24_H-1024_A-16/bert_model.ckpt.meta [Content-Type=application/octet-stream]...
# Removing file:///content/bert/uncased_L-24_H-1024_A-16/bert_model.ckpt.meta...
# Copying file:///content/bert/uncased_L-24_H-1024_A-16/bert_model.ckpt.index [Content-Type=application/octet-stream]...
# Removing file:///content/bert/uncased_L-24_H-1024_A-16/bert_model.ckpt.index...
# Copying file:///content/bert/uncased_L-24_H-1024_A-16/vocab.txt [Content-Type=text/plain]...
# Removing file:///content/bert/uncased_L-24_H-1024_A-16/vocab.txt...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file:///content/bert/uncased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001 [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Removing file:///content/bert/uncased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001...
#
# Operation completed over 5 objects/1.2 GiB.

# %% [markdown]
# ### **Training**
#
# > Set options for TPU.
#
# 1.   --use_tpu=True
# 2.   --tpu_name="find with 'TPU address is =>"

# %%
# !python run_squad.py \
  --vocab_file=$BUCKET_NAME/$BASE_MODEL/vocab.txt \
  --bert_config_file=$BUCKET_NAME/$BASE_MODEL/bert_config.json \
  --init_checkpoint=$BUCKET_NAME/$BASE_MODEL/bert_model.ckpt \
  --do_train=True \
  --train_file=train-$SQUAD_VERSION.json \
  --do_predict=True \
  --predict_file=dev-$SQUAD_VERSION.json \
  --train_batch_size=24 \
  --learning_rate=3e-5 \
  --num_train_epochs=2.0 \
  --use_tpu=True \
  --tpu_name=$TPU_ADDRESS \
  --max_seq_length=384 \
  --doc_stride=128 \
  --version_2_with_negative=True \
  --output_dir=$OUTPUT_DIR
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.662924 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.678444 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.678755 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.694183 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.694481 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.711385 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.711716 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.728543 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.728863 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.745663 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.745998 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.763317 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.763618 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.780567 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.780868 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.798319 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.798599 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.815401 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.815698 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.832446 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.832745 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.849626 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.849910 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.866677 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.866946 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.884035 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.884370 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.901482 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.901780 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.918819 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.919120 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.935360 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.935640 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.953026 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.953329 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.973967 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.974409 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:16.989867 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:16.990143 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.005325 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.005625 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.022608 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.022885 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.039972 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.040289 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.057471 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.058144 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.074585 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.074882 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.092025 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.092336 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.109178 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.109448 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.126430 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.126716 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.143239 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.143506 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.161362 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.161632 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.179758 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.180160 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.197427 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.197764 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.212692 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.212970 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.229794 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.230067 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.247375 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.247654 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.264525 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.264800 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.281654 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.281910 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.298979 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.299309 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.318739 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.319171 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.333513 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.333801 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.350646 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.350915 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.368115 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.368404 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.388521 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.388851 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.402261 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.402520 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.419771 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.420130 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.437168 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.437493 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.454034 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.454380 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.472823 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.473168 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.490920 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.491257 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.506762 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.507119 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.523748 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.524131 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.540937 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.541306 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.558097 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.558461 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.575091 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.575440 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.592598 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.592930 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.609317 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.609629 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.627161 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.627519 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.644351 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.644671 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.662600 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.662906 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.679802 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.680156 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.695954 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.696360 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.713308 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.713602 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.730439 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.730748 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.748047 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.748589 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.772597 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.773059 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.783581 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.783898 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.802567 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.802856 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.817011 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.817308 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.834235 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.834555 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.851573 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.851849 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.868638 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.868919 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.886365 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.886689 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.903827 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.904110 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.920672 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.920943 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.938105 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.938407 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.955464 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.955747 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.972702 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.972974 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:17.989540 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:17.989852 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.007516 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.007862 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.024657 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.024987 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.041557 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.041870 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.058464 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.058779 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.079525 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.079881 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.095129 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.095515 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Processing example: 3000
# I0516 10:31:18.107406 140235456931712 run_squad.py:1259] Processing example: 3000
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.111433 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.111704 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.128114 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.128393 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.145687 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.145972 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.163314 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.163657 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.180071 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.180341 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.197787 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.198057 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.214818 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.215080 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.232159 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.232432 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.249495 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.249791 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.266258 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.266558 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.289026 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.289358 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.302942 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.303216 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.318237 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.318518 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.335688 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.335968 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.352957 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.353217 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.371637 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.372064 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.387399 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.387676 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.406208 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.406583 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.422460 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.422763 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.439419 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.439692 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.456400 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.456647 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.473877 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.474200 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.491196 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.491473 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.508457 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.508719 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.526124 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.526411 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.542827 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.543092 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.560373 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.560647 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.580573 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.581001 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.596482 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.596776 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.612442 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.612782 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.630362 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.630670 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.646749 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.647058 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.663841 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.664301 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.680809 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.681338 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.698463 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.698789 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.715863 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.716234 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.733138 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.733494 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.751288 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.751579 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.792366 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.792702 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.799550 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.800236 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.807443 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.807770 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.819199 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.819513 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.836060 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.836326 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.853669 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.853940 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.870995 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.871548 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.889752 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.890055 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.905445 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.905712 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.922799 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.923082 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.939898 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.940264 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.957372 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.957659 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.974580 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.974840 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:18.991754 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:18.992040 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:19.009464 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:19.009777 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:19.027409 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:19.027740 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:19.044314 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:19.044618 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:19.061561 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:19.061918 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# ...
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.378613 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.378953 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.393928 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.394341 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.409202 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.409562 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.427297 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.427575 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.443843 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.444208 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.461547 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.461874 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.479233 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.479534 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.495728 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.496031 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.512713 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.513015 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.529926 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.530279 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Processing example: 12000
# I0516 10:31:37.543761 140235456931712 run_squad.py:1259] Processing example: 12000
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.547483 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.547768 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.564425 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.564772 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.583444 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.583843 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.599598 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.599917 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.617082 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.617497 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.634424 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.634745 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.652768 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.653128 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.667850 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.668204 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.685515 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.685831 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.702834 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.703151 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.720185 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.720521 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.737318 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.737633 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.754790 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.755135 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.772262 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.772573 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.789104 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.789496 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.815809 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.816209 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.823670 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.824020 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.841155 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.841452 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.858130 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.858482 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.876891 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.877274 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.892895 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.893236 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.910346 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.910654 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.928309 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.928650 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.944941 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.945297 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.962060 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.962420 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.979053 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.979374 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:37.996971 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:37.997314 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:38.013948 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:38.014299 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 10:31:38.031212 140235456931712 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 10:31:38.031715 140235456931712 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Stop infeed thread controller
# I0516 10:31:38.045064 140235456931712 tpu_estimator.py:598] Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# I0516 10:31:38.045373 140235456931712 tpu_estimator.py:430] Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# I0516 10:31:38.045580 140234225886976 tpu_estimator.py:425] InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# I0516 10:31:38.045692 140234225886976 tpu_estimator.py:530] Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# I0516 10:31:38.045866 140235456931712 error_handling.py:96] infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# I0516 10:31:38.046090 140235456931712 tpu_estimator.py:602] Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# I0516 10:31:38.046186 140235456931712 tpu_estimator.py:430] Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# I0516 10:31:38.046390 140234022455040 tpu_estimator.py:425] OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# I0516 10:31:38.046481 140234022455040 tpu_estimator.py:541] Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# I0516 10:31:38.046605 140235456931712 error_handling.py:96] outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# I0516 10:31:38.046718 140235456931712 tpu_estimator.py:606] Shutdown TPU system.
# INFO:tensorflow:prediction_loop marked as finished
# I0516 10:31:38.369748 140235456931712 error_handling.py:96] prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# I0516 10:31:38.370067 140235456931712 error_handling.py:96] prediction_loop marked as finished
# INFO:tensorflow:Writing predictions to: gs://bk_bert_squad_v2p0/uncased_L-24_H-1024_A-16_out/predictions.json
# I0516 10:31:38.370297 140235456931712 run_squad.py:745] Writing predictions to: gs://bk_bert_squad_v2p0/uncased_L-24_H-1024_A-16_out/predictions.json
# INFO:tensorflow:Writing nbest to: gs://bk_bert_squad_v2p0/uncased_L-24_H-1024_A-16_out/nbest_predictions.json
# I0516 10:31:38.370412 140235456931712 run_squad.py:746] Writing nbest to: gs://bk_bert_squad_v2p0/uncased_L-24_H-1024_A-16_out/nbest_predictions.json

# %% [markdown]
# ### **Evaluate**

# %%
# !gsutil cp $OUTPUT_DIR/predictions.json .
# !python evaluate-${SQUAD_VERSION}.py dev-${SQUAD_VERSION}.json predictions.json
# Out:
# Copying gs://bk_bert_squad_v2p0/uncased_L-24_H-1024_A-16_out/predictions.json...
# - [1 files][552.3 KiB/552.3 KiB]
# Operation completed over 1 objects/552.3 KiB.
# {
#   "exact": 74.95157079087004,
#   "f1": 77.95065217434244,
#   "total": 11873,
#   "HasAns_exact": 75.0506072874494,
#   "HasAns_f1": 81.05737065890139,
#   "HasAns_total": 5928,
#   "NoAns_exact": 74.85281749369217,
#   "NoAns_f1": 74.85281749369217,
#   "NoAns_total": 5945
# }
