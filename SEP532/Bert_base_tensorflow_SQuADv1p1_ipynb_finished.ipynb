# %% [markdown]
# <a href="https://colab.research.google.com/github/BrotherKim/Colab/blob/main/SEP532/Bert_base_tensorflow_SQuADv1p1_ipynb_finished.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**BERT Base, Tensorflow, SQUAD 1.1, Cloud TPU**
#
# ---

# %%
import os 
os.environ['BASE_MODEL'] = "uncased_L-12_H-768_A-12"
os.environ['SQUAD_VERSION'] = "v1.1"

# %% [markdown]
# ### **Change runstime environment to TPU**
#
# > **Runtime** - **Change runtime type** - **TPU**.

# %% [markdown]
# ### **Clone the BERT github repository**
#
#
# > Change Tensorflow version 1.14, and Clone BERT from github repository.

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==1.14
# Out:
# Uninstalling tensorflow-2.4.1:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.4.1.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.4.1
# Collecting tensorflow==1.14
#   Downloading https://files.pythonhosted.org/packages/f4/28/96efba1a516cdacc2e2d6d081f699c001d414cc8ca3250e6d59ae657eb2b/tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3MB)
#      |████████████████████████████████| 109.3MB 94kB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.32.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (3.12.4)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 35.8MB/s
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.19.5)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.15.0)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 6.0MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.12.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.8.1)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 32.0MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.36.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.12.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.3.3)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.6.1->tensorflow==1.14) (56.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (2.0.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (4.0.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.4.1)
# Installing collected packages: tensorflow-estimator, keras-applications, tensorboard, tensorflow
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0

# %%
# !git clone https://github.com/google-research/bert.git
# Out:
# Cloning into 'bert'...
# remote: Enumerating objects: 340, done.
# remote: Total 340 (delta 0), reused 0 (delta 0), pack-reused 340
# Receiving objects: 100% (340/340), 328.28 KiB | 3.91 MiB/s, done.
# Resolving deltas: 100% (182/182), done.

# %%
ls -l
# Out:
# total 8
# drwxr-xr-x 3 root root 4096 May 16 08:42 bert/
# drwxr-xr-x 1 root root 4096 May  6 13:44 sample_data/

# %%
cd bert
# Out:
# /content/bert

# %% [markdown]
# ### **BERT repository files**
#
#
# > use ls -l to check the content inside BERT folder, you can see all files related to BERT.

# %%
ls -l
# Out:
# total 400
# -rw-r--r-- 1 root root  1323 May 16 08:42 CONTRIBUTING.md
# -rw-r--r-- 1 root root 16475 May 16 08:42 create_pretraining_data.py
# -rw-r--r-- 1 root root 13898 May 16 08:42 extract_features.py
# -rw-r--r-- 1 root root   616 May 16 08:42 __init__.py
# -rw-r--r-- 1 root root 11358 May 16 08:42 LICENSE
# -rw-r--r-- 1 root root 37922 May 16 08:42 modeling.py
# -rw-r--r-- 1 root root  9191 May 16 08:42 modeling_test.py
# -rw-r--r-- 1 root root 11242 May 16 08:42 multilingual.md
# -rw-r--r-- 1 root root  6258 May 16 08:42 optimization.py
# -rw-r--r-- 1 root root  1721 May 16 08:42 optimization_test.py
# -rw-r--r-- 1 root root 66488 May 16 08:42 predicting_movie_reviews_with_bert_on_tf_hub.ipynb
# -rw-r--r-- 1 root root 50519 May 16 08:42 README.md
# -rw-r--r-- 1 root root   110 May 16 08:42 requirements.txt
# -rw-r--r-- 1 root root 34783 May 16 08:42 run_classifier.py
# -rw-r--r-- 1 root root 11426 May 16 08:42 run_classifier_with_tfhub.py
# -rw-r--r-- 1 root root 18667 May 16 08:42 run_pretraining.py
# -rw-r--r-- 1 root root 46532 May 16 08:42 run_squad.py
# -rw-r--r-- 1 root root  4394 May 16 08:42 sample_text.txt
# -rw-r--r-- 1 root root 12257 May 16 08:42 tokenization.py
# -rw-r--r-- 1 root root  4589 May 16 08:42 tokenization_test.py

# %% [markdown]
# ### **Download the BERT PRETRAINED MODEL**
#
#
# BERT Pretrained Model List :
#
#
# *   [BERT-Large, Uncased (Whole Word Masking)](https://storage.googleapis.com/bert_models/2019_05_30/wwm_uncased_L-24_H-1024_A-16.zip) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   [BERT-Large, Cased (Whole Word Masking)](https://storage.googleapis.com/bert_models/2019_05_30/wwm_cased_L-24_H-1024_A-16.zip) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   [BERT-Base, Uncased](https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip) : 12-layer, 768-hidden, 12-heads, 110M parameters
# *   [BERT-Large, Uncased](https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-24_H-1024_A-16.zip) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   [BERT-Base, Cased](https://storage.googleapis.com/bert_models/2018_10_18/cased_L-12_H-768_A-12.zip): 12-layer, 768-hidden, 12-heads , 110M parameters
# *   [BERT-Large, Cased](https://storage.googleapis.com/bert_models/2018_10_18/cased_L-24_H-1024_A-16.zip) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   [BERT-Base, Multilingual Cased (New, recommended)](https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.zip) : 104 languages, 12-layer, 768-hidden, 12-heads, 110M parameters
# *   [BERT-Base, Multilingual Uncased (Orig, not recommended) (Not recommended, use Multilingual Cased instead)](https://storage.googleapis.com/bert_models/2018_11_03/multilingual_L-12_H-768_A-12.zip) : 102 languages, 12-layer, 768-hidden, 12-heads, 110M parameters
# *   [BERT-Base, Chinese](https://storage.googleapis.com/bert_models/2018_11_03/chinese_L-12_H-768_A-12.zip) : Chinese Simplified and Traditional, 12-layer, 768-hidden, 12-heads, 110M parameters
#
# BERT has release **BERT-Base** and **BERT-Large** models. Uncased means that the text has been lowercased before WordPiece tokenization, e.g., John Smith becomes john smith, whereas Cased means that the true case and accent markers are preserved.
#
# **When using a cased model, make sure to pass --do_lower=False at the time of training.**
#
# You can download any model of your choice. We have used **BERT-Large-Uncased Model.**

# %%
# !wget https://storage.googleapis.com/bert_models/2018_10_18/$BASE_MODEL.zip
#!wget https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# Out:
# --2021-05-16 08:42:33--  https://storage.googleapis.com/bert_models/2018_10_18/uncased_L-12_H-768_A-12.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.128.128, 142.251.6.128, 74.125.126.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.128.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 407727028 (389M) [application/zip]
# Saving to: ‘uncased_L-12_H-768_A-12.zip’
#
# uncased_L-12_H-768_ 100%[===================>] 388.84M   146MB/s    in 2.7s
#
# 2021-05-16 08:42:35 (146 MB/s) - ‘uncased_L-12_H-768_A-12.zip’ saved [407727028/407727028]

# %%
# Unzip the pretrained model
# !unzip $BASE_MODEL.zip
# Out:
# Archive:  uncased_L-12_H-768_A-12.zip
#    creating: uncased_L-12_H-768_A-12/
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.meta
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
#   inflating: uncased_L-12_H-768_A-12/vocab.txt
#   inflating: uncased_L-12_H-768_A-12/bert_model.ckpt.index
#   inflating: uncased_L-12_H-768_A-12/bert_config.json

# %% [markdown]
# ### **Set up your TPU environment**
# *   Verify that you are connected to a TPU device
# *   You will get know your TPU Address that is used at time of fine-tuning
# *   Perform Google Authentication to access your bucket
# *   Upload your credentials to TPU to access your GCS bucket

# %%
import datetime
import json
import os
import pprint
import random
import string
import sys
import tensorflow as tf

assert 'COLAB_TPU_ADDR' in os.environ, 'ERROR: Not connected to a TPU runtime; please see the first cell in this notebook for instructions!'
TPU_ADDRESS = 'grpc://' + os.environ['COLAB_TPU_ADDR']
#print('TPU address is => ', TPU_ADDRESS)

from google.colab import auth
auth.authenticate_user()
with tf.Session(TPU_ADDRESS) as session:
  print('TPU devices:')
  pprint.pprint(session.list_devices())

  # Upload credentials to TPU.
  with open('/content/adc.json', 'r') as f:
    auth_info = json.load(f)
  tf.contrib.cloud.configure_gcs(session, credentials=auth_info)
  # Now credentials are set for all future sessions on this TPU.

os.environ['TPU_ADDRESS'] = TPU_ADDRESS
print('TPU address is => ', os.environ['TPU_ADDRESS'])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 14067755413010483840),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 13621619173832812184),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 2005206241407326813),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 16590728500804300776),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 14332194970066527071),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 6272201726110570482),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 11743335270788189838),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 1329088498728526902),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 2720691194653589843),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 9170890969059732849),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 10146416697597296391)]
# TPU address is =>  grpc://10.63.245.98:8470

# %% [markdown]
# ### **Download the SQUAD Dataset**

# %%
#Download the SQUAD train and dev dataset
# !gsutil cp gs://bk_bert_squad_v2p0/squad_eval/evaluate-${SQUAD_VERSION}.py .
# !gsutil cp gs://bk_bert_squad_v2p0/squad_eval/train-${SQUAD_VERSION}.json .
# !gsutil cp gs://bk_bert_squad_v2p0/squad_eval/dev-${SQUAD_VERSION}.json .
# Out:
# Copying gs://bk_bert_squad_v2p0/squad_eval/evaluate-v1.1.py...
# - [1 files][  3.3 KiB/  3.3 KiB]
# Operation completed over 1 objects/3.3 KiB.
# Copying gs://bk_bert_squad_v2p0/squad_eval/train-v1.1.json...
# \ [1 files][ 28.9 MiB/ 28.9 MiB]
# Operation completed over 1 objects/28.9 MiB.
# Copying gs://bk_bert_squad_v2p0/squad_eval/dev-v1.1.json...
# - [1 files][  4.6 MiB/  4.6 MiB]
# Operation completed over 1 objects/4.6 MiB.

# %% [markdown]
# ### **Create output directory**
#
#
# > Need to create a output directory at GCS (Google Cloud Storage) bucket, where you will get your fine_tuned model after training completion. For that you need to provide your BUCKET name and OUPUT DIRECTORY name.
#
# > Also need to move Pre-trained Model at GCS (Google Cloud Storage) bucket, as Local File System is not Supported on TPU. If you don't move your pretrained model to TPU you may face an error.

# %%
BUCKET = 'bk_bert_squad_v2p0' #@param {type:"string"}
assert BUCKET, '*** Must specify an existing GCS bucket name ***'
output_dir_name = os.environ['BASE_MODEL'] + '_out' #@param {type:"string"}

os.environ['BUCKET_NAME'] = 'gs://{}'.format(BUCKET)
os.environ['OUTPUT_DIR'] = 'gs://{}/{}'.format(BUCKET,output_dir_name)
tf.gfile.MakeDirs(os.environ['OUTPUT_DIR'])
print('***** Model output directory: {} *****'.format(os.environ['OUTPUT_DIR']))
# Out:
# ***** Model output directory: gs://bk_bert_squad_v2p0/uncased_L-12_H-768_A-12_out *****

# %% [markdown]
# ### **Move Pretrained Model to GCS Bucket**
#
#
# > Need to move Pre-trained Model at GCS (Google Cloud Storage) bucket, as Local File System is not Supported on TPU. If you don't move your pretrained model to TPU you may face the error.
#
#
#
# > The **gsutil** **mv** command allows you to move data between your local file system and the cloud, move data within the cloud, and move data between cloud storage providers.

# %%
# !gsutil mv /content/bert/$BASE_MODEL $BUCKET_NAME
# Out:
# Copying file:///content/bert/uncased_L-12_H-768_A-12/bert_config.json [Content-Type=application/json]...
# Removing file:///content/bert/uncased_L-12_H-768_A-12/bert_config.json...
# Copying file:///content/bert/uncased_L-12_H-768_A-12/bert_model.ckpt.meta [Content-Type=application/octet-stream]...
# Removing file:///content/bert/uncased_L-12_H-768_A-12/bert_model.ckpt.meta...
# Copying file:///content/bert/uncased_L-12_H-768_A-12/bert_model.ckpt.index [Content-Type=application/octet-stream]...
# Removing file:///content/bert/uncased_L-12_H-768_A-12/bert_model.ckpt.index...
# Copying file:///content/bert/uncased_L-12_H-768_A-12/vocab.txt [Content-Type=text/plain]...
# Removing file:///content/bert/uncased_L-12_H-768_A-12/vocab.txt...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file:///content/bert/uncased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001 [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Removing file:///content/bert/uncased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001...
#
# Operation completed over 5 objects/421.1 MiB.

# %% [markdown]
# ### **Training**
#
# > Set options for TPU.
#
# 1.   --use_tpu=True
# 2.   --tpu_name="find with 'TPU address is =>"

# %%
# !python run_squad.py \
  --vocab_file=$BUCKET_NAME/$BASE_MODEL/vocab.txt \
  --bert_config_file=$BUCKET_NAME/$BASE_MODEL/bert_config.json \
  --init_checkpoint=$BUCKET_NAME/$BASE_MODEL/bert_model.ckpt \
  --do_train=True \
  --train_file=train-$SQUAD_VERSION.json \
  --do_predict=True \
  --predict_file=dev-$SQUAD_VERSION.json \
  --train_batch_size=24 \
  --learning_rate=3e-5 \
  --num_train_epochs=2.0 \
  --use_tpu=True \
  --tpu_name=$TPU_ADDRESS \
  --max_seq_length=384 \
  --doc_stride=128 \
  --output_dir=$OUTPUT_DIR
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.473998 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.481043 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.481314 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.487183 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.487451 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.493523 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.493782 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.498879 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.499128 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.504684 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.504951 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.509837 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.510079 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.515929 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.516197 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Processing example: 1000
# I0516 09:17:50.519126 140150010460032 run_squad.py:1259] Processing example: 1000
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.522017 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.522195 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.528058 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.528270 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.534365 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.534568 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.540290 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.540501 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.546664 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.546914 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.552941 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.553165 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.559165 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.559480 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.567780 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.568016 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.572167 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.572387 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.577600 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.577827 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.583837 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.584071 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.589700 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.589956 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.596347 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.596569 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.602002 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.602215 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.608379 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.608586 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.614298 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.614509 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.620932 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.621153 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.627208 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.627439 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.633158 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.633386 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.639619 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.639878 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.645792 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.646037 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.651407 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.651635 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.657976 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.658203 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.664438 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.664699 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.672371 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.672741 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.680065 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.680373 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.686834 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.687163 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.693590 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.693951 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.699729 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.700216 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.705669 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.705980 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.710894 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.711134 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.715282 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.715548 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.720168 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.720412 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.726150 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.726392 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.732549 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.732825 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.745913 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.746203 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.751390 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.751662 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.757085 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.757366 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.762883 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.763172 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.769400 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.769673 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.775190 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.775483 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.781041 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.781354 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.786044 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.786306 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.791021 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.791289 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.796181 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.796437 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.801172 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.801443 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.807112 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.807524 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.813699 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.814025 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.819095 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.819446 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.825953 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.826220 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.831291 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.831557 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.837778 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.838006 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.843896 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.844136 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.849864 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.850097 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.856246 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.856557 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.862448 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.862685 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.869012 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.869325 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.874690 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.874930 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.881210 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.881501 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.887183 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.887462 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.894800 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.895081 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.900341 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.900573 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.905426 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.905634 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.914131 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.914369 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.918894 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.919138 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.926945 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.927171 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.931653 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.931919 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.936567 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.936802 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.942852 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.943088 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.948932 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.949168 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.955111 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.955477 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.961268 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.961520 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.967765 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.968028 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.977167 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.977532 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.984065 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.984374 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.991795 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.992216 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:50.998400 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:50.998663 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.003887 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.004183 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.009187 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.009679 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.014410 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.014812 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.019455 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.019696 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.024289 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.024532 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.029436 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.029683 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.035783 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.036044 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.041726 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.042006 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.048146 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.048406 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.054787 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.055050 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.060566 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.060845 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.066729 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.067005 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.074236 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.074615 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.079956 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.080199 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.086448 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.086695 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.091156 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.091402 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.097822 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.098043 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.103987 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.104236 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.110009 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.110284 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.116777 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.117013 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.122799 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.123049 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.128637 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.128899 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.134666 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.134923 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.140801 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.141033 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.147243 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.147499 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.153411 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.153738 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.160001 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.160236 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.165910 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.166170 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.171593 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.171978 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.184331 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.184696 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.191613 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.191949 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.199137 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.199410 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.205036 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.205305 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.210494 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.210734 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.215821 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.216043 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.221426 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.221719 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.227111 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.227392 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.232638 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.232974 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.239966 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.240268 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.245436 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.245668 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.251319 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.251554 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.257474 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.257710 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.267371 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.267771 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.273401 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.273671 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.279231 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.279584 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.285138 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.285407 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.290569 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.290829 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.296234 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.296561 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Processing example: 2000
# I0516 09:17:51.298505 140150010460032 run_squad.py:1259] Processing example: 2000
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.302058 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.302251 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.307630 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.307887 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.313067 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.313317 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.318778 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.319036 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.324138 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.324396 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.329027 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.329276 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:51.335063 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:51.335325 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# ...
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.698868 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.703953 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.704211 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.709088 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.709353 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.714056 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.714309 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.719268 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.719515 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.724359 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.724591 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.729458 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.729692 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.734335 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.734570 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.739616 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.739885 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.744706 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.745019 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.749826 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.750085 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.755095 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.755397 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.760451 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.761395 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.766779 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.767044 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.771898 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.772160 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.777141 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.777416 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.781851 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.782115 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.787402 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.787681 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.792225 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.792497 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.797262 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.797532 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.802203 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.802483 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.807455 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.807750 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.812710 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.813027 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.818137 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.818434 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.825282 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.825621 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.831042 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.831346 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.836383 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.836703 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.841861 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.842155 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.847244 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.847548 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.852509 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.852805 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.857467 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.857712 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.863168 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.863482 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.870064 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.870425 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.877246 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.877590 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.882704 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.883046 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.888565 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.888908 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.894223 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.894548 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.900299 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.900608 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.906344 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.906641 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0516 09:17:58.909692 140150010460032 tpu_estimator.py:590] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0516 09:17:58.909964 140150010460032 tpu_estimator.py:594] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Stop infeed thread controller
# I0516 09:17:58.911957 140150010460032 tpu_estimator.py:598] Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# I0516 09:17:58.912155 140150010460032 tpu_estimator.py:430] Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# I0516 09:17:58.912352 140148638902016 tpu_estimator.py:425] InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# I0516 09:17:58.912456 140148638902016 tpu_estimator.py:530] Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# I0516 09:17:58.912591 140150010460032 error_handling.py:96] infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# I0516 09:17:58.912740 140150010460032 tpu_estimator.py:602] Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# I0516 09:17:58.912850 140150010460032 tpu_estimator.py:430] Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# I0516 09:17:58.912992 140148613723904 tpu_estimator.py:425] OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# I0516 09:17:58.913077 140148613723904 tpu_estimator.py:541] Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# I0516 09:17:58.913200 140150010460032 error_handling.py:96] outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# I0516 09:17:58.913321 140150010460032 tpu_estimator.py:606] Shutdown TPU system.
# INFO:tensorflow:prediction_loop marked as finished
# I0516 09:17:59.095217 140150010460032 error_handling.py:96] prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# I0516 09:17:59.095527 140150010460032 error_handling.py:96] prediction_loop marked as finished
# INFO:tensorflow:Writing predictions to: gs://bk_bert_squad_v2p0/uncased_L-12_H-768_A-12_out/predictions.json
# I0516 09:17:59.095714 140150010460032 run_squad.py:745] Writing predictions to: gs://bk_bert_squad_v2p0/uncased_L-12_H-768_A-12_out/predictions.json
# INFO:tensorflow:Writing nbest to: gs://bk_bert_squad_v2p0/uncased_L-12_H-768_A-12_out/nbest_predictions.json
# I0516 09:17:59.095839 140150010460032 run_squad.py:746] Writing nbest to: gs://bk_bert_squad_v2p0/uncased_L-12_H-768_A-12_out/nbest_predictions.json

# %% [markdown]
# ### **Evaluate**

# %%
# !gsutil cp $OUTPUT_DIR/predictions.json .
# !python evaluate-${SQUAD_VERSION}.py dev-${SQUAD_VERSION}.json predictions.json
# Out:
# Copying gs://bk_bert_squad_v2p0/uncased_L-12_H-768_A-12_out/predictions.json...
# - [1 files][577.4 KiB/577.4 KiB]
# Operation completed over 1 objects/577.4 KiB.
# {"exact_match": 80.79470198675497, "f1": 88.11652189524192}
