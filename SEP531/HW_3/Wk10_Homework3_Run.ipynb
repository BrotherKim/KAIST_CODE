# %% [markdown]
# <a href="https://colab.research.google.com/github/BrotherKim/KAIST_CODE/blob/master/SEP531/HW_3/Wk10_Homework3_Run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
function ClickConnect(){
    console.log("코랩 연결 끊김 방지");
    document.querySelector("colab-toolbar-button#connect").click()
}
setInterval(ClickConnect, 60 * 1000)

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !rm -rf /content/KAIST_CODE
# %cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/BrotherKim/KAIST_CODE.git
# %cd KAIST_CODE/SEP531/HW_3/Homework3/
# Out:
# Cloning into 'KAIST_CODE'...
# remote: Enumerating objects: 490, done.
# remote: Counting objects: 100% (490/490), done.
# remote: Compressing objects: 100% (293/293), done.
# remote: Total 490 (delta 298), reused 388 (delta 196), pack-reused 0
# Receiving objects: 100% (490/490), 40.39 MiB | 32.21 MiB/s, done.
# Resolving deltas: 100% (298/298), done.
# /content/KAIST_CODE/SEP531/HW_3/Homework3

# %%
# !ls
# Out:
# data	   nmt.py	 README.md  run.sh    vocab.py
# for_colab  README_ko.md  run.py     utils.py

# %%
# !bash run.sh vocab
# Out:
# read in source sentences: ./data/train.de-en.de.wmixerprep
# read in target sentences: ./data/train.de-en.en.wmixerprep
# initialize source vocabulary ..
# number of word types: 32008, number of word types w/ frequency >= 2: 32008
# initialize target vocabulary ..
# number of word types: 22823, number of word types w/ frequency >= 2: 22823
# generated vocabulary, source 32011 words, target 22824 words
# vocabulary saved to ./data/vocab.json

# %%
#patience 1
# !bash run.sh train
# Out:
# {'--batch-size': '32',
#  '--batch_size': 32,
#  '--beam-size': '5',
#  '--beam_size': 5,
#  '--clip-grad': '5.0',
#  '--clip_grad': 5.0,
#  '--continue_training': False,
#  '--cuda': True,
#  '--dev-src': './data/valid.de-en.de',
#  '--dev-tgt': './data/valid.de-en.en',
#  '--dev_src': './data/valid.de-en.de',
#  '--dev_tgt': './data/valid.de-en.en',
#  '--dropout': 0.3,
#  '--embed-size': '256',
#  '--embed_size': 256,
#  '--help': False,
#  '--hidden-size': '256',
#  '--hidden_size': 256,
#  '--input-feed': False,
#  '--log-every': '10',
#  '--log_every': 10,
#  '--lr': 0.001,
#  '--lr-decay': '0.5',
#  '--lr_decay': 0.5,
#  '--max-decoding-time-step': '70',
#  '--max-epoch': '30',
#  '--max-num-trial': '5',
#  '--max_decoding_time_step': 70,
#  '--max_epoch': 30,
#  '--max_num_trial': 5,
#  '--patience': 1,
#  '--sample-size': '5',
#  '--save-to': 'model.bin',
#  '--save_to': '/content/drive/MyDrive/KAIST/SEP531/hw3_cp/checkpoint',
#  '--seed': 0,
# ...

# %%
#patience 3
# !bash run.sh train
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# epoch 4, iter 15310, avg. loss 40.11, avg. ppl 7.64 cum. examples 41902, speed 12426.22 words/sec, time elapsed 752.06 sec
# epoch 4, iter 15320, avg. loss 40.53, avg. ppl 7.26 cum. examples 42222, speed 13470.08 words/sec, time elapsed 752.55 sec
# epoch 4, iter 15330, avg. loss 43.32, avg. ppl 8.26 cum. examples 42542, speed 12835.69 words/sec, time elapsed 753.06 sec
# epoch 4, iter 15340, avg. loss 41.96, avg. ppl 8.60 cum. examples 42862, speed 12743.21 words/sec, time elapsed 753.55 sec
# epoch 4, iter 15350, avg. loss 42.09, avg. ppl 8.43 cum. examples 43182, speed 12858.99 words/sec, time elapsed 754.04 sec
# epoch 4, iter 15360, avg. loss 40.63, avg. ppl 7.87 cum. examples 43502, speed 13144.67 words/sec, time elapsed 754.52 sec
# epoch 4, iter 15370, avg. loss 42.62, avg. ppl 8.65 cum. examples 43822, speed 13501.59 words/sec, time elapsed 754.99 sec
# ...

# %%
#patience 5
# !bash run.sh train
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# epoch 7, iter 33190, avg. loss 34.89, avg. ppl 6.04 cum. examples 38080, speed 13423.76 words/sec, time elapsed 1663.56 sec
# epoch 7, iter 33200, avg. loss 34.83, avg. ppl 6.06 cum. examples 38400, speed 12512.50 words/sec, time elapsed 1664.05 sec
# epoch 7, iter 33210, avg. loss 33.00, avg. ppl 5.73 cum. examples 38720, speed 12798.89 words/sec, time elapsed 1664.53 sec
# epoch 7, iter 33220, avg. loss 32.71, avg. ppl 5.78 cum. examples 39040, speed 12166.32 words/sec, time elapsed 1665.02 sec
# epoch 7, iter 33230, avg. loss 37.92, avg. ppl 6.79 cum. examples 39360, speed 12783.91 words/sec, time elapsed 1665.51 sec
# epoch 7, iter 33240, avg. loss 35.73, avg. ppl 6.24 cum. examples 39680, speed 12613.40 words/sec, time elapsed 1666.01 sec
# epoch 7, iter 33250, avg. loss 35.53, avg. ppl 6.12 cum. examples 40000, speed 13407.65 words/sec, time elapsed 1666.48 sec
# ...

# %%
#patience 7
# !bash run.sh train
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# epoch 12, iter 57140, avg. loss 29.61, avg. ppl 4.60 cum. examples 36480, speed 12819.05 words/sec, time elapsed 2826.77 sec
# epoch 12, iter 57150, avg. loss 26.92, avg. ppl 4.19 cum. examples 36800, speed 13115.16 words/sec, time elapsed 2827.23 sec
# epoch 12, iter 57160, avg. loss 29.08, avg. ppl 4.67 cum. examples 37120, speed 12571.41 words/sec, time elapsed 2827.71 sec
# epoch 12, iter 57170, avg. loss 31.83, avg. ppl 4.62 cum. examples 37440, speed 13419.52 words/sec, time elapsed 2828.21 sec
# epoch 12, iter 57180, avg. loss 29.10, avg. ppl 4.42 cum. examples 37760, speed 12947.15 words/sec, time elapsed 2828.69 sec
# epoch 12, iter 57190, avg. loss 31.15, avg. ppl 4.87 cum. examples 38080, speed 12994.27 words/sec, time elapsed 2829.18 sec
# epoch 12, iter 57200, avg. loss 29.82, avg. ppl 4.74 cum. examples 38400, speed 12810.52 words/sec, time elapsed 2829.66 sec
# ...

# %%
# patience = 9
# !bash run.sh train
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# epoch 20, iter 91080, avg. loss 25.22, avg. ppl 3.41 cum. examples 34542, speed 13003.21 words/sec, time elapsed 4482.42 sec
# epoch 20, iter 91090, avg. loss 22.61, avg. ppl 3.29 cum. examples 34862, speed 12616.88 words/sec, time elapsed 4482.90 sec
# epoch 20, iter 91100, avg. loss 23.50, avg. ppl 3.33 cum. examples 35182, speed 13286.38 words/sec, time elapsed 4483.37 sec
# epoch 20, iter 91110, avg. loss 21.11, avg. ppl 3.06 cum. examples 35502, speed 12899.21 words/sec, time elapsed 4483.84 sec
# epoch 20, iter 91120, avg. loss 22.97, avg. ppl 3.13 cum. examples 35822, speed 13588.61 words/sec, time elapsed 4484.31 sec
# epoch 20, iter 91130, avg. loss 24.16, avg. ppl 3.38 cum. examples 36142, speed 13000.06 words/sec, time elapsed 4484.80 sec
# epoch 20, iter 91140, avg. loss 23.87, avg. ppl 3.11 cum. examples 36462, speed 13272.17 words/sec, time elapsed 4485.31 sec
# ...

# %%
# !bash run.sh train

# %%
# !cp model.bin* /content/gdrive/MyDrive/KAIST/SEP531/hw3_cp

# %%
# !bash run.sh test

# %%
# !ls
# Out:
# data	   nmt.py	README_ko.md  run.py  utils.py
# for_colab  __pycache__	README.md     run.sh  vocab.py

# %%
# !bash run.sh test
# Out:
# load test source sentences from [./data/test.de-en.de]
# load test target sentences from [./data/test.de-en.en]
# load model from /content/gdrive/MyDrive/KAIST/SEP531/hw3_cp/model.bin
# Decoding:   0% 0/6750 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Decoding:   0% 0/6750 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "run.py", line 401, in <module>
#     main()
#   File "run.py", line 396, in main
#     decode(args)
#   File "run.py", line 287, in decode
#     max_decoding_time_step=int(args['--max-decoding-time-step']))
#   File "run.py", line 314, in beam_search
#     example_hyps = model.beam_search(src_sent, beam_size=beam_size, max_decoding_time_step=max_decoding_time_step)
#   File "/content/KAIST_CODE/SEP531/HW_3/Homework3/nmt.py", line 367, in beam_search
# ...
