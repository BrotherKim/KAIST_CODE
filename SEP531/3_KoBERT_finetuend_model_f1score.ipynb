# %% [markdown]
# <a href="https://colab.research.google.com/github/BrotherKim/KAIST_CODE/blob/master/SEP531/3_KoBERT_finetuend_model_f1score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ROOT_DIR = '/content/drive/MyDrive/KAIST/SEP531/kor_ks_labeled'
TRAIN_DIR = '%s/train' % ROOT_DIR
VALID_DIR = '%s/valid' % ROOT_DIR

NUM_TRAIN = 171
NUM_VALID = 58

SAVEPOINT_PATH = '/content/drive/MyDrive/KAIST/SEP531/KoBERT_emotion_finetuned_data_added.pt'
#SAVEPOINT_PATH = '/content/drive/MyDrive/KAIST/SEP531/KoBERT_emotion_finetuned.pt'

# %%
# !ls -l /content/drive/MyDrive/KAIST/SEP531
# Out:
# total 741149
# -rw------- 1 root root   1894595 Nov  8 06:21 4차년도.csv
# -rw------- 1 root root   2142130 Dec  4 08:42 4_utf8.csv
# -rw------- 1 root root   2167298 Dec  4 09:52 4차년도_utf8.csv
# -rw------- 1 root root   2642158 Nov  8 06:21 5차년도_2차.csv
# -rw------- 1 root root   2976104 Dec  4 08:41 5_2_utf8.csv
# -rw------- 1 root root   2976104 Dec  4 09:52 5차년도_2차_utf8.csv
# -rw------- 1 root root   1433551 Nov  8 06:21 5차년도.csv
# -rw------- 1 root root   1659315 Dec  4 08:41 5_utf8.csv
# -rw------- 1 root root   1678755 Dec  4 09:52 5차년도_utf8.csv
# drwx------ 2 root root      4096 Nov 23 14:55 hw3_cp
# -rw------- 1 root root 368848687 Nov  8 07:19 KoBERT_emotion_finetuned_data_added.pt
# -rw------- 1 root root 368848687 Nov  6 07:19 KoBERT_emotion_finetuned.pt
# drwx------ 2 root root      4096 Nov 21 00:02 kor_cc_labeled
# drwx------ 2 root root      4096 Nov 21 00:02 kor_jj_labeled
# drwx------ 2 root root      4096 Nov 21 00:02 kor_jr_labeled
# drwx------ 2 root root      4096 Nov  6 08:12 kor_ks_labeled
# drwx------ 2 root root      4096 Nov 21 00:02 kor_kw_labeled
# -rw------- 1 root root   1641543 Nov  6 06:49 한국어_단발성_대화_데이터셋.xlsx

# %% [markdown]
# #KoBERT 다운로드(사용)#

# %%
#깃허브에서 KoBERT 파일 로드
# !pip install git+https://git@github.com/SKTBrain/KoBERT.git@master
# Out:
# Collecting git+https://****@github.com/SKTBrain/KoBERT.git@master
#   Cloning https://****@github.com/SKTBrain/KoBERT.git (to revision master) to /tmp/pip-req-build-wpwfasvg
#   Running command git clone -q 'https://****@github.com/SKTBrain/KoBERT.git' /tmp/pip-req-build-wpwfasvg
# Requirement already satisfied: gluonnlp>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from kobert==0.1.2) (0.10.0)
# Requirement already satisfied: mxnet>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from kobert==0.1.2) (1.8.0.post0)
# Requirement already satisfied: onnxruntime>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from kobert==0.1.2) (1.9.0)
# Requirement already satisfied: sentencepiece>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from kobert==0.1.2) (0.1.96)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from kobert==0.1.2) (1.10.0+cu111)
# Requirement already satisfied: transformers>=4.8.1 in /usr/local/lib/python3.7/dist-packages (from kobert==0.1.2) (4.12.5)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from gluonnlp>=0.6.0->kobert==0.1.2) (0.29.24)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from gluonnlp>=0.6.0->kobert==0.1.2) (21.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from gluonnlp>=0.6.0->kobert==0.1.2) (1.19.5)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from mxnet>=1.4.0->kobert==0.1.2) (0.8.4)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet>=1.4.0->kobert==0.1.2) (2.23.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=0.3.0->kobert==0.1.2) (2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=0.3.0->kobert==0.1.2) (3.17.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet>=1.4.0->kobert==0.1.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet>=1.4.0->kobert==0.1.2) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet>=1.4.0->kobert==0.1.2) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet>=1.4.0->kobert==0.1.2) (1.24.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.7.0->kobert==0.1.2) (3.10.0.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.8.1->kobert==0.1.2) (0.2.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.8.1->kobert==0.1.2) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.8.1->kobert==0.1.2) (3.4.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=4.8.1->kobert==0.1.2) (0.0.46)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.8.1->kobert==0.1.2) (4.8.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.8.1->kobert==0.1.2) (2019.12.20)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.8.1->kobert==0.1.2) (0.10.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.8.1->kobert==0.1.2) (4.62.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->gluonnlp>=0.6.0->kobert==0.1.2) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.8.1->kobert==0.1.2) (3.6.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->onnxruntime>=0.3.0->kobert==0.1.2) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.8.1->kobert==0.1.2) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.8.1->kobert==0.1.2) (1.1.0)

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import gluonnlp as nlp
import numpy as np
from tqdm import tqdm, tqdm_notebook

# %%
#kobert
from kobert.utils import get_tokenizer
from kobert.pytorch_kobert import get_pytorch_kobert_model

#transformers
from transformers import AdamW
from transformers.optimization import get_cosine_schedule_with_warmup

# %%
#GPU 사용
device = torch.device("cuda:0")

# %%
#BERT 모델, Vocabulary 불러오기
bertmodel, vocab = get_pytorch_kobert_model()
# Out:
# using cached model
# using cached model

# %% [markdown]
# #실행 환경(사용)#
#
# - Python >= 3.6
# - PyTorch >= 1.70
# - Transformers = 3.0.2
# - Colab
# - batch size = 64 (convertable)
# - epochs = 10 (convertable)

# %%
# !pip install -U torchtext==0.6.0
# !pip install transformers
# Out:
# Requirement already satisfied: torchtext==0.6.0 in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (0.1.96)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.15.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (3.0.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchtext==0.6.0) (3.10.0.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.12.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.46)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)

# %%
#!pip install mxnet
#!pip install gluonnlp pandas tqdm
#!pip install sentencepiece
#!pip install transformers==3.0.2
#!pip install torch

# Libraries

import matplotlib.pyplot as plt
import pandas as pd
import torch

# Preliminaries

from torchtext.data import Field, TabularDataset, BucketIterator, Iterator

# Models

import torch.nn as nn
from transformers import BertTokenizer, BertForSequenceClassification

# Training

import torch.optim as optim

# Evaluation

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

# %%
#구글드라이브 연동
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #KoBERT 입력 데이터로 변환(사용)#

# %%
class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len,
                 pad, pair):
        transform = nlp.data.BERTSentenceTransform(
            bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair)

        self.sentences = [transform([i[sent_idx]]) for i in dataset]
        self.labels = [np.int32(i[label_idx]) for i in dataset]

    def __getitem__(self, i):
        return (self.sentences[i] + (self.labels[i], ))

    def __len__(self):
        return (len(self.labels))

# %%
# Setting parameters
max_len = 64
batch_size = 64
warmup_ratio = 0.1
num_epochs = 5
max_grad_norm = 1
log_interval = 200
learning_rate =  5e-5

# %% [markdown]
# #추출한 데이터에 감정 레이블 추가(사용)#

# %%
class BERTClassifier(nn.Module):
    def __init__(self,
                 bert,
                 hidden_size = 768,
                 num_classes=7,   ##클래스 수 조정##
                 dr_rate=None,
                 params=None):
        super(BERTClassifier, self).__init__()
        self.bert = bert
        self.dr_rate = dr_rate
                 
        self.classifier = nn.Linear(hidden_size , num_classes)
        if dr_rate:
            self.dropout = nn.Dropout(p=dr_rate)
    
    def gen_attention_mask(self, token_ids, valid_length):
        attention_mask = torch.zeros_like(token_ids)
        for i, v in enumerate(valid_length):
            attention_mask[i][:v] = 1
        return attention_mask.float()

    def forward(self, token_ids, valid_length, segment_ids):
        attention_mask = self.gen_attention_mask(token_ids, valid_length)
        
        _, pooler = self.bert(input_ids = token_ids, token_type_ids = segment_ids.long(), attention_mask = attention_mask.float().to(token_ids.device))
        if self.dr_rate:
            out = self.dropout(pooler)
        return self.classifier(out)

# %% [markdown]
# 새로운 문장을 테스트 할 때, 입력되는 문장을 KoBERT의 입력 형식으로 바꿔주는 코드를 작성해주어야 한다. 아래 코드를 작성하여 토큰화, 패딩, 텐서를 바꿔주고 예측을 하는 'predict' 함수를 만들어 주었다.

# %%
model1 = BERTClassifier(bertmodel,  dr_rate=0.5).to(device)
model1.load_state_dict(torch.load(SAVEPOINT_PATH), strict=False)
model1.eval()
# Out:
# BERTClassifier(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(8002, 768, padding_idx=1)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (classifier): Linear(in_features=768, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
#토큰화
tokenizer = get_tokenizer()
tok = nlp.data.BERTSPTokenizer(tokenizer, vocab, lower=False)

dic = {0:'공포', 1:'놀람', 2:'분노', 3:'슬픔', 4:'중립', 5:'행복', 6:'혐오'}
dic = {0:'fear', 1:'surprise', 2:'anger', 3:'sadness', 4:'neutral', 5:'happiness', 6:'disgust'}
r_dic = {'fear':0, 'surprise':1, 'anger':2, 'sadness':3, 'neutral':4, 'happiness':5, 'disgust':6}
def getEmotion(out):
  idx_eval=[]
  val_eval=[]
  for i in out:
    logits=i
    logits = logits.detach().cpu().numpy()
    idx = np.argmax(logits)
    idx_eval.append(idx)
    val_eval.append(dic.get(idx))
    return idx_eval[0], val_eval[0]


def predict(predict_sentence):

    data = [predict_sentence, '0']
    dataset_another = [data]

    another_test = BERTDataset(dataset_another, 0, 1, tok, max_len, True, False)
    test_dataloader = torch.utils.data.DataLoader(another_test, batch_size=batch_size, num_workers=5)
    
    model1.eval()

    for batch_id, (token_ids, valid_length, segment_ids, label) in enumerate(test_dataloader):
        token_ids = token_ids.long().to(device)
        segment_ids = segment_ids.long().to(device)

        valid_length= valid_length
        label = label.long().to(device)

        out = model1(token_ids, valid_length, segment_ids)

        return getEmotion(out)


        # file wrting
# Out:
# using cached model

# %% [markdown]
# #Eval

# %%
r_dic.get('sadness')
# Out:
# 3

# %%
import csv

y = []
p = []
def Eval(filename):
  with open(filename, 'r') as f:
    csv_data = csv.reader(f, delimiter=',')
    next(csv_data)
    for line in csv_data:
      text = line[1]
      label = line[2]
      label_idx = r_dic.get(label)
      idx, val = predict(text)
      #print('(%s/%s) %s\n' % (val, label, text))
      print('(%c)(%d/%d) %s\n' % ('O' if (idx == label_idx) else 'X', idx, label_idx, text))
      p.append(idx)
      y.append(label_idx)
  #print('>> Generated file %s/%s.answer\n' % (path, jsonfilename))

  #with open('%s/%s.data' % (path, jsonfilename), 'w') as f:
  #  for u in ut:
  #    f.write('%s\t%s\n' % (u['standard_form'], u['dialect_form']))

# %%
Eval(train_csv)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (X)(4/2) 어, 청소 니가 대신 해 줘!
#
# (X)(3/2) 둘 다 청소 하기 싫어. 귀찮아.
#
# (O)(2/2) 둘 다 하기 싫어서 화내.
#
# (X)(3/2) 그럼 방세는 어떡해.
#
# (O)(3/3) 권태긴줄 알았는데 다른 사람이 생겼나보더라고.
#
# (X)(4/3) 그냥 걷고 있어.
#
# (O)(2/2) 어. 고등학교 동창인데 이렇게 더럽게 쓸줄 몰랐어.
#
# (X)(4/3) 처음 학원에서 만났다가 서로 좋아해서 사귀게 되었지.
#
# (X)(4/3) 내가 애정 표현을 잘 못해서 자주 싸우긴 했어.
#
# (O)(3/3) 오늘 헤어졌어.
#
# (O)(2/2) 룸메이트와 너무 자주 싸우게 돼.
#
# (X)(3/2) 그러고 싶은데 보증금 때문에 그럴 수가 없어.
#
# (O)(3/3) 이 회사가 이번 시즌 마지막 회사였어.
#
# (X)(0/3) 부모님한테 아직 말 안했는데 말하기가 두려워.
#
# (O)(3/3) 아니. 입맛도 없어.
#
# (X)(2/3) 응. 혼 났지.
#
# (O)(3/3) 그럴 시간도 없다.
#
# (O)(3/3) 부모님도 다 슬퍼하셔.
#
# (X)(5/3) 그래, 고마워.
#
# (O)(2/2) 해봤는데, 전화를 안 받네.
#
# (X)(4/2) 맨날 그래 얘는.
#
# (X)(3/2) 어. 크게 다치진 않았는데.
#
# (X)(4/2) 일주일에 다섯번은 먹는다니까?
#
# (O)(3/3) 그저께 아파해서 병원을 갔는데 괜찮아지나 싶더니 결국엔 이렇게 됐네.
#
# (O)(3/3) 다들 마음이 안좋지. 집에 들어가기도 싫네, 나는.
#
# (O)(3/3) 응. 그래봐야지. 해피도 오래 살긴 했어.
#
# (X)(3/2) 그렇지. 뭐 생명까지는 괜찮은데. 우리 마음에 지장이 있네.
#
# (X)(3/2) 지난 번에도 드시고 다친 적 있었거든, 얼굴? 이번에 또 그런 거야.
#
# (X)(3/2) 다들 지쳤어. 나도 지쳤구, 이제.
#
# (O)(3/3) 어제 밤 새서 작성한 기획안 다시 해야되네.
#
# (X)(4/3) 그렇지. 아픈데도 했더니, 참, 근데 맞는 말이라서.
#
# (O)(3/3) 응. 마음 좀 추스려야지. 근데 내가 잘하는게 없는 거 같네.
#
# (X)(4/3) 모르겠어. 좀 최대한 추스려볼게.
#
# (O)(3/3) 노력하면 괜찮아지겠지. 근데 내가 실력이 부족한 건 맞아.
#
# (O)(2/2) 청소 좀 하고 살자.
#
# (X)(4/3) 응. 그 동안 괜찮았는데.
#
# (X)(3/2) 응. 인제 병원에서 퇴원하는 길이야.
#
# (O)(3/3) 이제 두 달 지났어.
#
# (O)(0/0) 어제 지진 있었잖아. 다행히 다치진 않았어.
#
# (X)(3/0) 옆에서 친구가 넘어져서 발목 다쳤어.
#
# (X)(4/2) 아니 룸메이트 하기 전에는 그냥 학교에서만 알던 사이?
#
# (X)(3/2) 또 술 먹고 그랬지 뭐. 지금 병원에 계셔.
#
# (O)(2/2) 했는데 소용 없어. 다 포기했어, 지금은.
#
# (O)(3/3) 응. 걷고 있어.
#
# (O)(3/3) 아휴. 이제 내년 거 준비해야지 뭐.
#
# (O)(3/3) 너무 죄송해서 말도 못하겠어.
#
# (X)(3/0) 응. 다리 조금 다쳤는데 좀 쉬면 괜찮아질 것 같아.
#
# (O)(3/3) 다른 여자가 생겼나봐.
#
# (X)(4/3) 대학교 때 동아리 선배였었어.
#
# (X)(4/3) 우리는 싸울 일이 전혀 없었어.
#
# (O)(3/3) 두 달 됐나봐. 일년 지난 거 같아.
#
# (X)(4/3) 잘 모르겠어.
#
# (O)(3/3) 나 면접에서 떨어졌어.
#
# (X)(4/3) 집에서 쉬고 있어.
#
# (O)(3/3) 내일부터 다시 다른데 알아보려고.
#
# (O)(3/3) 먹었지. 이미 너무 늦은 시간인걸.
#
# (O)(2/2) 지난달에 내가 분명히 얘기 했거든? 근데 며칠 가지도 않아.
#
# (X)(1/0) 어제 지진 난 거 알아?
#
# (X)(4/0) 나는 괜찮아.
#
# (X)(3/0) 친구가 좀 심하게 다쳤어.
#
# (X)(3/2) 당연히 따로 살고 싶은데 자취방 보증금을 나 혼자 어떻게 내.
#
# (O)(2/2) 벌써 30분은 지난 거 같애.
#
# (O)(2/2) 전화했는데 다와간다는데 안오네 아직도.
#
# (O)(2/2) 가끔 한 번씩 그러긴 하는데, 오늘은 좀 심하네. 아, 화나!
#
# (O)(6/6) 응. 치워야 되는데 어떡하지? 누가 치우지도 않고 갔네?
#
# (X)(4/6) 그래야겠다. 좀 이따 보고 내가 치우든지 해야겠다.
#
# (O)(3/3) 나 이번 회사 면접 또 떨어졌어.
#
# (O)(3/3) 엄마 아빠 얼굴도 못 보겠어서 괜히 밖에 돌아다니고 있어.
#
# (O)(3/3) 당연히 얘기 못했지. 지금 집에도 못 들어가고 있는데.
#
# (O)(3/3) 계속 걱정하느라 밥 생각도 안나.
#
# (O)(2/2) 지금 저녁 약속 있어서 친구 기다리는데, 얘가 올 생각을 안 해.
#
# (O)(2/2) 벌써 한 시간이 넘었다. 미친 거 아니야?
#
# (O)(2/2) 당연히 연락 해봤지! 근데 답장도 잘 안해.
#
# (O)(2/2) 어휴 얘 고등학교 때부터 그랬어.
#
# (O)(2/2) 이걸로 몇 번 싸우기도 했는데 도대체 들어먹질 않어.
#
# (O)(2/2) 룸메와 너무 싸우게 돼.
#
# (X)(3/2) 방을 너무 지저분하게 써. 경고도 했는데.
#
# (O)(2/2) 한 달 전 쯤에 경고를 한 번 줬는데, 좀 고쳐지는 듯 하더니, 또 그러네. 음식물 쓰레기도 막 버리고.
#
# (X)(4/2) 응. 고등학교 동창이야.
#
# (X)(3/2) 보증금이 없어서. 한동안 같이 지내야 될 거 같아.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (X)(4/3) 친구였다가 사귀게 됐어.
#
# (O)(3/3) 아니. 3년동안 한번도 싸운적이 없었어.
#
# (O)(3/3) 그렇다고 일찍 퇴근하면 잘 하지도 못하면서 노력도 안한다고 그럴 것 같아.
#
# (O)(3/3) 내가 부족해서 그런 거 나도 알고 있다니까!
#
# (O)(2/2) 우리 아빠 어제 술먹고 또 사고쳤어.
#
# (O)(2/2) 거의 맨날 먹어. 일주일에 하루 이틀 빼곤 거의 술이야!
#
# (O)(2/2) 엄마는 포기한지 한참됐고 이제 나도 모르겠어.
#
# (X)(4/2) 고등학교 때 엄청 친한 사이였어. 근데 이럴 줄은 몰랐다.
#
# (O)(3/3) 오늘 면접도 다 떨어졌다.
#
# (X)(2/3) 아니. 다른 친구들도 다 붙었는데, 염치가 있지. 얘기 못 드렸어.
#
# (O)(2/2) 아 몰라 진짜 미쳤나봐. 왜 나한테만 이래.
#
# (O)(3/3) 엄마 아빠도 계속 슬퍼하지.
#
# (O)(3/3) 말씀 드려야지.
#
# (O)(6/6) 할 뻔 했어. 나까지 토할 뻔했다, 야.
#
# (O)(6/6) 아니, 아니야. 따뜻한 물도 못 먹겠어.
#
# (X)(4/6) 이따 내려가면서 관리실에 얘기해야지.
#
# (O)(2/2) 벌써 한 시간 넘어간다. 이거 진짜 너무한 거 아니냐.
#
# (X)(4/2) 얘 고등학교 때부터 유명했어.
#
# (O)(3/3) 나 결국 남자친구랑 헤어졌어.
#
# (O)(3/3) 자긴 권태긴 것 같다고 시간을 갖자고 그러더라. 그런데 결국 다른 사람이 생긴 것 같아.
#
# (X)(3/2) 아니. 술 마시고 계단에서 넘어지셔서 지금 병원에 있어.
#
# (X)(3/2) 응. 잠깐 허리만 삐끗하신 것 같아.
#
# (X)(3/2) 처음에는 몇 번 했는데, 이제는 거의 포기 상태야.
#
# (O)(3/3) 사실 두 달도 넘었어.
#
# (O)(2/2) 룸메랑 싸우는 것도 이제 지긋지긋하다 정말.
#
# (O)(2/2) 당연히 화내봤지! 근데 그것도 그때 뿐이야.
#
# (X)(0/2) 보증금이 800인데, 나 혼자서 부담할 수가 없잖아.
#
# (O)(6/6) 화장실에 토한 거 그대로 있다.
#
# (O)(6/6) 속이 미슥미슥 거려. 나도 토할 거 같애.
#
# (X)(4/6) 그래야겠다. 나가는 김에 얘기하고 가야겠어.
#
# (O)(2/2) 아니, 약속을 해놓고 왜 얘는 이렇게 안 와!
#
# (O)(2/2) 지금 한 시간이 넘었어!
#
# (O)(3/3) 위로해줘서. 응, 다시 준비해야지.
#
# (O)(3/3) 다. 밥? 먹었어 방금.
#
# (O)(2/2) 아무리 얘기해도 지가 뭘 잘못했는지를 몰라!
#
# (O)(3/3) 나는 하는 일마다 왜 다 이 모양일까.
#
# (O)(3/3) 내가 엉망으로 해서 혼난 거라 할 말도 없어.
#
# (O)(2/2) 당연히 내봤지.
#
# (X)(3/2) 아. 힘들어. 너무 힘들어.
#
# (O)(2/2) 그래서 따로 방 구하려고. 알아봤어.
#
# (X)(4/3) 챙겨먹었어?
#
# (O)(3/3) 난 잘하는 게 없나봐.
#
# (X)(4/3) 잠깐 나갔다 올까?
#
# (O)(3/3) 일찍은 못 갈 거 같아.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 오래 살았어.
#
# (X)(4/3) 이제 알아보는 중이야.
#
# (O)(2/2) 야! 우리 아빠 어제 또 넘어졌어.
#
# (O)(2/2) 술 먹고 그랬지 뭐! 아휴. 몰라!
#
# (X)(4/2) 생명이 뭐여. 아유, 지장 없어!
#
# (O)(2/2) 아유, 주 5일은 먹네, 주 5일은! 어휴, 맨날 먹어, 맨날!
#
# (O)(2/2) 그런 건 소용 없어. 소용 하나도 없어!
#
# (X)(4/6) 괜히 거기로 갔어. 가지 말걸.
#
# (X)(3/6) 하, 얼른 잊어버려야지.
#
# (X)(4/6) 아까 이미 말씀드렸어.
#
# (X)(3/0) 친구가 다쳤어.
#
# (X)(4/0) 다들 괜찮은 거 같아.
#
# (X)(4/6) 따뜻한 물 마시는 건 솔직히 좀 답이 아닌 거 같고, 그냥 빨리 화장실 가서 볼 일 보고, 맛있는거나 먹으러 가자.
#
# (X)(4/6) 그래! 관리자한테 말하고 빨리 치우라고 말하자.
#
# (O)(2/2) 한 시간은 된 거 같다, 진짜! 도대체 언제까지! 아, 진짜.
#
# (O)(2/2) 근데 하, 진짜 깜깜무소식이다!
#
# (O)(2/2) 화를 내봤는데 고치는듯 하더니 또 그러네.
#
# (O)(2/2) 하. 안그래도 다른 회사 알아봐야될 거 같애.
#
# (O)(3/3) 밤새 기획안 작성했는데, 다 잘못됐대.
#
# (X)(3/2) 친한 여직원들 있긴 한데, 하, 잘 모르겠다.
#
# (X)(4/2) 알았어. 들어줘서 고마워.
#
# (O)(2/2) 약속 있어서 친구 기다리고 있는데 아직도 안왔어.
#
# (O)(2/2) 어. 조금만 기달리래. 계속 기달리라고만 말해.
#
# (O)(2/2) 얘는 매번 늦어.
#
# (X)(3/2) 우리 아빠가 또 다쳤어.
#
# (O)(2/2) 뻔하지. 또 술마시고 넘어졌어.
#
# (X)(4/2) 자주 드셔.
#
# (O)(2/2) 진짜 퇴근한지 얼마나 됐다고 회사에서 연락이 또 왔어.
#
# (X)(5/2) 있어서 정말 다행이야. 정말 고마워.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어.
#
# (O)(0/0) 지진이 났잖아. 나는 괜찮았는데 내 친구는 발목을 다쳤어.
#
# (X)(4/0) 지금은 괜찮은 거 같애.
#
# (X)(4/0) 내 친구는 발목을 다쳤거든. 다른 사람들은 잘 모르겠어.
#
# (X)(4/0) 어, 나도 며칠 지켜봐야될 거 같애.
#
# (O)(6/6) 누가 화장실에 토하고 하나도 안 치웠어.
#
# (X)(4/6) 지금도 그대로 있다니까?
#
# (O)(6/6) 으, 물 마시려고 해도 자꾸 그게 생각 나.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (X)(4/3) 집에 가는 길.
#
# (X)(4/3) 아니 아직 모르셔.
#
# (O)(3/3) 아니, 아직. 배도 안 고파.
#
# (O)(2/2) 아까부터 계속 연락했는데 답도 잘 없어!
#
# (O)(2/2) 얘 맨날 이래!
#
# (O)(2/2) 얘기를 해도 그 때 뿐이고 다음에 약속하면 또 똑같이 맨날 늦어.
#
# (O)(2/2) 아, 룸메랑 또 싸웠어!
#
# (O)(2/2) 알기는 고딩 때부터 알았지.
#
# (X)(1/0) 지금은 괜찮은데 어제 완전 놀랬어.
#
# (O)(0/0) 응 그래야겠어. 지진을 처음 겪어봐서 진짜 너무 무섭더라.
#
# (O)(2/2) 아, 못다녀, 못다녀! 아, 진짜 짜증나!
#
# (O)(2/2) 아 진짜 딴 데로 옮겨야 되나봐! 월급 더 주는 것도 아니면서 왜 나한테만 일을 시켜?
#
# (O)(2/2) 다른 사람 일까지 다 나한테 시키는데 내가 누구한테 털어놔!
#
# (O)(2/2) 아 진짜 니가 욕이라도 해줘. 진짜 화병생기겠어.
#
# (O)(3/3) 그냥 밖에 돌아다니고 있어.
#
# (X)(2/3) 하도 스트레스 받아서 그런지 배도 안 고파.
#
# (O)(2/2) 룸메랑 너무 싸워. 진짜.
#
# (O)(6/6) 으, 화장실에 누가 토하고 안치웠어.
#
# (O)(6/6) 어. 지금도 그대로 있어. 너무 놀라서 뛰쳐나왔잖아.
#
# (X)(1/6) 당연히 완전 놀랐지.
#
# (O)(6/6) 안그래도 지금 막 물 좀 마시려고.
#
# (X)(5/6) 어, 좋은 생각이다. 내가 지금 가서 얘기하고 올게.
#
# (O)(0/0) 어제 갑자기 지진이 일어났거든.
#
# (X)(4/0) 어, 지금은 안정 된 거 같애.
#
# (X)(3/0) 내 친구가 발목을 조금 다쳤어.
#
# (O)(2/2) 그러니까. 나한테만 일을 시키고. 완전 다니기 싫어.
#
# (X)(3/2) 내일부터라도 당장 이직 준비를 해야겠어.
#
# (X)(3/2) 다들 나한테 일만 시킬려고 하지 내 말은 아무도 들어주지 않아.
#
# (X)(3/2) 우리 아빠가 어제 또 다쳤어.
#
# (X)(4/2) 다행히 생명에 지장은 없대.
#
# (X)(3/2) 일주일에 5일이나 술을 마셔. 너무 걱정 돼.
#
# (X)(3/2) 여러번 해봤는데 소용없어.
#
# (X)(3/2) 해봐도 그때 뿐이야. 잠깐만 나아지는 거 같아도, 다시 원상태로 돌아와.
#
# (O)(3/3) 어제 진행했는데 너무 허전해.
#
# (O)(3/3) 밤 새서 기획안을 작성했는데, 혼만 났어.
#
# (X)(4/3) 너랑 통화하려고 잠깐 밖에 나와있긴 해.
#
# (O)(3/3) 그렇게 말해주는 사람은 너 밖에 없어.
#
# (O)(3/3) 지금 면접 보고 나오는 길이야. 밖에 있어.
#
# (O)(3/3) 응. 또 준비 해야지.
#
# (O)(3/3) 다 떨어졌는데, 입맛도 없어, 지금은.
#
# (O)(2/2) 룸메랑 너무 자주 싸우게 돼.
#
# (O)(2/2) 얘는 청소를 너무 안해. 음식물 쓰레기도 아무데나 버려.
#
# (O)(2/2) 고등학교 동창인데 이정도일줄은 몰랐어.
#
# (O)(3/3) 권태기가 왔다고 잠시 시간을 갖자더니, 다른 여자가 생겼대.
#
# (X)(4/3) 이제 한 두달 정도 됐나?
#
# (O)(3/3) 나 애인한테 차였어.
#
# (O)(3/3) 학교에서 만난 후배인데 나 군대도 기다려준 친구야.
#
# (O)(3/3) 사소한 일로 많이 싸웠었는데, 그 때마다 잘 풀었었어.
#
# (O)(6/6) 응. 아직 그대로 있어! 더러워 죽겠어!
#
# (X)(4/6) 응. 그래야 될 거 같아. 다른 층을 써야될 거 같애.
#
# (X)(2/6) 그러게. 사람들 매너가 꽝이네. 물이라도 좀 마셔야겠다.
#
# (X)(4/6) 응. 조금 있다 가서 말씀드릴게.
#
# (O)(2/2) 한 달 전에 주의를 줬는데, 또 그러네?
#
# (X)(4/2) 고등학교 때 동창이었어.
#
# (X)(4/2) 보증금이 모잘라서 아직 안돼.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(3/3) 혼자 밖에서 걷고 있어.
#
# (O)(3/3) 아직까지 부모님한테는 알리지 못했어.
#
# (O)(6/6) 으 화장실에 누가 토하고 안 치우고 갔어.
#
# (O)(6/6) 응. 아직도 그대로 있어.
#
# (O)(6/6) 으 다른 층 써야될 거 같아. 깜짝 놀랐네.
#
# (X)(2/6) 그래야될 거 같아. 말해야 되겠어.
#
# (O)(3/3) 나는 잘하는게 없나봐.
#
# (O)(3/3) 응. 회사 상사한테 혼났어.
#
# (O)(3/3) 일찍 퇴근하기는 글렀어. 밤 새야될 거 같아.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어.
#
# (O)(0/0) 친구와 밥 먹는데, 심한 지진이 일어났어.
#
# (X)(3/0) 친구가 발목을 다쳤어.
#
# (X)(4/0) 그래. 그렇게 할게.
#
# (X)(3/2) 매일 그만두고 싶은 마음이야.
#
# (X)(3/2) 아. 사실 갈 데가 없어.
#
# (X)(3/2) 아니. 아무도 없어. 난 혼자야.
#
# (X)(3/2) 방을 너무 지저분하게 써.
#
# (O)(2/2) 한 달 전에 주의를 줬는데 또 그러네?
#
# (X)(4/2) 고등학교 때 동창이었어.
#
# (X)(3/2) 보증금이 모잘라서 당분간은 힘들 거 같애.
#
# (O)(2/2) 룸메와 너무 자주 싸우고 있어.
#
# (O)(2/2) 한달 전에 화를 냈었는데, 그 때 이후로 괜찮아지더니 다시 지금 또 그래.
#
# (O)(2/2) 응. 고등학교 동창이었는데 이렇게까지 심할 줄은 몰랐어.
#
# (X)(4/2) 집 계약문제 때문에 생각 좀 해봐야 될 거 같애.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(3/3) 이제 면접 마치고 집 가고 있어. 지하철이야.
#
# (O)(3/3) 응. 또 다른 회사 준비해야 할 거 같은데, 너무 힘들다.
#
# (X)(2/3) 이제 이야기해야 될 거 같애.
#
# (O)(3/3) 아니, 아직 못 먹었어. 너무 배고파.
#
# (X)(2/3) 또 상사한테 혼 났어.
#
# (O)(3/3) 어제 밤 새도록 기획안 준비했는데.
#
# (O)(3/3) 그래도 기획안 다시 짜야 돼서 눈치 보여서 못 나갈 거 같애.
#
# (O)(3/3) 눈치보여서 일찍 퇴근은 못할거같애.
#
# (O)(3/3) 나 헤어졌어.
#
# (O)(3/3) 다른 여자가 있었나봐. 그동안 날 속였던 거 같아.
#
# (X)(4/3) 3년 전에 그냥 아는 친구 사이였는데 연인으로 만나게 됐어.
#
# (O)(3/3) 아니. 평소에는 싸운적도 없었는데, 며칠전부터 갑자기 이렇게 일이 생겼어.
#
# (O)(2/2) 룸메이트와 싸웠어.
#
# (O)(2/2) 방을 너무 지저분하게 쓰는 거 있지?
#
# (O)(2/2) 응. 주의를 한 번 줬지. 그런데 하는 거 같더니만 다시 원래대로 지저분하게 쓰고 있어.
#
# (X)(4/2) 응. 고등학교 동창인데, 친한 사이였어.
#
# (X)(4/2) 그러고 싶긴 한데, 집을 또 얻으려면 돈이 있어야하잖아.
#
# (O)(3/3) 나 오늘 면접 또 떨어졌어.
#
# (O)(3/3) 벌써 다섯 번째 떨어진거라. 마지막 대안으로 낸 면접이라. 자신이 없어 이제. 너무 지쳐.
#
# (O)(3/3) 아니. 아직 말씀 못드렸어.
#
# (O)(3/3) 아직 안 먹었어. 밥도 안 넘어 가.
#
# (X)(4/3) 응. 위로해줘서 고마워.
#
# (O)(2/2) 응. 그런데 연락이 안 돼.
#
# (X)(3/2) 아빠가 술 먹고 또 넘어져서 다쳤어.
#
# (X)(3/2) 술 드시고 계단 가시다가 넘어지셨어.
#
# (X)(4/2) 응. 그렇지.
#
# (O)(2/2) 일주일에 다섯 번은 드셔.
#
# (X)(3/2) 해봤는데, 이제는 포기 상태야.
#
# (O)(2/2) 어휴, 회사에서 또 전화왔어.
#
# (O)(2/2) 모르겠어. 일이 너무 많아서 계속 다니기 힘들 것 같아.
#
# (X)(3/2) 다른 데 좀 알아봐야 될 거 같애. 나도 너무 힘들어. 지쳤어.
#
# (O)(2/2) 없어. 그래서 더 스트레스 받는 거 같아.
#
# (O)(0/0) 어제 저녁에 지진이 나서 너무 무서웠어.
#
# (O)(0/0) 아니. 아직도 가슴이 두근두근 거려.
#
# (X)(3/0) 내 친구는 발목을 다쳤고, 다른 사람들도 좀 많이 다친 것 같아.
#
# (X)(4/0) 응, 알겠어.
#
# (O)(6/6) 화장실에 누가 토해놨어. 너무 지저분해!
#
# (O)(6/6) 깜짝 놀랐지! 어휴, 생각만 해도 지저분해!
#
# (X)(4/6) 그래야겠어. 그래야 마음을 진정시키지.
#
# (X)(4/6) 당연히 말해야지. 얼른 전화하자.
#
# (O)(3/3) 지금까지 싸운적이 한번도 없었는데, 얘가 다른 사람 생겼나봐.
#
# (X)(4/3) 친구 소개로 만났어.
#
# (O)(2/2) 룸메이트가 동창인데 방을 더럽게 써.
#
# (X)(4/2) 아니, 한달 전에 주의 한 번만 해봤어.
#
# (O)(2/2) 응. 중학교 동창인데 이렇게까지 더러울줄은 몰랐어.
#
# (O)(3/3) 나 또 면접 떨어졌어.
#
# (X)(4/3) 아직 밖이야.
#
# (X)(4/3) 아니. 아직 모르셔.
#
# (O)(3/3) 나는 잘한 게 없나봐.
#
# (X)(4/3) 응. 근데 다시 해야 돼.
#
# (O)(3/3) 응. 다시 해야돼서 오늘 퇴근 못할 거 같애.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 아니. 부모님도 슬퍼하셔서 나도 집에 가기 싫어.
#
# (X)(4/3) 응. 어제 진행했어.
#
# (O)(2/2) 약속이 있어서 지금 친구 기다리고 있는데 아직도 안왔어.
#
# (O)(2/2) 응. 해봤는데, 항상 늦는 친구니까.
#
# (O)(2/2) 어. 매번 그래.
#
# (O)(2/2) 어, 매번 말하지. 늦지 않게 오라고.
#
# (X)(3/2) 우리 아빠가 또 다쳤어.
#
# (X)(3/2) 술 먹다가 계단에서 넘어져가지구 허리를 다쳤어.
#
# (O)(2/2) 어. 일주일에 5일은 마시는 거 같애.
#
# (X)(3/2) 다 포기 했어. 어쩌지?
#
# (O)(2/2) 아니. 맨날 그만두고 싶어.
#
# (O)(2/2) 아니. 나한테만 계속 일 워가지고.
#
# (O)(0/0) 어 나 어제 저녁에 진짜 무서웠어.
#
# (X)(3/0) 어. 나는 괜찮은데 같이 갔던 친구가 발목을 다쳤어. 식당에 갔는데.
#
# (O)(0/0) 응. 지금은 괜찮은데, 지진이 너무 무서워.
#
# (X)(3/0) 아니. 넘어진 사람들 많더라고. 제 친구도 발목을 다쳐가지고.
#
# (O)(6/6) 으, 누군가가 화장실에서 토하고 안 치웠어.
#
# (O)(6/6) 어. 더러워 죽겠어!
#
# (X)(1/6) 어. 진짜 놀랐어. 다른 층 가봐야겠어.
#
# (X)(4/6) 말씀 드려야 될 거 같애. 빨리 치워달라고.
#
# (O)(3/3) 어제 세상을 떠났어.
#
# (O)(3/3) 어. 갑자기 아프게 되었어.
#
# (O)(3/3) 하 부모님들이 많이 슬퍼하셔.
#
# (O)(2/2) 약속이 있어서 친구 기다리고 있는데, 아직 안 왔어.
#
# (O)(2/2) 한 시간은 넘은 것 같아.
#
# (O)(2/2) 매번 그러네.
#
# (O)(3/3) 아니. 이번이 마지막일지도 몰라.
#
# (O)(3/3) 걱정하시니까 아직 말씀 못드렸어.
#
# (O)(3/3) 먹어야 되는데 입맛이 없네.
#
# (O)(2/2) 약속이 있어서 친구 기다리고 있는데, 아직 안 왔어.
#
# (O)(2/2) 좀 자주 그러긴 하는데 오늘은 심하네.
#
# (X)(3/0) 친구가 조금 다쳤어.
#
# (X)(5/0) 응. 그렇게 할게. 고마워.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 어제 의식을 잃어서 병원에 갔는데 그렇게 됐네.
#
# (O)(3/3) 마음이 너무 허전하고 다들 슬퍼하셔.
#
# (X)(4/3) 응. 지금 준비하고 있어.
#
# (O)(3/3) 나는 잘하는게 없나봐.
#
# (O)(3/3) 응. 상사한테 혼났어.
#
# (O)(3/3) 할 일이 너무 많아서 일찍 퇴근은 힘들 것 같아.
#
# (O)(3/3) 아니. 다 내 잘못일지도 몰라.
#
# (O)(3/3) 아니. 알아보는 중이야.
#
# (O)(3/3) 너무 힘들어서 집에도 못 들어가겠어.
#
# (O)(3/3) 쉴 때도 자꾸 일 생각밖에 안나서 미치겠어.
#
# (X)(2/3) 혼나서 조퇴한다고 말도 못하겠어.
#
# (O)(6/6) 그대로 있을걸? 나도 그냥 나왔거든.
#
# (X)(2/6) 진짜 소리질렀다니까, 놀래서.
#
# (X)(0/6) 좀 진정 좀 해야겠다.
#
# (O)(3/3) 나 또 떨어졌어.
#
# (O)(3/3) 아니. 너무 죄송해서 말 못했어.
#
# (O)(3/3) 입맛도 없다. 어떡하냐.
#
# (O)(0/0) 진짜 무서웠어.
#
# (O)(0/0) 지진 났잖아. 넌 못 느꼈어?
#
# (X)(4/0) 응, 다행히. 난 괜찮아.
#
# (O)(0/0) 그래야지. 근데 진짜 무섭더라.
#
# (O)(2/2) 해도 사과하고 끝이야, 그냥.
#
# (X)(4/2) 응. 지금 그런 방법도 생각하고 있어.
#
# (O)(3/3) 면접 또 떨어졌어.
#
# (X)(4/3) 지, 집 가고 있는 중이야.
#
# (O)(3/3) 응. 근데 이번 건 제일 마지막이었어.
#
# (O)(3/3) 입맛도 없어, 아직.
#
# (O)(3/3) 응, 잘하는게 없나봐.
#
# (X)(2/3) 서류를 만들어서 제출했는데, 상사한테 처음부터 해오라고.
#
# (O)(3/3) 그러고 싶은데 시간이 없어서.
#
# (O)(3/3) 어. 오늘 중에 서류 다시 다 해야돼서.
#
# (O)(2/2) 방을 너무 더럽게 써.
#
# (O)(2/2) 화냈는데 그때는 잘하는 거 같더니 지금 또 더럽게 쓰고 있어.
#
# (X)(4/2) 그래 친구였어.
#
# (O)(3/3) 어제 갑자기 쓰러져가지고 병원에 갔는데.
#
# (O)(3/3) 부모님도 슬퍼하셔.
#
# (O)(3/3) 장례식은 어제 끝났어.
#
# (X)(4/3) 그렇게 믿고 싶어.
#
# (O)(2/2) 지난번에 말했는데 또 늦네요.
#
# (X)(3/2) 아빠가 어제 또 다쳤어.
#
# (X)(3/2) 어. 허리만 다치셨어.
#
# (X)(3/2) 얘기 해 봤는데 다들 포기했어.
#
# (X)(3/2) 힘든 거 같애.
#
# (X)(4/2) 새로운델 알아봐야겠어.
#
# (X)(3/2) 없어. 친한 사람이 없어서.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어.
#
# (O)(0/0) 친구랑 식당에 있었는데 갑자기 지진이 와가지고.
#
# (X)(3/0) 응, 같이 갔던 친구가 다쳤어.
#
# (X)(4/0) 응. 그래야될 거 같애.
#
# (O)(6/6) 그대로 있어서 놀랐어!
#
# (X)(3/6) 응. 다시는 보고 싶지 않아.
#
# (X)(2/6) 기분이 안 좋아서 그래야 될 거 같애.
#
# (X)(2/6) 말해야될 것 같아.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (O)(3/3) 딴 남자가 생긴 거 같아.
#
# (X)(4/3) 원래는 친구였는데, 사귀게 되었어.
#
# (X)(4/3) 두 달 지난 거 같아.
#
# (X)(3/2) 방을 너무 지저분하게 사용해.
#
# (O)(2/2) 화 내 봤는데 말 안 들어!
#
# (X)(4/2) 학교 때부터 친구야.
#
# (O)(2/2) 방 보증금이 없다. 미치겠네!
#
# (O)(3/3) 나는 잘하는게 없나봐.
#
# (X)(2/3) 자꾸 나만 혼내.
#
# (X)(4/3) 그러고 싶다. 근데 할 일이 너무 많아.
#
# (O)(3/3) 오늘도 밤 새야될 거 같아. 에휴.
#
# (O)(6/6) 으 화장실에 누가 토하고 안 치웠어.
#
# (O)(6/6) 응. 아직 그대로 있어.
#
# (X)(1/6) 깜짝 놀랐어!
#
# (X)(2/6) 아무것도 먹기 싫어!
#
# (O)(6/6) 아까전에 말했는데 아직 안 치워줘.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어!
#
# (X)(3/0) 나는 괜찮아. 친구가 발을 다쳤어.
#
# (X)(4/0) 응. 지금은 괜찮은 거 같아.
#
# (X)(3/0) 친구가 발을 다쳤다고!
#
# (X)(4/0) 그래. 알겠다.
#
# (X)(4/0) 응, 대체로 괜찮아. 진짜 대처 요령을 알아둬야 될 거 같아.
#
# (O)(6/6) 으, 화장실에 누가 토하고 안 치웠어!
#
# (X)(2/6) 응. 매너가 꽝이네. 아직도 그대로 있어.
#
# (X)(1/6) 깜짝 놀랬지! 다른 층으로 가봐야겠다.
#
# (X)(4/6) 응. 그래야 될 것 같아.
#
# (X)(3/2) 어제 우리 아빠가 또 다쳤어!
#
# (X)(3/2) 술 드시고 계단에서 넘어지셨어.
#
# (X)(4/2) 허리를 다쳐서 병원에 입원해계셔.
#
# (O)(2/2) 일주일에 5일은 드실걸?
#
# (O)(2/2) 진짜. 퇴근 한지 얼마 됐다고 연락 또 왔어!
#
# (O)(2/2) 맨날 야근해. 매일 그만두고 싶어.
#
# (X)(3/2) 나이가 많아서 이젠 갈데도 없어.
#
# (X)(3/2) 친한 사람이 아무도 없네.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (X)(4/3) 아는 친구 사이었다가 사귀게 됐어.
#
# (O)(3/3) 아니. 우리는 3년동안 한 번도 싸운적이 없어.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (O)(2/2) 약속 있어서 친구 기다리고 있는데 아직 안 왔어.
#
# (O)(2/2) 벌써 한 시간 됐어. 한 시간이 넘었는데 아직도 안 와.
#
# (O)(2/2) 나 지금 약속 한시간 연락도 안돼.
#
# (O)(2/2) 어. 맨날 늦는데 이번에 또 늦는 거야.
#
# (O)(2/2) 아, 말해도 안 들어. 맨날 똑같아 진짜. 아, 짜증나.
#
# (O)(2/2) 야. 나 맨날 늦는 지각쟁이 기다리고 있어, 또.
#
# (O)(2/2) 했는데, 안 받네. 얘 맨날 그래. 습관인가봐.
#
# (O)(6/6) 그럼 치워주시려나?
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (X)(4/3) 권태기지 뭐.
#
# (O)(3/3) 원래 알고 지내던 사이었는데, 만난진 한 3년 됐나?
#
# (O)(3/3) 그런 건 없었는데, 다른 여자 생긴 거 같아.
#
# (O)(2/2) 룸메와 너무 자주 싸워.
#
# (O)(2/2) 또 전화 왔어. 또 일하라고.
#
# (O)(3/3) 그랬을까? 내가 잘 못해준 것만 자꾸 생각 나.
#
# (O)(2/2) 그래, 맨날!
#
# (O)(2/2) 얘기해도 소용없어. 안 고쳐져.
#
# (O)(2/2) 회사에서 자꾸 나한테만 일 시켜!
#
# (O)(2/2) 모르겠어. 계속 일 시켜.
#
# (O)(3/3) 도 얘기 못했는데 나 헤어졌어.
#
# (O)(3/3) 연애를 3년을 했거든? 근데, 권태기가 왔다는거야. 그래서 그러려니 했는데, 그게 아니었던 거 같애.
#
# (O)(0/0) 진짜 어제 엄청 무서웠다.
#
# (O)(3/3) 나 남자친구랑 헤어졌어.
#
# (O)(3/3) 그냥 친하게 지내다가 그렇게 된거였지. 그래도 오랫동안 만났는데.
#
# (O)(3/3) 그런 건 아니고, 권태기라고 말은 했는데, 사실은 그게 아니었던 거지.
#
# (O)(3/3) 좀 됐어. 몇 달 됐는데. 하. 아직도 힘드네.
#
# (O)(2/2) 야. 아 ,걔 또 그래, 또! 아, 내가 진짜 그걸 치우라고 몇번을 얘기했는줄 알아? 아, 근데 걔 치우지도 않아! 치우지도! 다시 그래, 다시! 아, 나 진짜 미치겠네.
#
# (X)(4/3) 한 달 정도 된 거 같아.
#
# (O)(3/3) 우린 그냥 친구 사이였지, 뭐.
#
# (O)(2/2) 룸메랑 너무 자주 싸우게 돼.
#
# (O)(2/2) 안해! 이번에도 음식물 쓰레기 너무 더럽게 버려가지고 짜증냈잖아.
#
# (O)(2/2) 친구 기다리고 있는데 30분 넘게 안 와.
#
# (O)(6/6) 안그래도 말씀드리고 오는 길이야. 빨리 좀 치웠으면 좋겠다.
#
# (X)(3/2) 이야기는 매번 하지. 근데, 너무 친해서 그런지 내 말을 별로 중요하게 생각하지 않아.
#
# (O)(3/3) 새로운 사람이 생긴것 같아. 권태기를 느꼈대.
#
# (X)(4/3) 친구로 지내다가 3년 전부터 연애 감정이 생기기 시작하더라? 그때부터 연인이 된거지.
#
# (X)(4/3) 아니. 3년 간 연애하는 동안 싸운적은 한번도 없었어.
#
# (O)(3/3) 나는 잘 하는게 없나봐.
#
# (O)(3/3) 감기 때문에 힘든데 밤 새워 일했어.
#
# (X)(1/0) 네. 다치지는 않았는데 많이 놀랐지?
#
# (O)(0/0) 너무 무서웠지. 대처 요령을 공부 해둬야 될 거 같애. 같이 있었던 사람들은 크게 다치지는 않았어. 다행이야.
#
# (O)(2/2) 나 친구 기다리는데 아직도 안 왔어. 벌써 한 시간째 기다리고 있는데 전화도 안 받아.
#
# (O)(2/2) 하, 나 요즘에 룸메랑 진짜 많이 싸우고 있어. 스트레스 너무 받아.
#
# (O)(2/2) 당연히 해봤지. 근데 그 때 뿐이야.
#
# (O)(2/2) 응. 고등학교 동창이야. 근데, 이럴 줄 알았냐고.
#
# (X)(3/2) 안그래도 한 달만 다시 참아보고 그냥 안된다 싶으면 따로 살려고.
#
# (O)(3/3) 죄송스러워서 아무 말도 못하겠어. 좀 있다가 봐서 할려고.
#
# (O)(3/3) 아니. 입맛도 없네. 좀 있다 뭐 먹어야지.
#
# (O)(3/3) 또 상사한테 깨졌지 뭐. 되는 게 하나도 없어.
#
# (O)(3/3) 안그래도 감기 때문에 일찍 집에 가려고.
#
# (X)(2/6) 으악, 씨발! 이게 뭐야, 젠장!
#
# (O)(6/6) 아직도 그대로 있어. 진짜 최악이야!
#
# (O)(6/6) 어. 다른 층을 써야긴 써야겠어. 많이 놀랐고, 그리고.
#
# (O)(3/3) 다른 사람이 생긴 거 같아.
#
# (X)(4/3) 친구로 지내다가 만나게 됐어.
#
# (X)(4/3) 아니야. 그런 건 아니야.
#
# (O)(3/3) 이제 얼마 되지 않았어.
#
# (O)(2/2) 한 번씩 주의를 줬는데 안되네.
#
# (X)(4/2) 응. 대학교 동창이야.
#
# (O)(2/2) 안 맞으면 따로 살아야겠지?
#
# (O)(3/3) 일도 못가고 이러고 있어.
#
# (X)(4/3) 공채가 끝나서, 자리가 있을지 모르겠네.
#
# (O)(3/3) 부모님은 모르셔.
#
# (O)(3/3) 나는 잘하는 게 없나봐.
#
# (O)(3/3) 그럴까. 바람이라도 쐴까?
#
# (X)(4/3) 당연히 알고 있지. 그래도 열심히 해야지.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 엄마가 많이 속상해하지. 나도 집에 들어가기 싫고.
#
# (O)(6/6) 으, 누가 화장실에 토하고 안 치운거 있지?
#
# (X)(1/6) 진짜 놀랬어. 엄청 깜짝 놀랬다니까?
#
# (O)(3/3) 그냥 뭐 다른남자가 좋단다.
#
# (X)(4/3) 소개팅 어플에서 만났지. 전에 얘기했잖아.
#
# (O)(3/3) 특별히 그런 것 없었는데. 쯧. 내가 싫어진 건지. 그 남자가 더 좋은 건지.
#
# (O)(2/2) 청소를 안한다니까. 아, 스트레스 쌓인다.
#
# (O)(2/2) 내 봤지. 화도 내 보고, 좋게 얘기도 해보고.
#
# (O)(2/2) 방 같이 쓰면서 알았어. 이번에 처음.
#
# (X)(4/2) 안그래도 그럴까 생각중이야 지금.
#
# (O)(3/3) 또 면접 안됐다. 우야면 좋노. 집에는 뭐라 얘기하노.
#
# (O)(3/3) 그래야지, 뭐. 방법이 있나.
#
# (O)(3/3) 아직 모르는데, 말 몬하겠다.
#
# (O)(3/3) 밥 생각도 없어. 안 먹었다.
#
# (O)(3/3) 안 그래도 담배 한 대 피고 있다, 지금.
#
# (O)(3/3) 지금 퇴근하면 더 이상하지.
#
# (O)(3/3) 쯧. 그것도 잘 모르겠다. 그런 것 같기도 하고 아닌 것 같기도 하고.
#
# (O)(3/3) 우리집 강아지 오늘 묻어주고 왔다.
#
# (O)(3/3) 아니 원래 좀 안 좋았었는데, 오늘 아침에 갑자기 더 심해져서.
#
# (X)(4/3) 아니 그냥 화장했어.
#
# (X)(4/3) 고맙다 그렇게 얘기해줘서. 니밖에 없네.
#
# (O)(2/2) 아니 왜 그렇게 약속을 안 지키는데? 장난 치는 것도 아니고. 한 두번이가 이게.
#
# (O)(2/2) 전화도 안받는다. 인연을 끊든지 해야지 진짜.
#
# (O)(2/2) 어. 한 두 번이 아니다 지금, 이러는게.
#
# (O)(2/2) 해봤지. 한 두 번이 아니니까. 안 바뀐다, 사람이.
#
# (O)(2/2) 우리 아버지 또 사고쳤다. 미치겠다 미치겠어.
#
# (O)(2/2) 말도 못 꺼내게 하는데 무슨 얘기를 하노.
#
# (O)(2/2) 일요일인데도 회사에서 전화가 오노. 뭐 쉬지마란 얘기가.
#
# (X)(3/2) 그럴려고 다른 회사 알아보고 있어, 지금. 안그래도.
#
# (X)(4/2) 그런 사람 있으면 니한테 전화 안했지.
#
# (O)(0/0) 어제 지진 못 느꼈나, 니.
#
# (X)(3/0) 어. 근데 뭐 다치진 않았고. 괜찮다.
#
# (X)(4/0) 어, 사람들도 다 괜찮고. 그냥 다들 놀랐지, 뭐
#
# (O)(6/6) 추웠다 저거. 하. 누가 저랬지.
#
# (O)(6/6) 놀란 건 아닌데, 더러워서.
#
# (X)(4/6) 안 그래도 말해놨다. 청소해 달라고.
#
# (O)(6/6) 더러워 죽겠네. 그지않아?
#
# (O)(6/6) 하냐. 저거 더러워 죽겠다. 그대로 있어.
#
# (O)(6/6) 층으로 가야겠다. 놀라긴. 빨리 가자.
#
# (O)(6/6) 저거 보고 물도 못 마시겠어. 입맛 다 떨어졌어.
#
# (X)(4/3) 그렇게 할려고. 일단 회사에 걸리는, 걸릴 수 있도록 다시 노력할 거야.
#
# (O)(6/6) 관리하시는 분께 말씀드리고 다른 층으로 가자.
#
# (X)(6/2) 너무 더러워서.
#
# (X)(1/0) 괜찮아? 좀 많이 놀랐지. 지금은 좀 어때?
#
# (O)(2/2) 주의를 줬어. 그런데 똑같애.
#
# (X)(4/0) 나는 괜찮아. 그나마 다행이야.
#
# (X)(3/0) 많이 넘어지긴 했는데, 난 괜찮고 옆에 있는 친구는 발목을 좀 다쳤어.
#
# (X)(5/0) 고마워. 다행히 다치진 않아서 정말 다행이야.
#
# (X)(4/0) 너무 걱정 안해도 돼. 나는 괜찮아. 별로 아픈 것도 없고 그냥 좀 놀란 거 뿐이야. 너부터 챙겨.
#
# (O)(2/2) 얼마나 됐다고 회사에서 연락이 또 왔어, 또!
#
# (X)(5/2) 그래, 고맙다. 많이 위로가 됐어. 고마워!
#
# (O)(3/3) 다들 많이 상심이 크셔.
#
# (O)(3/3) 지금 혼자서 밖에 걸어다니고 있지.
#
# (O)(3/3) 아직 말씀 못 드렸어.
#
# (O)(3/3) 밥 맛이 없어서 안 먹으려고.
#
# (O)(6/6) 야야. 화장실 가지 마. 화장실에 누가 토했어.
#
# (O)(6/6) 응. 세면대랑 바닥이랑 난리났어 지금.
#
# (X)(1/6) 아니 놀랐다기보다는 기분이 되게 안좋다. 속이 안좋고.
#
# (X)(4/6) 물 말고, 주스 마실려고.
#
# (X)(4/6) 나 말고 사람들이 엄청 많이 갔으니까 아마 알고 계실 거야.
#
# (X)(1/0) 어제 저녁에 장난 아니었어.
#
# (O)(0/0) 아직 지진이라고 말도 안했는데 어떻게 알았어? 지진이 진짜 세게 왔다니까!
#
# (X)(4/0) 어. 놀란 거 빼고는 몸은 안 다쳤어.
#
# (X)(3/0) 친구 한 명이 다리를 조금 다쳤어.
#
# (O)(2/2) 나 룸메이트랑 싸웠어.
#
# (X)(6/2) 계속 거실을 안 치워. 내가 혼자 다 하고 있어.
#
# (O)(2/2) 어. 화 내봤는데 그냥 애가 개념이 없는 거 같애.
#
# (O)(2/2) 이게 뭐 다니고 싶어서 다니는거니. 돈 주니까 다니는거지.
#
# (X)(4/2) 응. 어차피 이번달까지만 사는 걸로 계약 되어 있어서, 조금만 참으면 돼.
#
# (X)(3/2) 이직할만한 스펙이 돼야 이직을 하지. 일을 너무 많이 시켜서 자기계발할 시간이 없어.
#
# (O)(2/2) 말해봐야 소용없어.
#
# (O)(2/2) 고생이지. 한 30분 기다린 거 같애.
#
# (X)(6/2) 벌써 왔죠! 기대도 안합니다.
#
# (O)(2/2) 진지하게 듣지를 않아.
#
# (O)(3/3) 다른 데 또 준비해야지.
#
# (X)(4/3) 응. 알고 계셔. 그런데 괜찮대.
#
# (X)(4/3) 안 먹었는데, 이제 먹으려고 해.
#
# (X)(4/3) 안그래도 쉴려고.
#
# (O)(3/3) 수 있는데, 그것도 눈치 보이네.
#
# (O)(3/3) 노력 부족이니까 내 잘못이 맞지.
#
# (O)(3/3) 남자친구가 헤어지자고 하더라.
#
# (O)(3/3) 응. 기획안 또 까였어.
#
# (O)(3/3) 두 달이나 됐는데 아직도 마음이 아파.
#
# (O)(2/2) 너무 안치우고 청소도 너무 안하는거야.
#
# (O)(2/2) 대화도 해봤는데 전혀 고쳐지지가 않아.
#
# (X)(0/2) 아, 안그래도 그것 때문에 걱정이야.
#
# (O)(3/3) 장례는 치르진 않았어. 그냥 좋은 곳에 묻어줬어.
#
# (O)(3/3) 하, 나 면접 또 떨어졌어.
#
# (X)(5/3) 고마워. 덕분에 위로가 되네.
#
# (O)(3/3) 가로수길 걷고 있어.
#
# (O)(3/3) 이번이 마지막이라고 생각했는데, 또 준비 해야겠지?
#
# (O)(3/3) 나는 잘하는게 없나봐.
#
# (O)(3/3) 기획안 다시 써야해서 그럴 시간도 없다.
#
# (O)(3/3) 어제도 밤 샜는데 오늘도 일찍가긴 글렀어.
#
# (X)(4/2) 이제 출발한대.
#
# (O)(2/2) 응. 자주 그래.
#
# (X)(4/2) 또 시작하네.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 응. 그래도 회복하면서 좋아지는 것 같았는데, 결국 갔네.
#
# (X)(4/2) 생명에는 지장 없어.
#
# (X)(4/3) 아직. 이제 진행해야지.
#
# (O)(3/3) 고마워. 좋은 곳으로 갔으면 좋겠다.
#
# (O)(2/2) 퇴근한 지 얼마나 됐다고, 회사에서 또 연락 왔어.
#
# (X)(4/2) 그냥 참고 다녀야지.
#
# (X)(4/2) 앞자리 동기랑 이야기하고 있어.
#
# (O)(0/0) 저녁에 진짜 무서웠어.
#
# (O)(0/0) 저녁에 지진이 있었잖아.
#
# (X)(4/0) 다들 무서웠는데 지금은 괜찮아졌어.
#
# (X)(4/0) 다친데는 없어.
#
# (O)(2/2) 어제 또 다쳤어.
#
# (X)(3/2) 계단에서 넘어졌대.
#
# (O)(2/2) 회사에서 또 전화왔어.
#
# (X)(3/2) 옮겨야 하나 고민이야.
#
# (X)(3/2) 내가 너한테 이렇게 얘기 안하지.
#
# (X)(4/6) 알려줘서 고마워.
#
# (X)(5/2) 진짜 고맙다.
#
# (O)(6/6) 누가 토하고 안치웠어.
#
# (O)(2/2) 그런데, 똑같아.
#
# (O)(3/3) 면접 또 떨어졌어.
#
# (O)(3/3) 지금 나는 집에 가는 중이야.
#
# (O)(3/3) 노력했는데 왜 자꾸 결과가 이럴까? 나 너무 속상해.
#
# (O)(3/3) 은 처음에는 친구로 지내다가 3년간 잘 지냈었는데 갑자기 오랫동안 사귀었는지 갑자기 싸우면서 헤어지게 됐어.
#
# (O)(3/3) 응. 3년 동안 사귀고 헤어진 지 얼마 안 됐어. 그 친구한테 다른 여자친구가 생긴 거 같애.
#
# (O)(2/2) 냅두게 되면 다시 지저분해지는거야. 그래서 너무 나만 하니까 화가 나고 지저분하니까 화가 나서 싫어.
#
# (O)(3/3) 난 할 말도 없고 이제 무슨 말을 해야할까?
#
# (O)(3/3) 맨날 안좋은 소식만 전해드리면 속상할 거 같애서 이번에는 말씀 못드렸어.
#
# (X)(6/2) 미정이가 진짜 더러워. 청소를 진짜 하나도 안해.
#
# (X)(4/2) 말은 해봤는데, 소용이 없어. 그냥 내 힘만 상하더라.
#
# (O)(2/2) 원래 고등학교 같은 동창이지. 근데 이럴줄 알았냐고. 진짜 심각해.
#
# (X)(3/2) 안 그래도 진짜 딱 한 달만 더 살아보고 안 되겠다 싶으면 그냥 따로 살자고 하려고.
#
# (X)(4/3) 아니. 밥맛도 없고, 그냥 술만 땡긴다.
#
# (O)(3/3) 응. 가족끼리 간단하게 하기로 했어. 조용히 보내주려고.
#
# (X)(5/3) 응. 고마워. 좋은데로 꼭 갈거야.
#
# (O)(2/2) 약속이 있어서 친구 기다리고 있는데 친구가 아직도 안 오네.
#
# (O)(2/2) 한 시간 기다렸는데 아직도 안 와.
#
# (O)(2/2) 한 백 번은 해봤을걸? 연락이 안 돼.
#
# (O)(2/2) 고등학교 때부터 맨날 이래. 진짜 지겹다.
#
# (O)(2/2) 말 정도가 아니라 맨날 싸우지. 그래도 안돼.
#
# (X)(3/2) 우리 아빠 어제 또 다쳤어.
#
# (O)(2/2) 놀랬지. 술 먹고 또 넘어졌어. 지금은 뭐, 치료 받고 있는 중이셔.
#
# (X)(4/2) 다행히 생명은 멀쩡하셔.
#
# (O)(2/2) 술은 거의 맨날 먹는 거 같애. 근데 가족 말은 전혀 안 들으셔.
#
# (X)(4/2) 엄청 하지. 맨날 잔소리 하고 부탁하고. 근데 안 돼.
#
# (O)(2/2) 진짜 퇴근한지 얼마나 됐다고 또 전화가 왔어, 회사에서.
#
# (O)(2/2) 마음 같아선 진짜 그만두고 싶어. 진짜 힘들다.
#
# (X)(3/2) 뭐, 동기들은 있는데 다들 바쁘니까.
#
# (X)(5/2) 에구, 진짜 고맙다. 말만 들어도 힘이 난다.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어.
#
# (X)(4/0) 응. 어제 식당에서 밥을 먹는데 지진이 났거든. 나는 다치진 않았는데 친구가 발목을 좀 다쳤어.
#
# (O)(0/0) 응. 진짜 놀랬지. 지금은 괜찮긴 한데, 아직도 좀 떨리긴 해.
#
# (O)(0/0) 넘어지는 사람도 있었고, 다친 사람도 있었고. 진짜 대처 요령을 좀 알아둬야겠다.
#
# (X)(4/6) 그래, 그게 좋겠다.
#
# (O)(2/2) 벌써 30분이나 기다리고 있어.
#
# (X)(4/2) 응, 늦게 일어나서 지금 오고 있대.
#
# (O)(2/2) 매번 그래. 진짜. 다음에는 안 만나고 싶어.
#
# (O)(2/2) 난 진지하게 얘기하는데 걔는 맨날.
#
# (O)(2/2) 룸메랑 너무 자주 싸우게 돼.
#
# (O)(3/3) 아니. 전혀 없었어. 그냥 조금씩 너무 서로한테 편안해졌던게 문제가 아니었을까 했는데, 그게 아니라 결국에는 다른 사람이 생겼던 거 같애.
#
# (O)(3/3) 두달 정도 됐는데, 시간이 되게 빨리 가서 그런지 이제야 말하게 됐네.
#
# (X)(4/2) 이직 하는게 나으려나. 근데 이 쪽 업종은 어차피 다 비슷해서.
#
# (X)(4/2) 그래도 뭐, 친구한테 얘기는 하지만, 일이 많은 건 어쩔 수 없네
#
# (O)(2/2) 룸메이트와 너무 자주 싸우게 돼.
#
# (X)(4/2) 그래도 너한테 얘기할 수 있어 다행이다.
#
# (O)(6/6) 들어가자마자 그냥 나와버렸어.
#
# (X)(2/6) 아, 이게 무슨 매너야!
#
# (X)(4/6) 고마워. 그거 마시고 달래야겠다.
#
# (X)(4/6) 관리 하시는 분한테도 말씀드리러 가자.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어!
#
# (X)(3/0) 난 안 다쳤는데 내 친구가 발목을 삐어버렸어.
#
# (X)(4/0) 정리돼서 지금은 괜찮아.
#
# (X)(3/0) 괜찮은데, 다친 애는 아직까지도 아프대.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 따로 내색은 안하는데, 다들 슬프지.
#
# (X)(4/3) 이제 찾아보고 할려고.
#
# (O)(3/3) 고마워. 그래도 마음이 좀 허전하네.
#
# (X)(4/3) 지금 그냥 걸어서 집 가고 있어.
#
# (O)(3/3) 밥 생각도 없네.
#
# (X)(3/2) 우리 아빠 어제 또 다쳤어!
#
# (X)(3/2) 술 먹고 지금 이 병원에 있긴 한데, 허리가 아프대.
#
# (X)(4/2) 일주일에 5일 이상은 먹으니까! 거의 맨날 먹는 거지.
#
# (O)(2/2) 걱정해서 다들 얘기 했는데, 이제 다들 화만 난다.
#
# (O)(3/3) 어제 기획안 열심히 준비했는데 다시 해오래.
#
# (X)(4/3) 잠깐 산책하고 왔어.
#
# (X)(4/3) 걱정해줘서 고마워.
#
# (O)(3/3) 나는 잘하는게 하나도 없나봐.
#
# (X)(4/3) 그게 좋을까? 근데 너무 밤을 새서 그런가 피곤하네.
#
# (O)(2/2) 하. 룸메이트가 너무 지저분해. 같이 못 살겠어.
#
# (O)(2/2) 청소를 안해. 너무 지저분해.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(3/3) 밤새서 기획안 제출했는데 또 제대로 못 했다고 혼났어.
#
# (X)(2/3) 보여서 나가지도 못해. 계속 나만 노려보고 있어.
#
# (X)(3/2) 어제 아빠가 술 드시고 오다가 또 넘어져서 다치셨어.
#
# (O)(2/2) 이젠 놀랍지도 않아. 한 두 번이 아니거든.
#
# (X)(3/0) 나는 안 다쳤는데, 내 친구는 발목을 다쳤어. 다른 사람들도 좀 다쳤고.
#
# (X)(3/0) 친구는 발목을 다쳤고 다른 사람들도 좀 많이 다친 것 같아.
#
# (O)(6/6) 화장실에 누가 토해놨어.
#
# (O)(6/6) 안 치우고 그냥 갔나봐. 아직도 그대로 있어.
#
# (O)(6/6) 생각만 해도 토할 것 같아.
#
# (O)(6/6) 우웩. 화장실에 누가 토했어. 너무 더러워. 절대 가지마.
#
# (O)(6/6) 지금 눈 앞에 토가 가득 있는 거 같애. 머리가 아퍼.
#
# (X)(4/6) 친구들한테도 꼭 이야기해주고, 관리 아저씨에게도 꼭 이야기하도록 하자.
#
# (O)(0/0) 너무 무서워. 놀랬어.
#
# (O)(0/0) 다행히 모두 잘 대처했어. 하지만 그래도 무서웠어.
#
# (O)(2/2) 퇴근한지 한시간만에 다시 일을 주는 직장상사 너무 싫다.
#
# (O)(2/2) 일은 재미 있는데, 너무 많이 시켜. 너무 힘들어.
#
# (X)(5/2) 함께 일하는 동료가 마음이 잘 맞아. 정말 다행이지?
#
# (X)(5/2) 먼저 얘기 해달라고 말해줘서 고마워. 힘이 된다.
#
# (X)(3/2) 아빠가 술 마시고 또 다쳤어. 여러번째야. 너무 힘들다.
#
# (O)(2/2) 병원에 입원했어. 벌써 몇번짼지 모르겠다. 정말, 술이 너무 싫어!
#
# (X)(3/2) 이렇게 계속 다치자, 진짜 죽으면 어떡하지? 걱정돼.
#
# (X)(3/2) 거의 매일 드셔서 건강도 걱정되고, 다치구, 그러니 너무 속상하고 힘들어.
#
# (X)(3/2) 아무리 술을 그만 드시라고 말해도, 아빠가 전혀 듣지 않아.
#
# (O)(2/2) 매번 한 시간씩 약속에 늦는 친구가 정말 미워!
#
# (O)(2/2) 전화도 잘 안 받아.
#
# (O)(2/2) 매번 약속에 늦어!
#
# (O)(3/3) 배고파서 밥 먹으러 왔어.
#
# (O)(3/3) 말씀 못 드렸어.
#
# (O)(3/3) 이렇게 슬픈데 배는 고프다.
#
# (X)(5/3) 좋은 기획안 쓰기 위해 잠시 머리를 식히는 것도 좋은 것 같애. 조언 고마워.
#
# (X)(4/3) 오늘까진 기획안 열심히 쓰고, 내일 쉬려고.
#
# (O)(3/3) 해피를 보고 싶어 해. 너무 그리워 해.
#
# (O)(3/3) 장례는 잘 했어. 걱정에 고마워.
#
# (O)(2/2) 룸메이트가 너무 청소를 안 해. 힘들어.
#
# (O)(2/2) 청소를 안하는줄 몰랐지. 정말, 같이 룸메이트가 된거 후회해.
#
# (O)(2/2) 정말 따로 사는 게 방법일 수 있겠다. 얘기해 봐야겠어.
#
# (O)(3/3) 권태기가 왔다더니 지나고 생각해보니까 다른 여자가 생긴 거 같애.
#
# (O)(3/3) 친구였다가 어떻게 어떻게 사귀게 됐지.
#
# (O)(3/3) 딴 건 없었고 그냥 다른 여자가 생긴 것 같애.
#
# (X)(4/3) 2개월 정도 됐어. 처음 너한테 이야기 하는 거야.
#
# (O)(2/2) 룸메가 청소를 진짜 안해. 진짜 더럽거든.
#
# (O)(2/2) 참다가 한 번 내 봤는데, 그 때 뿐이야.
#
# (X)(3/2) 한달만 더 참아보고 결정할려고.
#
# (O)(3/3) 나 면접 또 떨어졌대. 어떡하지?
#
# (O)(3/3) 또 준비해야하는데 너무 힘들다.
#
# (O)(3/3) 아니 모르셔. 도저히 이야기를 못 하겠어.
#
# (O)(3/3) 입맛이 없어서 밥도 못 먹겠어.
#
# (O)(3/3) 나는 잘하는 게 없나봐.
#
# (O)(3/3) 상사한테 또 혼났어. 진짜 너무 힘들다.
#
# (O)(3/3) 그러고 싶은데 다시 작성해야 돼서 시간이 없어.
#
# (O)(3/3) 안그래도 감기 때문에 일찍 퇴근하려고.
#
# (X)(5/3) 그래. 고마워. 위로 받으니까 훨씬 좋다.
#
# (O)(3/3) 어제 밤에 갑자기 아프더니 좀 나아지는 줄 알았는데, 이렇게 돼버렸어.
#
# (O)(3/3) 엄마가 너무 속상해해. 정말 걱정이야.
#
# (X)(4/3) 가족끼리 간단하게 하려고.
#
# (O)(2/2) 엄청 이야기 많이 해봤어. 근데 그 때 뿐이야.
#
# (O)(2/2) 술 먹고 또 넘어지셨대. 지금은 치료중이야.
#
# (X)(3/2) 생명에 지장은 없으셔. 치료는 받아야 되고.
#
# (O)(2/2) 거의 맨날 드셔. 속상해 죽겠어!
#
# (X)(3/2) 많이 해봤어. 근데 소용이 없네.
#
# (X)(4/2) 안 그래도 요새 여기저기 알아보고 다녀.
#
# (X)(3/2) 털어놓을 사람은 없어. 이렇게 너한테 전화하는 것 밖에는.
#
# (O)(0/0) 어제 저녁에 지인짜 무서웠어.
#
# (O)(0/0) 지금은 괜찮은데 그땐 너무 무서웠어.
#
# (O)(6/6) 으 누가 화장실에 토하고 안치웠어.
#
# (O)(6/6) 따뜻한 물이라도 마셔야겠다, 진짜.
#
# (O)(3/3) 못난 내 자신이 너무 슬퍼.
#
# (O)(3/3) 다 끝내놓고 퇴근하래.
#
# (X)(5/3) 힘이 돼줘서 고마워.
#
# (O)(2/2) 벌써 한 시간 지났어.
#
# (O)(2/2) 매번 약속마다 늦어.
#
# (X)(6/2) 방에 쓰레기를 너무 아무 데나 버려.
#
# (O)(2/2) 한 달 전에 한번 얘기했는데, 고쳐지는가 싶더니 다시 똑같이 행동하더라고.
#
# (O)(2/2) 원래 알던 사이였지. 청소 습관이 안 맞아서 지금 어떻게 해야 될지 고민 중이야.
#
# (O)(2/2) 한 번 더 말해보고, 고쳐지지 않으면 따로 사는 게 방법일 거 같아.
#
# (O)(6/6) 화장실에 누가 토하고 안 치웠어.
#
# (O)(6/6) 어, 그대로 있어!
#
# (O)(3/3) 학교에서 만난 사이었지. 헤어진지 두 달이나 넘었네.
#
# (X)(4/3) 아니. 한 번도 싸운 적은 없었어.
#
# (O)(3/3) 아직 모르셔. 또 떨어져서 말씀드리는게 걱정이야.
#
# (O)(3/3) 아직 안 먹었어. 근데 별로 생각이 없네.
#
# (O)(3/3) 나는 잘하는게 없나봐.
#
# (O)(3/3) 그래야겠다. 나가서 쉬면 좀 나아지겠지.
#
# (O)(3/3) 혼났어서 일찍 퇴근하는 거는 눈치가 좀 보여.
#
# (O)(3/3) 내 잘못이 아니었으면 좋겠어. 아마 아니겠지? 더 열심히 노력할 거야.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 의식이 없길래 병원에 데려갔는데 결국 세상을 떠났어.
#
# (O)(3/3) 갖자고 해가지고. 근데 알고보니 새로운 사람 생겼나봐.
#
# (O)(3/3) 원래 알던 사이였는데, 사귀게 됐지.
#
# (O)(3/3) 두 달 정도 됐는데, 아직도 마음이 아프네.
#
# (X)(4/2) 어. 그것도 생각 해봐야 될 거 같애.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(3/3) 아직 말 못했어.
#
# (O)(3/3) 안 먹었어. 입맛도 없어.
#
# (O)(6/6) 응. 지금도 그대로 있어. 너무 더러워.
#
# (X)(4/3) 응. 그래야될 거 같애.
#
# (X)(3/6) 다른층 써야지 뭐. 많이 놀랐네.
#
# (X)(4/3) 응. 오늘 완성해서 가야될 거 같애.
#
# (O)(3/3) 아니야 내가 잘못해서 그런거야.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 아니 부모님도 힘들어하셔.
#
# (X)(4/3) 아니 아직. 이제 해야 돼.
#
# (O)(2/2) 이제 한 시간 기다린 거 같애.
#
# (O)(2/2) 연락 해봤는데 안 받네.
#
# (X)(4/3) 대학교 입학해서 같은 과에서 만났지.
#
# (X)(3/2) 우리 아빠가 어제 또 다쳤어.
#
# (O)(3/3) 이제 한 두 달 쯤 되어 가는 거 같아. 아무것도 할 수가 없어.
#
# (X)(3/2) 응. 지금 입원해서 치료 중이야.
#
# (O)(2/2) 둘이 같이 살지만, 치우는 건 항상 나고, 내가 부탁하는 것도 실천을 안 해.
#
# (O)(2/2) 퇴근한 지 얼마나 됐다고, 회사에서 또 연락이 왔어.
#
# (X)(3/2) 힘들어 죽을 거 같애.
#
# (O)(2/2) 그렇지. 나만 청소를 하는 거고, 화를 한 두 번 내 봤는데 잘 안 되네.
#
# (X)(3/2) 다른 회사 알아봐야 할 것 같애.
#
# (O)(2/2) 어. 고등학교 동창이야. 학교때는 참 잘맞았는데 말이야.
#
# (X)(3/2) 아니. 동료와 안 친해서.
#
# (X)(5/2) 어, 고마워. 그렇게 말해줘서.
#
# (O)(3/3) 나는 잘하는게 없나봐.
#
# (O)(3/3) 상사한테 기획안이 잘못되었다고 많이 혼났어.
#
# (X)(4/3) 그래 고마워. 잠깐 나가서 커피 한 잔 하면서 좀 쉬어야겠다.
#
# (X)(4/3) 몸이 너무 안 좋아서 조퇴하고 내일 다시 열심히 해볼려고.
#
# (O)(3/3) 그렇게 말해줘서 고마워. 근데 나도 잘못한 부분이 있는 거 같아.
#
# (O)(3/3) 싸우진 않았는데, 음, 여자친구한테 내가 좀 소홀했던 것 같애.
#
# (O)(6/6) 누가 토해놨어. 기숙사에.
#
# (O)(3/3) 힘들다. 그만둬야할까? 어떻게 해야될까. 정말 고민이 많이 되는 거 같애. 어떡하면 좋겠니.
#
# (O)(3/3) 응. 기분 전환 좀 해야되겠어.
#
# (X)(4/3) 아닌 거 같기도 하고. 어떻게든 되겠지.
#
# (O)(3/3) 나 면접 떨어졌어.
#
# (O)(3/3) 집에 가고 있는 길인데, 다섯 번째 면접이었어. 너무 가슴 아프다.
#
# (O)(3/3) 준비 많이 한 면접이었는데 부모님이 실망하실 것 같아. 마음이 아파.
#
# (O)(3/3) 아니. 아직 모르고 계실 거야. 실망하실까봐 걱정이 돼.
#
# (O)(3/3) 아니. 아직 안 먹었어. 입맛도 없고.
#
# (O)(3/3) 나는 잘 하는게 없나봐. 상사한테 또 혼났어.
#
# (O)(3/3) 응. 회사에서 혼났어. 밤 새워서 기획안 작성한건데 마음에 안들었나봐.
#
# (X)(4/3) 응. 그러고 싶어. 기분 전환 하고 싶다.
#
# (O)(3/3) 걱정해줘서 고마워. 오늘도 야근해야 될 거 같아.
#
# (X)(4/3) 그래도 내가 할 일인걸. 고마워 친구야.
#
# (O)(3/3) 응. 갑자기 아프게 된 거야. 응급실에 데려갔잖아.
#
# (O)(3/3) 15년이나 키운 강아지인데 많이 기억에 남을거야.
#
# (O)(2/2) 한 시간이나 기다렸어. 너무 화가 난다.
#
# (O)(2/2) 연락 해봤는데, 잘 받지도 않고, 이 친구가 항상 이렇게 늦는 친구였어. 너무 열 받는다.
#
# (O)(2/2) 자주 늦는 친구야. 이 버릇을 어떻게 고쳐주지?
#
# (O)(3/3) 아무래도 다른 여자가 있는 거 같아.
#
# (X)(4/3) 친구의 소개로 만났지.
#
# (X)(4/3) 싸움은 없었지만 요즘들어 소홀하긴 했었어.
#
# (O)(3/3) 시간을 갖자그래서 나는 그렇게만 생각했지. 그런데 그게 아니더라고.
#
# (O)(3/3) 최근에 헤어진거야.
#
# (O)(2/2) 룸메랑 너무 자주 싸우게 돼.
#
# (X)(6/2) 청소도 안하고 너무 더러워.
#
# (O)(2/2) 한 달 전부터 계속 얘기하는데, 소용이 없어.
#
# (X)(4/2) 고등학교 때부터 알던 사이였어.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(3/3) 지금 돌아가는 길인데 너무 힘들다.
#
# (O)(3/3) 이번 면접이 마지막 시즌일거라. 이제 힘들 거 같아.
#
# (O)(3/3) 걱정하실까봐 말 못 했어. 아직 모르셔.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (O)(3/3) 나는 정말 잘하는게 하나도 없나봐.
#
# (O)(3/3) 응. 기획안을 제출했는데, 다시 해오라는 소리 들었어.
#
# (O)(3/3) 여자친구가 다른 사람 만나고 있었더라고.
#
# (O)(3/3) 다시 작성해야 되는거라 쉬는 시간도 없을 거 같아.
#
# (O)(3/3) 오늘도 밤 새서 다시 해야할 것 같애.
#
# (O)(3/3) 예전에 친구 소개로 만났었는데 결국 이렇게 됐네.
#
# (X)(4/3) 응. 고마워, 위로해줘서.
#
# (O)(0/0) 갑자기 지진이 와가지고.
#
# (O)(3/3) 처음엔 안 그랬는데 시간이 지날수록 좀 그렇게 된 거 같더라구.
#
# (X)(2/0) 어. 지금은 괜찮은데 또 올지 몰라가지고.
#
# (X)(3/0) 그때 식당에 있었는데 같이 있던 친구가 다쳤어.
#
# (X)(5/0) 응. 그럴게. 고마워.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 그저께 아파서 병원에 갔는데, 괜찮아지더니 결국 세상을 떠났어.
#
# (O)(3/3) 엄마도 너무 슬퍼하셔.
#
# (O)(3/3) 아직 안했어. 집에 가면 해피 생각나서 집에도 들어가기 싫어.
#
# (O)(6/6) 어. 그대로 있지, 안 치워서.
#
# (X)(1/6) 어 깜짝 놀랐어.
#
# (O)(2/2) 룸메와 너무 자주 싸우게 돼.
#
# (X)(2/6) 지금 속이 안 좋아.
#
# (O)(6/6) 어. 그래야 될 거 같애. 치워달라고.
#
# (O)(2/2) 너무 청소도 안하고 지저분해.
#
# (O)(2/2) 응. 화도 내보고 했는데 쉽게 안 고쳐지네.
#
# (O)(2/2) 룸메랑 너무 자주 싸우게 돼. 어우 걔는 왜이렇게 지저분한 거야.
#
# (O)(3/3) 결국 헤어졌어.
#
# (O)(3/3) 사람이 생긴 것 같아.
#
# (O)(2/2) 룸메와 너무 자주 싸우게 돼.
#
# (X)(4/0) 넌 어때? 괜찮아?
#
# (X)(3/0) 괜찮아. 너는 어때? 너도 안 다쳤은, 안 다쳤길 바래.
#
# (X)(4/0) 넌 다치지 않았니?
#
# (X)(4/0) 응. 뭔가 대처 요령을 알아둬야 하는게 중요한 거 같애.
#
# (O)(3/3) 더 이상 그녈 만날 수 없어.
#
# (O)(3/3) 그 사람이 더 좋은가봐, 나보다.
#
# (O)(3/3) 만났지. 벌써 10년이 넘었네.
#
# (X)(4/3) 그래도 잘 화해하고 괜찮았었거든.
#
# (O)(3/3) 다른 사람이 있었나봐.
#
# (O)(3/3) 나는 능력이 없나봐.
#
# (O)(3/3) 나 헤어졌어.
#
# (X)(2/3) 친구가 바람 폈어.
#
# (X)(4/3) 선배였어.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(3/3) 집에 못가고 밖에 걸어다녀.
#
# (O)(3/3) 이제 더 지원할데가 없어.
#
# (O)(3/3) 아직 말 못했어.
#
# (O)(3/3) 밥 먹기가 싫어.
#
# (O)(2/2) 아니, 청소를 해야되는데 청소를 안하는거야!
#
# (O)(2/2) 어. 화 내봤어.
#
# (X)(4/2) 응. 원래 고등학교 친구였어.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (O)(3/3) 이별 통보 받았어.
#
# (O)(3/3) 어떡하면 좋을까.
#
# (O)(2/2) 룸메와 너무 자주 싸우게 돼.
#
# (O)(2/2) 친구 만나러 왔는데 30분째 오지를 않아!
#
# (O)(3/3) 너무 슬퍼.
#
# (O)(2/2) 룸메와 너무 자주 싸우게 돼.
#
# (X)(3/2) 어제 우리 아빠가 또 다치셨어.
#
# (O)(6/6) 으, 화장실에 누가 토하고 안 치웠어.
#
# (X)(4/2) 응. 친한 친구였어.
#
# (O)(6/6) 어. 그대로 있어. 아, 정말.
#
# (X)(4/2) 한번 생각해봐야할 것 같아.
#
# (X)(1/6) 진짜 많이 놀랬어.
#
# (X)(1/6) 그래야겠어. 아, 정말 많이 놀랬어.
#
# (X)(4/6) 그러게. 내가 가서 말씀드려야겠어.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (X)(4/3) 집에 가는 길이야.
#
# (O)(2/2) 한시간 넘게 기다렸어.
#
# (O)(2/2) 응. 연락을 해봤는데 얜 항상 이렇게 늦는다니까?
#
# (O)(3/3) 조금 쉬었다가 나중에 다시 하려, 해야지.
#
# (O)(2/2) 응. 처음이 아니라 자주 그래.
#
# (O)(3/3) 아직 말씀 안 드렸어. 어떡하지.
#
# (O)(3/3) 아니 아직. 밥 생각이 없다.
#
# (X)(3/2) 울 아빠가 어제 또 다쳤어.
#
# (X)(3/2) 술 먹고 계단 오르다가 넘어지셨어.
#
# (X)(3/2) 지장은 없으신데, 술을 너무 매일 드셔.
#
# (O)(2/2) 일주일에 다섯번은 드셔.
#
# (O)(2/2) 얘기 해봤는데, 가족 모두 좀 포기했어.
#
# (X)(4/3) 아니. 3년 동안 한 번도 싸운 적이 없었다니까?
#
# (O)(3/3) 한 두달 됐어. 아무한테도 이야기 못했어.
#
# (X)(3/0) 지금은 괜찮은데, 친구가 발목을 다쳤어.
#
# (O)(3/3) 내가 잘못해서 헤어졌어.
#
# (O)(3/3) 나는 잘하는 게 없나봐.
#
# (X)(5/0) 알겠어. 걱정해줘서 고마워.
#
# (O)(3/3) 일찍 가면 좋겠지만 밤 새야겠지?
#
# (X)(3/2) 아니. 회사에 말할 사람들 없어.
#
# (X)(5/2) 응, 알겠어. 고마워.
#
# (O)(3/3) 그런 건 아니었는데, 오래 살긴 했었어.
#
# (O)(6/6) 어! 그대로 있어. 진짜 최악이야!
#
# (O)(3/3) 가족들도 나처럼 많이 슬퍼하고 있어.
#
# (O)(3/3) 응. 이제 해야지 그냥. 조촐하게 할려고.
#
# (X)(1/6) 일단은 그래야 될 것 같애. 진짜 놀랬지?
#
# (X)(4/6) 그래야겠다. 따뜻한 물을 마셔야겠어.
#
# (X)(4/6) 안 그래도 말씀드리려고.
#
# (O)(2/2) 친구 만나기로 했는데 친구 아직까지 안 왔어.
#
# (O)(2/2) 30분이나 됐어.
#
# (O)(2/2) 약속이 있어서 친구 기다리고 있는데 아직 안 왔어.
#
# (O)(2/2) 응. 오고 있다고 하는데, 모르겠어.
#
# (O)(2/2) 벌써 한시간이 넘었어.
#
# (O)(2/2) 응. 약속 있을 때마다 맨날 그래.
#
# (O)(2/2) 한 30분 전에 연락 되고 지금은 연락이 안돼.
#
# (O)(2/2) 이야기해도 미안하다는 말밖에 안 해.
#
# (O)(2/2) 응. 거의 매번 그래.
#
# (X)(3/2) 우리 아빠가 어제 또 다쳤어.
#
# (X)(3/2) 아니, 안 괜찮으셔. 허리 다치셔서 병원에 입원하셨어.
#
# (O)(2/2) 음. 생명에는 지장이 없으신데, 너무 화가 나.
#
# (O)(2/2) 거의 매일 드셔.
#
# (O)(2/2) 퇴근한지 얼마나 됐다고 회사에서 연락 또 왔어.
#
# (O)(2/2) 모르겠어. 정말 너무한 거 같아. 회사에 나밖에 없나.
#
# (X)(3/2) 생각은 수도 없이 해봤지만, 내가 할 수 있는게 또 뭐가 있나 해서.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어.
#
# (O)(3/3) 잘하는게 없나봐.
#
# (O)(0/0) 친구랑 저녁 먹는데 지진 나가지고 너무 무서웠어.
#
# (O)(0/0) 응. 괜찮아. 근데 어제 생각하면 정말 무섭기는 해. 다친 데는 없어, 괜찮아.
#
# (X)(4/3) 아니, 안 괜찮아.
#
# (X)(4/3) 어. 잘 진행했어.
#
# (X)(4/0) 다행히 괜찮아.
#
# (X)(4/3) 힘이 나는 거 같아.
#
# (O)(2/2) 너무 화가 난다.
#
# (O)(6/6) 화장실에 토하고 누가 안 치웠어.
#
# (X)(2/6) 아니, 내가 치웠어.
#
# (O)(3/3) 기획안 때문에 혼났어.
#
# (X)(2/6) 정말 너무한 거 같아. 누가 그랬을까?
#
# (X)(4/0) 다행히 다치지는 않았어.
#
# (X)(5/0) 괜찮아졌어. 고마워.
#
# (X)(3/2) 응. 힘들다. 원래 알던 사이였지.
#
# (X)(3/0) 괜찮은 거 같아. 가벼운 경상 정도야.
#
# (X)(1/0) 근데 너무 놀랐어.
#
# (O)(0/0) 어제 같이 있던 사람들은 괜찮아. 대처 요령을 알아둬야겠어.
#
# (X)(3/2) 회사에서 연락이 왔어.
#
# (O)(2/2) 됐다고 회사에서 또 전화왔어.
#
# (O)(3/3) 어 너무 슬프고 기분이 나빠. 그래서 오늘 소주나 한 잔 할까 해.
#
# (O)(3/3) 혼자서 걷고 있어. 술집에 가려고.
#
# (O)(3/3) 또 기운 내서 또 준비할 거야. 그래도 괜찮겠지?
#
# (X)(4/2) 아직 안 왔어.
#
# (O)(2/2) 시간이나 기다렸어.
#
# (O)(2/2) 전화를 안 받아.
#
# (O)(0/0) 진짜 무서웠어.
#
# (O)(3/3) 내 기획안 거절 당하고 왔어.
#
# (O)(3/3) 그럴 시간이 없을 것 같아.
#
# (O)(3/3) 오늘 헤어졌어, 오늘.
#
# (O)(3/3) 이번에 떨어질줄 알았으면 좀 더 열심히 할걸.
#
# (X)(4/3) 집이지. 술이나 한 잔 해야되겠다.
#
# (X)(3/2) 우리는 항상 싸우게 되는 거 같아.
#
# (X)(6/2) 청소를 안해놓거든. 깨끗하게 살 수 없을까?
#
# (X)(4/3) 알고보니까 남자가 있었어.
#
# (X)(4/3) 친구 소개팅으로 만났어.
#
# (X)(3/2) 우리 아빠 어제 또 다쳤어.
#
# (O)(2/2) 퇴근한지 얼마나 됐다고 회사에서 또 연락이 왔어.
#
# (O)(2/2) 정말 그만두고 싶어. 진짜, 진심.
#
# (X)(3/2) 요즘 많이 알아보고 다니는데 적당한 자리가 없어.
#
# (O)(2/2) 괜찮으셔. 그 정도까지는 아니야. 근데 너무 자주 있는 일이라서 이젠, 정말 화가 나.
#
# (O)(3/3) 나, 결국 헤어졌어.
#
# (O)(3/3) 남자친구에게 다른 여자가 생긴 것 같아.
#
# (O)(3/3) 입맛도 없네. 밥도 싫다.
#
# (O)(3/3) 아 나 면접 또 떨어졌어.
#
# (O)(3/3) 어제 세상을 떠났어. 너무너무 슬프다.
#
# (O)(3/3) 아니. 갑자기 강아지가 의식을 잃었거든.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(2/2) 는데 지금 한시간이 됐는데 아직도 안왔어.
#
# (O)(2/2) 지저분하게 써.
#
# (X)(4/3) 너 어디야?
#
# (X)(4/2) 근데 아직 안왔어.
#
# (O)(2/2) 이번이 두 번째야.
#
# (X)(4/2) 사람 없지. 그래서 너한테 연락한 거야.
#
# (O)(2/2) 너무 오래 기다려갖고 너무 열받어.
#
# (X)(4/2) 연락 안했지.
#
# (O)(2/2) 인제 만나면 이야기 할려고!
#
# (O)(3/3) 면접이 또 떨어졌어.
#
# (O)(3/3) 걔랑 어제 싸우다가 결국 헤어졌어.
#
# (O)(3/3) 걔랑 싸운거 알잖아. 걔도 나한테 질렸나봐. 그래서 그냥 내가 헤어지자고 했어.
#
# (O)(3/3) 힘들어. 다른 회사 또 준비를 할 거야, 나는.
#
# (O)(3/3) 잘 만나고 있었는데 이렇게 돼서 나도 너무 슬프다.
#
# (O)(3/3) 걔랑 나랑은 잘 안맞나봐.
#
# (X)(4/3) 그러고 나 잘 될 거야. 밥은 국밥 먹었어.
#
# (O)(3/3) 어. 하루밖에 안됐는데 너무 힘들다.
#
# (O)(2/2) 자빠져갖고 또 다쳤어!
#
# (X)(3/2) 계시고 근데 좀 있으면 괜찮아지실 거 같애.
#
# (O)(2/2) 청소 좀 하라고 얘기 했는데, 지금 또 음식물 쓰레기 아무데나 버리고 청소는 나 혼자 한단 말이야.
#
# (O)(2/2) 어. 고주망태가 되듯이 먹어. 자주 먹어!
#
# (O)(2/2) 전에 걔한테 경고했거든. 근데 시간 지나니까 또 똑같애. 나만 청소해.
#
# (O)(2/2) 고주망태가 돼서 듣지도 않어.
#
# (X)(6/2) 보증금 없다 그래서 월세만 내고 살라고 했더니 이게 뭐야. 같이 못 살겠다.
#
# (X)(3/2) 어차피 내 집인데 내가 나갈 순 없잖아?
#
# (O)(6/6) 지금 그대로 토가 그대로 있어갖고 냄새가 안좋아.
#
# (X)(4/6) 지금 냄새도 지독해서 다른층 써.
#
# (O)(3/3) 이번 면접도 떨어졌어. 올해만 벌써 다섯 번째야! 나 어떡하냐?
#
# (X)(4/6) 왜 나한테 시키기만 해? 너가 가서 관리하는 사람한테 말하고 와.
#
# (O)(3/3) 공채는 끝났어. 내년에 해보려고.
#
# (O)(3/3) 말 안했어. 집에 가서 얘기 할 건데 아, 도저히 얘기 못하겠다.
#
# (X)(3/0) 밥이 다 쏟아져서 밥도 못 먹고 지금 너무 배고파.
#
# (X)(5/0) 어제는 놀랐는데 지금은 괜찮은거 같아. 고마워.
#
# (X)(4/0) 너무 걱정이 돼. 나도 아프면은 바로 병원 갈테니까 고맙다.
#
# (O)(3/3) 감기 들린 채로 열심히 했는데 너무 속상하다.
#
# (O)(2/2) 지금 또 전화가 와갖고 조상무가 일을 시키는데 이걸 어쩌냐?
#
# (O)(3/3) 밖에 못나가. 집에 가서 푹 쉬어야지. 감기 들려서 추워서 나가지도 못해, 지금.
#
# (X)(4/2) 근데 지금 다 너가 나 먹여 살릴래?
#
# (X)(2/3) 걸렸는데도 기획안 다시 써오라고 하는 사람들인데. 몰래몰래 쉬면서 일할게.
#
# (X)(3/2) 마땅한 회사가 없어서 지금 어디 그만두지도 못해.
#
# (O)(3/3) 밤에 응급실에 갔는데, 결국엔 해피가 세상을 떠났어.
#
# (O)(3/3) 나는 정말 아무것도 할 수 없는 사람인가봐.
#
# (X)(2/3) 또 물어봐. 회사에서 혼났다고.
#
# (O)(3/3) 밥도 잘 먹고, 회복 하다가 어제 밤에 갑자기 또 쓰러졌어.
#
# (X)(4/3) 지금 있으니까 잠시 나가서 쉬고 올게.
#
# (O)(3/3) 그래도 이겨내야지. 너무 슬프긴 하다.
#
# (O)(3/3) 좀 신경을 써야될 거 같애. 그런데, 퇴근은 일찍 못 할 거 같애.
#
# (O)(3/3) 그냥 가족끼리 뒷산에 가서 묻어주고 오려고. 위로 잘 해드릴게.
#
# (O)(3/3) 잘 놀고 있었는데 갑자기 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 근데 다행히 우리 가족은 마음을 추스려서 괜찮으셔.
#
# (O)(3/3) 몸 잘 추스리고, 아직 장례는 못 치뤘어.
#
# (X)(5/3) 붙을 거야. 너도 너무 걱정하지 말고. 힘내자 우리 모두. 화이팅!
#
# (O)(2/2) 넘게 드셔! 가족들이 다 걱정하고 말리는데, 술을 못 끊겠대!
#
# (O)(2/2) 야근하고 집에 왔는데 퇴근한지 얼마나 됐다고 또 회사에서 전화가 왔어.
#
# (O)(2/2) 집에 오면 계속 전화오고 나한테만 일을 다 시키는 거 같애. 이 회사 나 못 다니겠어.
#
# (O)(2/2) 빠서 다른 회사 알아볼 시간도 없어. 너가 좀 소개시켜주라.
#
# (O)(2/2) 정신 없이 일하다가 야근하다가 퇴근하고. 쳇바퀴 같은 삶이야.
#
# (O)(3/3) 점점 싸우고 종종 있었지. 근데 이렇게 될 줄 몰랐네.
#
# (O)(2/2) 룸메랑 끝내고 혼자 살고 싶어.
#
# (O)(2/2) 음식을 시켜 먹고 정리도 안하고, 설거지도 안하고, 집청소도 안하고, 그리고 무엇보다 월세를 안 내.
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# (O)(3/3) 실수한 거 만회해야돼.
#
# (O)(3/3) 일찍 퇴근할 수가 없어.
#
# (O)(3/3) 나이가 좀 있어서 그런 거 같애.
#
# (O)(3/3) 아직은 힘들어하시네.
#
# (O)(3/3) 좋은데로 보내드려야지.
#
# (O)(3/3) 3년 동안 사귄 남자친구랑 결국 헤어졌어.
#
# (O)(2/2) 약속 시간이 지났는데, 친구가 안 오네.
#
# (O)(2/2) 연락을 하는데, 지금 온다고 하는데, 속상하네.
#
# (O)(2/2) 말을 했는데 잘 지켜지지가 않네.
#
# (X)(3/2) 어제 우리 아빠가 또 다치셨어.
#
# (X)(3/2) 술 마시고 넘어지셨어.
#
# (X)(3/2) 지장은 없는데 조금 힘들어하시네.
#
# (X)(4/3) 3년 전에 친구 소개로 만났어.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어. 너 느꼈어?
#
# (O)(2/2) 이야기를 하는데도 잘 안됐네.
#
# (X)(3/0) 응. 나는 괜찮은데 같이 있던 친구는 허둥대다가 발목을 좀 삐었어.
#
# (O)(2/2) 퇴근한 지 얼마나 됐다고, 또 오라고 하는 거야.
#
# (O)(3/3) 헤어진지 두 달 정도 됐는데 아직도 적응이 안돼. 생각만 하면 눈물이 나고 가슴이 아파.
#
# (O)(2/2) 그래두 다녀야지.
#
# (X)(3/2) 요즘 세상엔 갈데가 없어.
#
# (X)(4/2) 응. 회사 동료. 동생도 있고.
#
# (X)(4/2) 그래, 알겠어.
#
# (O)(0/0) 어 정말 무섭더라고 어떻게 해야될지 알고 있었다고 생각했거든? 근데 막상 상황이 되니까 발만 동동 구르고 있게 되더라고. 다른 사람들도 똑같앴어. 정말 무서워하더라니까?
#
# (O)(6/6) 화장실 세면대랑 바닥에 토가 그대로 있어. 너무 더러워.
#
# (O)(0/0) 아직도 진정이 안되고 있어.
#
# (X)(4/0) 조금 다친 거 같아.
#
# (X)(4/6) 속이 안 좋은데 따뜻한 물을 마시면 좀 나아질 거 같아.
#
# (O)(6/6) 응. 아직도 그대로야.
#
# (X)(4/6) 그래야 되겠어. 다른 층을 한 번 가봐야 되겠어.
#
# (X)(4/6) 그러게. 아저씨가 안계시네?
#
# (O)(3/3) 그저께 밤에 갑자기 의식을 잃어서 정신없이 병원에 데려갔는데 그렇게 됐어.
#
# (O)(2/2) 오늘도 야근하고 지금 막 집에 들어와서 쉬려고 하는데 회사에서 새로운 업무를 준다고 전화왔어.
#
# (O)(3/3) 응. 장례 잘 치뤄줬는데, 그래도 모자란 것 같애. 뭔가 더 해줄게 있나 생각 중이야.
#
# (O)(3/3) 정말 허전해 죽겠어. 앞으로 어떻게 살아야 될지 모르겠어. 우리 해피 생각만 나, 자꾸.
#
# (O)(6/6) 아우 더러워. 누가 화장실에 토하고 안치우고 그냥 도망갔어.
#
# (O)(2/2) 다른 사람한텐 안그러는데 나한테만 계속 업무를 많이 주니까 나도 힘들어서 다른 직장으로 옮기고 싶어.
#
# (X)(4/2) 내가 스트레스 받고 힘들 때 너한테 이야기할게. 오늘도 너한테 이야기 하니까 내 마음이 좀 풀린다.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (O)(3/3) 나 결국 이별통보 받았어.
#
# (O)(3/3) 권태기가 왔다고 시간갖자고 하더니 알고보니 새로운 사람이 생긴거였어.
#
# (X)(4/3) 친구처럼 지내다가 사귀게 되었어. 그래서 항상 친구같은 커플이었지.
#
# (O)(3/3) 평소에 싸우거나 마음이 맞지 않는 일은 별로 없었어. 그냥 설레임이 사라졌어.
#
# (X)(2/3) 마음이 아픈 게 아니라 뒤통수 맞은 기분이야. 너무 어이가 없어.
#
# (X)(2/3) 아니. 그렇지 않았으니까 어이없는 거지. 괜찮다가 갑자기 이렇게 헤어지자면 여자 생긴 거 밖에 없지. 그치?
#
# (X)(3/2) 집에서 청소를 안해서 맨날 잔소리를 해서 그런가봐.
#
# (X)(4/2) 어릴 때부터 친구였어. 그래서 처음에 같이 발, 같이 살 때는 괜찮았는데 점점 원래 자기 습관이 나오는 것 같아.
#
# (O)(3/3) 나 오늘 면접에서 또 떨어졌대.
#
# (O)(3/3) 다음 면접은 내년에 있어. 그 전까지는 천천히 준비해야지.
#
# (O)(3/3) 스트레스 받아서 밥맛이 없어.
#
# (X)(2/3) 지금 밖으로 나가서 쉴 분위기가 아니야.
#
# (O)(0/0) 어제 저녁에 정말 무서운 일을 겪었어.
#
# (O)(0/0) 친구랑 식당에서 밥을 먹는데 갑자기 지진이 일어났어! 난 다치진 않았어.
#
# (O)(6/6) 기숙사 화장실에 누가 토해놓고 도망갔어.
#
# (O)(6/6) 응. 그대로 있어. 내가 여기 진짜 오래 살았거든? 근데 이 정도는 처음이야.
#
# (X)(4/6) 그럼 당연하지. 앞으론 이런 일이 없었으면 좋겠어.
#
# (X)(4/6) 이따가 수업 가는 길에 우리가 말씀 드리자.
#
# (X)(3/2) 돈 주는데 다녀야되긴 하는데, 나중에 기회가 되면 이직해야겠어.
#
# (X)(4/2) 아직은 괜찮아. 좀 심해지면 다시 생각해볼게.
#
# (X)(3/2) 아니. 젊은 직원이 별로 없어서 말할 사람이 없어.
#
# (X)(4/0) 지금은 아픈덴 없지만 아프면 병원에 갈게.
#
# (X)(4/2) 그래. 너는 항상 내 편이니까. 항상 고마워.
#
# (O)(3/3) 아니. 다들 슬퍼해.
#
# (X)(4/3) 아니 아직. 내일 할 거 같애.
#
# (O)(3/3) 나도 그렇게 믿고 싶어. 고마워 위로해줘서.
#
# (O)(2/2) 약속이 있어서 친구 기다리고 있는데, 아직도 안 왔어.
#
# (O)(2/2) 한 시간은 넘은 거 같애.
#
# (O)(2/2) 30분 째 때부터 연락하고 있는데 안받아.
#
# (O)(2/2) 어. 지난 번에도 얘기했는데, 안 고쳐져.
#
# (X)(3/2) 우리 아빠가 어제 또 다쳤어.
#
# (X)(3/2) 술 먹다가 계단에서 넘어져가지고 허리를 다쳤어.
#
# (O)(2/2) 어. 거의 맨날 마셔.
#
# (X)(3/2) 했는데도 소용이 없어. 그래서 다들 포기했어.
#
# (O)(2/2) 퇴근한지 얼마나 됐다고 회사에서 또 연락이 왔어.
#
# (X)(3/2) 너무 힘들어. 나만 일하는 거 같애.
#
# (X)(3/2) 이직 하고 싶지. 지금 계속 알아보고 있는데.
#
# (X)(4/2) 없는 거 같애. 동료들 잘 안친해서.
#
# (X)(4/2) 고마워. 그렇게 해야될 거 같애. 위로해줘서 고마워.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어!
#
# (O)(0/0) 갑자기 지진이 나가지고 나는 안 다쳤지.
#
# (O)(0/0) 지금은 괜찮은데 또 언제 날지 모르니까 좀 무서워.
#
# (X)(3/0) 식당에 있었는데 같이 밥 먹던 친구는 발목을 다쳤어.
#
# (O)(0/0) 어. 근데 그때 식당에 있던 사람들이 넘어진 사람도 있어가지고, 좀 무서워.
#
# (O)(6/6) 으. 화장실에서 누가 토하고, 안 치웠어.
#
# (O)(6/6) 응. 그대로 있어. 바닥이랑 세면대에.
#
# (X)(3/6) 응. 근데 그 사람은 괜찮을까?
#
# (X)(2/6) 어. 지금 기분이 안좋아.
#
# (X)(3/6) 응. 그래야 될거 같애. 누가 한 지도 알아봐야 되고. 그 분이 참 걱정된다.
#
# (O)(2/2) 룸메이트와 너무 자주 싸우게 돼.
#
# (X)(3/2) 안그래도 진지하게 고민중이야. 다시 한 번 말해보고 안고쳐지면 따로 살아야 할 것 같아.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(3/3) 지금은 밖이야. 부모님께 죄송해서 집에도 못 가겠어.
#
# (O)(3/3) 다시 준비를 해야하는데 계속 떨어지니까 자신감이 너무 없어.
#
# (O)(3/3) 부모님은 아직 모르시고 있어. 너무 죄송해서 말씀을 못드리겠어.
#
# (O)(3/3) 밥은 아직 안 먹었어. 밥 생각도 없고 아무 생각도 안 들어.
#
# (O)(2/2) 룸메와 자주 싸우게 돼.
#
# (O)(2/2) 룸메가 자꾸 청소를 하나도 안할려고 해.
#
# (O)(2/2) 걔는 화를 내도 달라지는게 없어.
#
# (O)(2/2) 아니야. 지금 같이 살기엔 너무 늦었어.
#
# (O)(0/0) 응. 다치지는 않았는데, 어제 지진이 일어났어.
#
# (O)(0/0) 지금은 괜찮은데 어제는 너무 무서웠다.
#
# (X)(4/0) 응. 같이 있던 사람들도 지금은 다 괜찮아졌어.
#
# (X)(4/0) 걱정해줘서 고마운데 병원 갈 정도는 아니야.
#
# (X)(4/3) 아는 형한테 소개 받아서 만났었는데.
#
# (X)(4/3) 응, 평소에 크고 작은 일로 싸우는 일이 좀 많았었어.
#
# (X)(4/6) 아니야. 따뜻한 물까지 마실 필요는 없을 거 같아.
#
# (O)(2/2) 얜 맨날 그래. 버릇이 안 고쳐져.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (X)(3/2) 술 먹다가 사고나셔서. 지금 병원에 입원해계셔.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (O)(3/3) 남자친구가 권태기인 거 같다고 시간을 좀 갖자고 하더라고. 결국엔 차였어.
#
# (O)(3/3) 아니야. 우린 3년 동안 한번도 싸운적이 없었어. 남자친구한테 다른 여자가 생긴 것 같아.
#
# (O)(3/3) 이제 두달정도 됐어.
#
# (O)(2/2) 룸메랑 너무 자주 싸우게 돼.
#
# (O)(2/2) 아 이친구가 너무 청소를 잘 안해. 지저분하게 방을 써.
#
# (X)(3/2) 룸메이트랑 자주 싸우게 돼서 힘들어.
#
# (X)(3/2) 글쎄. 난 청소만 잘하면 계속 같이 살고 싶거든.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(2/2) 룸메이트가 방을 어지럽히고 청소를 안해!
#
# (O)(3/3) 지금 그냥 밖에서 걷고 있는 중이야.
#
# (O)(2/2) 청소를 하라고 화를 냈더니 며칠 동안은 방청소를 했어. 그런데 요새 또 다시 방을 어지럽히고 음식물 쓰레기를 아무데나 버려.
#
# (O)(3/3) 나는 잘하는 게 없나 봐.
#
# (O)(2/2) 고등학교 때 알던 친구인데 이렇게 방을 지저분하게 쓸줄 몰랐어.
#
# (O)(2/2) 청소 문제 때문에 자꾸 싸우게 돼서 스트레스 받아. 아무래도 따로 사는 게 방법인 거 같아.
#
# (O)(2/2) 친구를 만나기로 해서 기다리고 있는데, 친구가 약속 장소에 아직도 안 왔어.
#
# (O)(2/2) 약속 장소에서 한 시간 넘게 기다렸는데 친구가 안왔어.
#
# (O)(2/2) 친구한테 전화를 했는데 전화를 안받아. 너무 답답해!
#
# (O)(2/2) 만날 때마다 약속시간에 늦어. 너무 화가 나.
#
# (O)(2/2) 화나는 걸 참고 이야기 안했더니 자꾸 약속시간을 어기는 것 같아.
#
# (O)(6/6) 1층 화장실에 누가 토를 해놨어.
#
# (O)(6/6) 아무도 안 치워서 화장실 바닥이랑 세면대에 토가 그대로 있어!
#
# (X)(1/6) 일층 화장실에 갔다가 토가 있어서 엄청 놀랐어.
#
# (O)(6/6) 토를 봐서 속이 안좋은데 따뜻한 물을 마시는게 낫겠다.
#
# (O)(6/6) 속이 좀 나아지면 관리하시는 분께 화장실 좀 치워달라고 말씀드려야?
#
# (O)(0/0) 어제 저녁에 너무 무서웠어!
#
# (O)(3/3) 장례는 진행했는데 집에 있으면 자꾸 해피가 생각나서 집에 못있겠어.
#
# (O)(0/0) 친구랑 식당에서 밥을 먹는데 갑자기 지진일어났어. 나는 다치진 않았어.
#
# (O)(0/0) 아직도 무섭고 놀라서 진정이 안돼.
#
# (O)(2/2) 혼자서 한 시간 기다렸어.
#
# (O)(0/0) 식당에서 밥을 먹던 사람들은 여기저기 넘어져있었어. 그리고 내 친구는 많이 다치진 않았지만 발목을 다쳤어.
#
# (X)(4/0) 다친데는 없지만 아프면 병원 갈게.
#
# (O)(2/2) 야근하고 지금 막 집에 들어와서 쉬려고 누웠는데 회사에서 새로운 업무를 맡게 됐다고 전화왔어.
#
# (X)(3/2) 아빠가 어제 또 다쳤어.
#
# (O)(2/2) 일이 너무 많아서 매일 야근을 하는데 새로운 업무를 계속 주니까 너무 힘들어!
#
# (O)(2/2) 다른 사람한테는 안 그러는데 나한테만 과중한 업무를 주니까 너무 스트레스 받아서 직장을 옮기고 싶어.
#
# (X)(3/2) 회사 안에 내 마음을 털어놓고 말 할 사람이 없어. 그래서 더 힘들어.
#
# (O)(2/2) 속상하기 보다는 이제 화가 나. 술은 일주일에 5일 이상은 드시는 거 같애.
#
# (X)(4/2) 힘들 때 너한테 이야기할게. 이야기 할 사람이 있어서 너무 좋다.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어!
#
# (O)(0/0) 그러니까. 어제 지진이 났을때 사람들이 너무 놀래서 막 우왕좌왕 도망가다가 다른사람들은 넘어지고 내친구는 발목을 다쳤거든. 그런데 그렇게 심하게 다친 것 같지는 않아.
#
# (O)(6/6) 윽 누가 화장실에 토하고 안치웠어.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (X)(4/3) 3년 전에 친구 모임에서 만났지.
#
# (O)(3/3) 두 달 되었어. 하지만 너무 그리워.
#
# (O)(3/3) 나 면접에서 또 떨어졌어.
#
# (O)(3/3) 너무 실망해서 집에 못 들어가고 길을 걷고 있어.
#
# (O)(2/2) 청소를 너무 안해.
#
# (O)(2/2) 화를 낼 때만 잠깐씩 하드라고.
#
# (O)(3/3) 다른 회사 갈 준비를 해야하는데, 자꾸 떨어지니까, 자신이 없어.
#
# (X)(4/2) 그게 좋은 방법일 수도 있겠어.
#
# (O)(3/3) 너무 답답해서 잠깐 밖에 나왔어.
#
# (O)(3/3) 마지막으로 준비했던 회사야. 다른 곳은 인제 없어.
#
# (O)(3/3) 부모님은 내 눈치만 보고 계셔. 가서 말씀 드려야 되겠지.
#
# (O)(3/3) 입맛도 없어.
#
# (O)(3/3) 실망하실 것 같아서 말씀 못드렸어.
#
# (O)(3/3) 나는 잘하는게 없어.
#
# (O)(3/3) 밤새워 준비한 기획안을 또 퇴짜맞았어. 다시 해오래.
#
# (O)(3/3) 너무 지쳐서 입맛이 없어.
#
# (O)(3/3) 쉬는 것도 눈치보여.
#
# (O)(3/3) 기획안이 오늘까지라서 또 밤새야할 거 같아.
#
# (O)(3/3) 내 잘못이지. 잘하는게 하나도 없잖아.
#
# (O)(3/3) 사귀던 남자친구랑 결국 헤어졌어.
#
# (O)(3/3) 우리 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 밥 먹다가 갑자기 쓰러지는 거야. 그러더니 갑작스럽게 죽음을 맞이했어.
#
# (O)(3/3) 엄마가 가장 힘들어하셔.
#
# (O)(3/3) 키우는 동안 우리한테 행복을 줬으니깐 분명 좋은 곳으로 갔겠지?
#
# (O)(3/3) 남자친구는 권태기가 왔다고 잠깐 시간을 가지자고 했어. 근데 새로운 여자친구가 생긴 것 같아.
#
# (X)(4/3) 3년 전에 우리 오빠가 소개시켜 줬어.
#
# (O)(3/3) 평소에 전혀 싸운적이 없었고, 마음이 너무 잘 맞았어. 그래서 이별을 받아들이기가 힘들어.
#
# (O)(3/3) 헤어진지 두 달이 됐는데 아직도 마음이 아파. 너무 힘들어.
#
# (O)(2/2) 친구랑 약속이 있어서 나왔는데 아직도 안오고 있어.
#
# (O)(2/2) 벌써 한시간이 지나고 있어.
#
# (O)(2/2) 연락은 해봤는데 전화를 안 받아.
#
# (X)(6/2) 늦을때마다 이야긴 해봤지. 하지만 또 똑같애졌어.
#
# (X)(3/2) 어제 아빠가 또 다치셨어.
#
# (X)(4/2) 다행히 괜찮으시대. 지금은 퇴원하셨어.
#
# (X)(4/2) 맨날 드시고 오시지.
#
# (X)(3/2) 엄마가 그 일 때문에 매번 화를 내셔. 하지만 고치겠다고 하시고 다시 똑같아.
#
# (O)(3/3) 나 잘하는게 아무것도 없나봐.
#
# (O)(2/2) 퇴근한지 얼마나 됐다고 회사에서 또 연락이 왔어!
#
# (O)(2/2) 내가 만만한 거지. 그러니 그렇게 연락을 계속 하지.
#
# (X)(3/2) 나도 그러고 싶은데 어렵게 들어온 회사잖아. 쉽게 그만둘수가 없어.
#
# (O)(2/2) 다들 바쁘다는 핑계로 내 말을 들어주질 않아.
#
# (X)(4/2) 이야기 들어줘서 정말 고마워.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어!
#
# (O)(3/3) 어제까지 밤을 새고 열심히 기획안을 완성했어. 상사한테 제출했더니, 잘못됐다고 지적하면서 처음부터 다 다시 해오래.
#
# (O)(3/3) 지금 할 일이 많아서 밖에 나가서 쉴 수가 없어.
#
# (O)(0/0) 약속이 있어서 나왔다가 지진이 발생한거야! 나는 다치진 않았어.
#
# (O)(3/3) 잘못된 기획안을 완성하려면 오늘도 야근해야해.
#
# (O)(0/0) 많이 놀라긴 했지. 그리고 지진도 멈추었어.
#
# (O)(3/3) 모든게 나의 잘못 같아서 속상해.
#
# (X)(4/0) 친구가 대피하다가 발목을 조금 삐었어. 하지만 지금은 좋아졌어.
#
# (X)(4/0) 알았어. 몸에 좀 이상 있으면 병원 가봐야 되겠다.
#
# (O)(3/3) 집에서 키우던 강아지 해피가 세상을 떠났어.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 응급실 다녀와서 조금 나아지는 듯 하더니 갑자기 정신을 잃고 세상을 떠났어.
#
# (O)(3/3) 그저께 갑자기 의식을 잃어서 동물 병원 응급실로 데려갔어. 치료를 받으면서 좀 나아졌는데, 결국 세상을 떠났어.
#
# (O)(3/3) 가족들도 너무 슬퍼하고 있어. 나도 지금 너무 슬퍼. 눈물 날 것 같아.
#
# (O)(3/3) 아직 못 했어. 다들 너무 정신이 없어서 이제 천천히 알아봐야지.
#
# (O)(3/3) 해피가 갑자기 세상을 떠나서 부모님이 많이 허전해하시고 슬퍼하셔.
#
# (O)(3/3) 정말 좋은 곳으로 갔으면 좋겠다. 위로해줘서 고마워.
#
# (O)(6/6) 정말 깜짝 놀랬어. 지금도 그대로 있을 거야.
#
# (O)(2/2) 약속이 있어서 친구 기다리고 있는데, 아직 안 왔어.
#
# (O)(6/6) 지금 화장실 안가고 있어.
#
# (O)(3/3) 장례는 가족끼리 잘 치뤘어. 장례를 끝내고 집에 왔는데 해피의 집을 보니 해피가 너무 보고 싶어. 너무 그리워.
#
# (O)(2/2) 한 시간이나 넘게 기다렸어. 저번에도 이러더니 왜 이러는지 모르겠어.
#
# (X)(2/6) 괜찮아. 마음은 진정이 됐어. 지금은 범인을 찾아야 되겠어.
#
# (O)(2/2) 전화해봤는데 전화도 안 받아. 자고 있나봐.
#
# (X)(4/6) 지난 번에도 그 분이 치우셨어. 또 말씀 드릴 수 없지.
#
# (O)(3/3) 항상 나를 반겨주는 해피가 없으니까 너무 슬퍼. 너무 허전해. 우리 해피 좋은 곳으로 가서 잘 살았으면 좋겠어.
#
# (O)(2/2) 조금 자주 그러는 편이야. 매번 말을 했는데도 바뀌지가 않아.
#
# (O)(2/2) 여러 번 했지. 말을 해도 듣는 척도 안 해. 너무 짜증 나.
#
# (O)(6/6) 화장실에 누가 토하고 안 치웠어.
#
# (O)(2/2) 우리 아빠 술 드시고 또 다치셨어.
#
# (O)(6/6) 지금도 그대로 있어. 하나도 안치웠어. 너무 더러워.
#
# (X)(2/6) 깜짝 놀랐어. 사람들이 왜 이렇게 매너가 없을까? 자기가 한 건 직접 치워야지.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (X)(2/6) 마음이 진정이 안돼. 너무 불결하고 너무 짜증나.
#
# (O)(3/3) 권태기가 왔다고 시간을 갖자고 하는거야.
#
# (X)(3/2) 술을 드시고 계단을 오르다가 넘어지셔서 허리를 다치셨대. 그래서 병원에 입원하셨어.
#
# (X)(4/6) 그래야겠어. 내가 지금 가서 말씀 드리고 올게.
#
# (X)(4/3) 친구의 소개로 만났었지. 3년동안 사겼는데.
#
# (O)(2/2) 퇴근한지 얼마나 됐다고 회사에서 또 전화왔어.
#
# (O)(3/3) 평소에는 잘 안싸웠어. 3년동안 한번도 안싸웠다니까.
#
# (O)(2/2) 모르겠어. 너무 스트레스 받아. 회사에 나밖에 없는것도 아닌데, 왜 나한테만 일을 시키는걸까?
#
# (O)(3/3) 두 달 정도 됐는데 마음이 너무 슬퍼서 아무도 못 만나겠어.
#
# (X)(3/2) 생명에 지장은 없는데 허리 치료 때문에 당분간 병원에 계셔야할 것 같아.
#
# (X)(3/2) 안 그래도 진지하게 고민하고 있어. 우선 결정될 때까지는 계속 다녀야지.
#
# (O)(2/2) 회사 사람들은 다 너무 싫어. 너랑 얘기하니까 그나마 조금 낫다.
#
# (O)(2/2) 룸메이트하고 너무 자주 싸우게 돼.
#
# (O)(2/2) 일주일에 다섯 번은 기본이고, 어떤 주는 일주일 내내 드셔!
#
# (X)(4/2) 알겠어. 힘든 일 있으면 너한테 연락할게. 위로해줘서 고마워.
#
# (O)(2/2) 방을 너무 더럽게 쓰는거야. 음식물 쓰레기도 아무데나 버린다니까?
#
# (O)(2/2) 화를 내지. 자꾸 싸우게 되잖아. 한두번도 아니고.
#
# (X)(3/2) 우리 아빠가 어제 또 다쳤어.
#
# (O)(2/2) 고등학교 동창인데 이렇게 더러울거라고는 생각을 못했지. 같이 살아보니까 정말 힘드네.
#
# (X)(3/2) 술 드시고 계단에서 넘어져서 허리를 다쳤어. 지금은 병원에 입원해 있어.
#
# (X)(3/2) 자꾸 술을 드시고 다쳐오셔서 가족들이 걱정이 됐어. 그래서 술을 그만드시라고 말씀드렸더니 아버지는 계속 술을 드시는거야. 그래서 가족들이 포기한 상태야.
#
# (O)(2/2) 정말 그래. 더 이상 같이 살기가 힘들어. 얘기를 해봐야겠어.
#
# (X)(4/2) 그렇게 크게 다친건 아니야. 며칠만 병원에 입원해있으면 된대.
#
# (X)(4/2) 일주일에 5일은 드시니까 엄청나게 자주 드시는 거지.
#
# (O)(3/3) 나 면접에서 또 떨어졌어.
#
# (X)(3/2) 엄청 많이 얘기해봤지. 그래도 술을 못 끊어. 술 없으면 못 사나봐.
#
# (O)(3/3) 길에서 그냥 걷고 있어. 너무 속상해서. 도저히 집에 못들어가겠다.
#
# (O)(3/3) 준비해야지. 해야되는데, 벌써 올해만 다섯번째야! 이렇게 계속 떨어지냐.
#
# (O)(3/3) 아직 얘기를 못 했어. 친구들은 다 취업을 잘하는데 나만 못하니까. 부모님한테 어떻게 얘기해.
#
# (O)(3/3) 속은 허기가 진 거 같은데, 스트레스 때문에 배가 고픈 거 같지도 않아.
#
# (O)(2/2) 룸메와 너무 싸우게 돼.
#
# (O)(3/3) 나는 잘하는게 없나봐.
#
# (O)(3/3) 어제 밤 새서 기획안을 작성해서 상사한테 제출했는데, 다시 해오래.
#
# (X)(4/2) 응. 대학교 같이 다니던 동기야.
#
# (O)(3/3) 혼자 나가기가 힘들어. 감기도 걸렸고.
#
# (X)(3/2) 그러게. 한번 더 얘기해보고 정말 안 괜찮아지면 따로 살아야 되겠어.
#
# (O)(3/3) 말 하기 자신은 없는데, 얘기 해봐야겠어. 몸도 안좋고 정신도 안좋으니까.
#
# (O)(3/3) 고마워. 근데 나는 너무 슬퍼서 내 잘못인 거 같애.
#
# (O)(3/3) 해피가 세상을 떠났어.
#
# (O)(3/3) 어젯밤에 의식을 잃어서 응급실에 데려갔는데 그렇게 됐어.
#
# (O)(3/3) 아직 모르셔. 방금 전화 왔는데 차마 받질 못하겠더라고.
#
# (O)(3/3) 부모님도 많이 슬퍼하셔. 집에 있으면 강아지 생각이 너무 많이 나서, 도저히 들어갈 수가 없어. 15년동안 키웠으니까.
#
# (O)(3/3) 장례를 치뤄야 되는데 어떡해야 되지? 음.
#
# (O)(3/3) 편하게 좋은 곳으로 갔겠지? 응. 힘을 내야되는데 어떡하지.
#
# (O)(3/3) 응. 오늘도 출근하자마자 혼났어.
#
# (O)(2/2) 친구 약속 기다리는데 아직도 안왔어.
#
# (O)(2/2) 한 시간 넘게 기다렸어. 연락 해도 안듣네?
#
# (O)(2/2) 전화를 해도 안 받고, 문자를 해도 답장이 없고. 왜 이러는 거야, 얘는 도대체!
#
# (O)(2/2) 매번 약속에 이래. 안 이런적이 거의 없어.
#
# (X)(3/2) 얘기를 조금씩 하기는 하는데, 고등학교 친구라서 심하게 말은 못하고. 참 얘랑 문제다 문제야.
#
# (X)(5/3) 그렇게 말해줘서 정말 고마워.
#
# (X)(3/2) 우리 아빠가 어제 또 다쳤어.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(2/2) 술 먹고 맨날 넘어져. 병원에 있어.
#
# (O)(2/2) 생명은 지장 없는데 너무 자주 이러니까 가족들이 다 힘들잖아.
#
# (X)(3/2) 응. 너무 자주 먹지. 일주일에 5일은 거의 먹어.
#
# (O)(3/3) 아니. 다들 정말 충격받아서 많이 힘들어하셔.
#
# (O)(2/2) 나도 얘기하고 어머니도 얘기하고 동생도 얘기하는데 아버지가 전혀 말을 안 듣고 혼자 맨날 그래. 가족 다 포기했어.
#
# (O)(2/2) 퇴근한지 얼마나 됐다고 회사에서 연락 또 왔어.
#
# (O)(2/2) 매일 그만 두고 싶은 생각이 들어. 정말 이해할 수가 없어, 이 회사는!
#
# (X)(4/3) 응. 위로해줘서 정말 고마워.
#
# (O)(2/2) 자주 생각하지. 당분간은 여기 있는데, 반드시 옮길거야. 정말 이 회사 싫어!
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어.
#
# (X)(4/2) 다 일을 많이 주는 사람들뿐이야. 옆에 있는 사람도 주고. 다 나한테 일을 많이 줘.
#
# (X)(4/2) 그래. 힘들 때 이모카가 들어줘서 너무 고맙다.
#
# (X)(4/0) 친구랑 저녁먹는데 지진이 일어났어. 나는 다치진 않았는데 친구가 발목을 좀 다쳤네.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어.
#
# (X)(4/0) 넘어지는 사람도 있었는데, 대부분 다치진 않았던 것 같아.
#
# (O)(0/0) 친구랑 밥 먹는데 지진이 난 거야! 나는 안 다쳤지.
#
# (O)(0/0) 너무너무 놀랬어. 내 마음이 쿵쾅거린다니까. 나는 괜찮은데 친구가 다쳤어.
#
# (X)(4/0) 식당에 넘어진 사람들 많이 봤어. 큰 일은 없었어, 다행히.
#
# (X)(4/0) 맞아. 사고 후유증이 위험하다잖아. 항상 조심해야돼.
#
# (O)(2/2) 약속이 있어서 친구 기다리고 있는데 아직 안왔어.
#
# (O)(6/6) 으, 화장실에 누가 토하고 안치웠어.
#
# (X)(4/2) 한 시간은 기다린 것 같아. 해 뜰 때 왔는데, 이제 해가 중천이야.
#
# (O)(6/6) 응. 정말 최악이야. 경비 아저씨한테 얘기했으니까 누군가 치우겠지?
#
# (O)(2/2) 응. 연락도 여러번 해봤는데 한 번도 안 받았어.
#
# (X)(2/6) 놀랬지! 들어갔는데, 그런 게 막 있으니까.
#
# (O)(2/2) 응. 얘는 자주 이래. 연락을 해도 항상 안받아.
#
# (X)(4/6) 얘기해야지. 이런 일이 다시는 발생하지 않아야 해.
#
# (O)(2/2) 아직 얘기해 본적은 없어. 오늘은 반드시 얘기하려고.
#
# (O)(3/3) 오늘로 이를째야. 오늘 헤어졌어. 그런데 되게 오래된 거 같아.
#
# (O)(2/2) 아, 룸메와 너무 자주 싸우게 돼. 매 거즘 매일매일 싸우는 거 같아.
#
# (X)(4/2) 다른 건 없어. 청소문제로 자주 부딪치게 돼.
#
# (O)(6/6) 화장실에 누가 토를 했어.
#
# (O)(2/2) 청소는 나만 한다고 봐야 돼. 화도 내 봤지. 자꾸 이런식으로 가다보면은 서로 사이가 안 좋아질 거 같아서.
#
# (X)(4/2) 고등학교 때부터 알고 지내던 정말 친한 친구야. 조금씩 신경 써주면 서로 편할텐데. 그렇지?
#
# (X)(2/6) 아마도 그렇겠지. 사람들도 진짜 너무하다. 어떻게 자기껄 안치우고 그냥 갈수가 있지?
#
# (O)(6/6) 어. 장난 아니야. 우와, 지금 생각만 해도 끔찍하다.
#
# (X)(2/6) 그치. 아니, 자기가 그렇게 했으면 누구라도 불러서 좀 치워달라고 해야되는 거 아니야?
#
# (X)(4/6) 안 그래도 보자마자 관리인한테 말하고 왔어. 도저히 못 보겠다고.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어.
#
# (O)(0/0) 응. 난 다치진 않았는데 어떻게 지진이 이렇게 자주 일어나지?
#
# (O)(0/0) 지금 괜찮아. 또 이런 일이 일어날까 봐 너무 무섭다.
#
# (O)(2/2) 퇴근한지 얼마나 됐다고 회사에서 또 호출이야.
#
# (X)(4/0) 응. 아프면 병원에 가볼게. 근데 나는 지진이 일어나자마자 탁자 밑으로 들어갔거든. 그래서 괜찮았던 거 같아.
#
# ...
#
# (O)(3/3) 우리 해피는 귀여워서 하늘에서 사랑 받을거야.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (O)(3/3) 마음이 변한거지 뭐. 슬프다.
#
# (O)(3/3) 알바하다가 만났어. 추억이 많아서 더 힘들어.
#
# (X)(4/3) 항상 나를 이해해줘서 싸울 일이 한 번도 없었어.
#
# (O)(3/3) 두달이나 지났는데 아직도 매일 보고싶어.
#
# (O)(3/3) 나 헤어졌어.
#
# (O)(3/3) 갑자기 시간을 갖자고 하더니 아무래도 다른 여자가 생긴 거 같더라고.
#
# (X)(4/3) 예전에 같이 일하던 사람이었어.
#
# (X)(4/3) 아니 전혀. 3년동안 한번도 싸운 적이 없었어.
#
# (O)(3/3) 이제 두 달 됐어.
#
# (O)(2/2) 아, 나 요새 룸메랑 맨날 싸우는 거 같아.
#
# (O)(2/2) 청소를 안 해. 엄청 지저분해.
#
# (O)(2/2) 얼마전에 내가 엄청 크게 화냈었거든. 그때는 미안하다면서 좀 치우더니, 얼마 안갔어.
#
# (X)(4/2) 10년도 넘었지. 고등학교 동창이거든.
#
# (X)(0/2) 아 그거 빼고는 괜찮은데 진짜 어떡해야될 지 모르겠다.
#
# (O)(3/3) 아, 나 마지막 면접까지 다 떨어졌어.
#
# (O)(3/3) 그냥 걷고 있었어. 너무 답답해서.
#
# (O)(3/3) 아, 해야되는데 진짜 너무 힘들다.
#
# (O)(3/3) 아니. 나 요새 면접 보는 것도 말씀 안 드렸어. 계속 떨어지는데 이걸 말씀드리기가 좀 그렇더라고.
#
# (O)(3/3) 입맛이 없어. 밥먹기 싫다.
#
# (O)(3/3) 내가 잘하는 게 있기는 한 걸까?
#
# (O)(3/3) 나 진짜 열심히 밤새가면서 기획안 작성했거든. 아 근데 다 다시해오래.
#
# (O)(3/3) 아, 지금 감기기운 있어서 찬바람 쐬면 더 안좋아질 것 같아.
#
# (O)(3/3) 어, 오늘은 야근해야지. 기획안 다시 내야되는데.
#
# (O)(3/3) 헤어진 지는 벌써 두 달이나 됐어. 늦게 얘기한 거야.
#
# (O)(3/3) 아니. 가족들도 지금 너무 슬퍼하고 있어.
#
# (O)(3/3) 병원에서 추천해준 절차대로 했는데 그래도 마음이 편하지가 않아.
#
# (O)(3/3) 그래. 그래도 15년이면 오래 살았으니까 마음 추스리려고.
#
# (X)(6/2) 연락을 해봤는데, 늦잠 잤다고 하니까 뭐라고 할 말이 없네. 지금 오는 중이래.
#
# (X)(4/2) 자주 약속시간때마다 잠수를 타는 친구야. 그래서 맨날 청개구리라고 놀리는데 이게 잘 안고치나봐.
#
# (O)(2/2) 한 달 전에 진지하게 약속 시간은 지키자고 벌금 같은 거 만들겠다고 했는데도, 지금 이러는 거야.
#
# (O)(3/3) 벌써 쉬고 왔지. 근데 그것도 오래 있으면 눈치 보여서 금방 들어왔어. 빨리 일 해야 돼.
#
# (X)(4/3) 그래. 열심히 노력하다 보면 나도 언젠가는 멋진 시니어가 될 수 있을 거야. 그치?
#
# (O)(2/2) 한 달 전에 진짜 심각하게 이러지 말자고 했는데, 말로는 고친다고 했어 분명히.
#
# (O)(2/2) 고등학교 때부터 엄청 친했어. 그래서 모르는 사람 보다는 나을 거라고 생각했는데, 규칙이 너무 없다, 지금.
#
# (X)(3/2) 아직 계약을 한 지가 얼마 안돼서 그렇게 쉽게 나가라고 할 수는 없어. 지금 자취방 구하기 어렵단 말이야.
#
# (X)(3/2) 계단에서 허리를 삐끗하셨대. 지금은 병원에 입원했어.
#
# (X)(3/2) 안 먹는 날을 생각하는 게 더 빠를 거야. 항상 술을 드시고 집에 와.
#
# (X)(3/2) 가족 회의 때 자주 술을 먹지 말자고 말하는데, 아빠가 그 말을 듣질 않으셔. 다들 포기했어.
#
# (X)(3/2) 나 아직 신입사원이야. 어떻게 이직을 하겠어.
#
# (X)(3/2) 그래, 고마워. 회사 안에 털어놓을 수 있는 사람이 없었어. 나는 참 외롭다.
#
# (X)(4/2) 그래 그럴게. 너는 항상 내 편이니까.
#
# (O)(0/0) 그렇게 갑자기 지진이 오면 행동 지침을 지킬 수가 없어. 그냥 피하기 바빠. 내 친구도 피하다가 발목을 다쳤어.
#
# (X)(4/0) 그래. 아픈 곳이 생기면 병원에 갈게.
#
# (X)(4/6) 아니야. 지금은 뭘 먹으면 안돼. 그냥 점심 때 뭐 먹을래.
#
# (X)(4/6) 안 그래도 관리하는 분한테 내가 이따가 말씀 드릴 거야.
#
# (O)(3/3) 싸우지는 않았는데, 권태기였나봐. 헤어지게 됐어.
#
# (O)(3/3) 우리는 소개로 만났었지. 다른 사람이 생겼었나 봐.
#
# (O)(3/3) 평소에 싸우진 않았어. 잘 맞는 것도 그렇게 많지 않았고. 다른 사람이 생겼나봐.
#
# (O)(2/2) 지난 번에도 화를 냈었는데, 그 때는 괜찮아지나 싶더니 다시 그러는 거 있지?
#
# (O)(2/2) 고등학교 동창이었어. 그 때는 이렇게 더러운지 몰랐지.
#
# (X)(3/2) 다시 한번 이야기를 해봐야될것 같아.
#
# (O)(3/3) 집에 가고 있는 길인데 너무 마음이 우울하다.
#
# (X)(4/3) 면접시즌 마지막이라 기대를 많이 했거든. 준비하려면 또 오래 걸릴거야.
#
# (O)(3/3) 입맛도 없고, 밥 먹을 생각이 없다. 아.
#
# (O)(3/3) 감기도 걸리고 밤새서 기획한 기획안이었어. 근데 잘못된 거를 말하면서 혼나니까 할말은 없더라.
#
# (O)(3/3) 기획안을 수정해야 돼서 아마 야근해야 될 거 같아.
#
# (X)(4/3) 그래. 차근히 다시 해봐야지.
#
# (O)(3/3) 갑자기 의식을 잃어서 응급실에 갔는데, 괜찮아지더니 갑자기 세상을 떠났어.
#
# (O)(3/3) 이제 준비하려고. 마음이 많이 허전하다.
#
# (O)(2/2) 연락도 되지 않아. 이렇게 늦는 거 고쳐줘야 되는데.
#
# (O)(2/2) 예전에도 이렇게 늦는 버릇이 있었어. 근데 아직도 못 고쳤네.
#
# (O)(2/2) 많이 다그치고도 했는데 고쳐지지가 않나봐.
#
# (X)(3/2) 우리 아버지, 어제 또 다쳤어.
#
# (O)(2/2) 일주일에 5일은 드시는 것 같아. 매일 그러고 드시는게 너무 화가 나.
#
# (O)(2/2) 다들 포기한 상태야. 자꾸 그러시니까 말하기도 싫어.
#
# (X)(4/2) 나도 그렇게 생각해. 이직을 좀 생각 많이 해봐야겠어.
#
# (X)(3/2) 다들 아마 나랑 비슷한 생각일거야. 바빠서 이야기도 잘 못하고.
#
# (X)(4/2) 그래. 내 얘기 들어줘서 고마워. 이야기 할게.
#
# (X)(3/0) 나는 다치진 않았어. 근데 같이 갔던 친구가 발목을 다쳤거든.
#
# (O)(0/0) 주변에서 다치는 걸 봤어. 너무 무섭더라.
#
# (X)(1/0) 그래야겠어. 좀 많이 놀랬거든.
#
# (O)(6/6) 정말 최악이야. 지금도 그대로 있을걸?
#
# (O)(6/6) 공용 화장실인데 왜 이렇게 더럽게 쓰는지 모르겠어.
#
# (O)(6/6) 속이 너무 안좋아. 얼른 다른데로 옮겨야겠어.
#
# (X)(4/6) 그래 맞아. 관리하시는 분한테 이야기하고 좀 개선해야 될 거 같아.
#
# (X)(4/3) 남자친구가 권태기가 왔다고 잠깐 시간을 갖재.
#
# (X)(4/3) 3년 전에 친구 소개로 만났어.
#
# (O)(3/3) 아니야. 우린 3년동안 한 번도 싸운적이 없었어. 아마 남자친구한테 다른 사람이 생긴 거 같아.
#
# (X)(4/3) 이제 두 달 정도 되어가는 거 같아.
#
# (O)(2/2) 룸메랑 너무 자주 싸우게 돼.
#
# (O)(2/2) 청소를 너무 잘 안 해. 방이 너무 지저분하게 써.
#
# (O)(2/2) 한달전에 주의를 주었지. 근데 그때는 조금 치우는가 싶더니 다시 또 안치우는 습관이 나오고 있어.
#
# (O)(2/2) 고등학교 동창이야. 근데 이렇게까지 지저분할 줄 몰랐어.
#
# (X)(4/2) 아 나는 같이 살고 싶은데 좋은 방법이 없을까?
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(3/3) 결과 듣고 지금 밖에 걸어가고 있는 중이야.
#
# (O)(3/3) 이게 공채 시즌 마지막이라 희망을 걸고 있었던 거거든. 다른 회사는 아직 생각도 안하고 있었어.
#
# (O)(3/3) 아직 말씀 못드렸어. 죄송스러워서 집에도 못 가겠어.
#
# (O)(3/3) 밥 생각도 없다.
#
# (O)(3/3) 나는 잘하는 게 없나봐.
#
# (O)(3/3) 응. 어제 나 감기 걸려서 엄청 힘들었잖아. 근데 밤새서 기획안 제출했는데 상사가 처음부터 다시 하래.
#
# (O)(3/3) 다 틀린 말은 아니지만, 그래도 너무 힘들어. 지금 이거 하려면 시간이 없을 거 같아.
#
# (O)(3/3) 어제 너무 잠을 못 자서 오늘은 조금 일찍 퇴근해서 집에서 할까봐.
#
# (X)(5/3) 고마워. 다시 힘내서 열심히 할게.
#
# (O)(3/3) 해피가 세상을 떠났어.
#
# (O)(3/3) 부모님도 많이 슬퍼하고 계셔.
#
# (O)(3/3) 어제 바로 했는데, 집에 있으면 자꾸 해피가 생각 나서 집에 못 들어가겠어.
#
# (O)(3/3) 마음이 너무 허전해. 분명 좋은 곳으로 갔을거야. 나도 그렇게 믿어.
#
# (O)(2/2) 약속이 있어서 친구 기다리는데, 아직 안 왔어.
#
# (O)(2/2) 지금 혼자서 한시간 넘게 기다리고 있어.
#
# (O)(2/2) 연락 계속 하고 있는데 연락이 안돼.
#
# (O)(2/2) 약속 있을 때마다 늦어.
#
# (O)(2/2) 얘기는 많이 했지. 그러면 그 때마다 미안하다고 얘기하고, 다음부터 늦지 않겠다고 하는데. 만날 때는 이렇게 연락이 안 돼.
#
# (X)(3/2) 우리 아빠가 어제 또 다쳤어!
#
# (X)(3/2) 술 마시고 집에 오다가 계단에서 넘어지셔서 허리를 다치셨대. 지금은 병원 입원치료 중이야.
#
# (O)(2/2) 생명에는 지장은 없는데, 지금 계속 술 달라고 난리야.
#
# (O)(3/3) 나 면접에서 오늘 또 떨어졌어.
#
# (O)(2/2) 일주일에 5일은 드시나 봐.
#
# (O)(3/3) 지금 집에 가는 길인데 들어가서 부모님한테 말씀드릴 용기가 안난다.
#
# (O)(2/2) 그럼. 얼마나 많이 했는데. 처음에는 걱정 돼서 맨날맨날 얘기했는데, 이제는 고쳐지지 않으니까 너무 화가 나. 이제는 우리 모두 포기한 상태야.
#
# (O)(3/3) 회사가 뭐, 엄청 많은 것도 아니고. 다음 면접은 내년이나 되야될 것 같아.
#
# (O)(2/2) 퇴근한지 얼마나 됐다고 회사에서 또 전화가 왔어.
#
# (O)(3/3) 부모님한테 뭐라고 말씀드려야 될지 모르겠어. 너라면 어떻게 하겠니.
#
# (O)(2/2) 모르겠어. 왜 나한테만 이렇게 업무를 많이 주는지 정말 이해가 되지 않아. 아, 그만두고 싶다.
#
# (O)(3/3) 밥 보다는 술이 마시고 싶은데, 지금 술 마시면 너무 안 좋을 것 같아.
#
# (X)(3/2) 매일 그만두고 싶지. 근데 이직이 그렇게 마음처럼 쉽지 않잖아.
#
# (O)(2/2) 아니. 이야기 할 사람이 없어. 그래서 매일 너한테 전화하잖아.
#
# (O)(3/3) 우리집 해피가 어제 갑자기 세상을 떠났어.
#
# (X)(5/2) 알겠어, 고마워. 또 전화할게.
#
# (O)(3/3) 갑자기 아프게 된 건 아니고 원래 좀 나이가 많아서 약했는데 어젯밤에 정신을 잃고 쓰러졌어.
#
# (O)(3/3) 가족들도 지금 너무 놀래서 서로 말이 없어.
#
# (O)(3/3) 응. 좋은 곳에 잘 묻어두고 왔어. 그래도 마음이 편하지 않네.
#
# (O)(0/0) 나 어제 진짜 무서웠어.
#
# (X)(4/3) 그랬겠지? 해피는 좋은 일을 많이 했으니까 아마 좋은 곳으로 갔을거야.
#
# (O)(0/0) 아니 친구랑 어제 식당에서 밥을 먹는데 지진이 일어난 거야! 다행히 나는 다치지는 않았어.
#
# (X)(1/0) 어제 엄청 놀랬지. 지금도 조금 가슴이 두근두근해.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (X)(3/0) 같이 밥 먹던 친구가 발목을 조금 다쳤는데 지금은 조금 괜찮은 거 같아.
#
# (X)(2/3) 권태기가 왔다고 변명하더니 새로운 남자 만나고 있더라고. 너무 화가 났지만, 그냥 모른척 했어.
#
# (X)(4/0) 응 알겠어. 그렇게 할게.
#
# (X)(4/3) 친한 오빠 동생 사이로 시작했는데, 같이 술 먹고 놀다 보니까 엄청 친해서 사귀자고 말 했었지.
#
# (X)(2/3) 그런 일은 하나도 없었어. 그냥 새로운 남자가 좋았나봐. 너무 어이없지?
#
# (O)(3/3) 벌써 헤어지자고 한지가 두 달이나 됐네. 근데 난 새로운 사람을 만날 생각을 못하고 있어.
#
# (O)(6/6) 누가 화장실에 토하고 안 치웠어.
#
# (O)(2/2) 약속 있어서 친구 기다리는데 친구 놈이 아직도 안왔다.
#
# (O)(6/6) 아마 그대로 있을거야. 내가 보고 다른층 쓰고서 바로 온거거든.
#
# (X)(6/2) 벌써 한 30분도 넘었어. 근데 여기가 어디 들어가서 기다릴 데가 없어서 내가 너무 짜증이 나. 카페라도 있으면 갈 텐데.
#
# (O)(6/6) 놀란 것 보다 아, 너무 지저분해서 진짜 기분이 꽝이야.
#
# (X)(6/2) 미안하다면서 와서 밥 사겠다고 그러는데, 밥 안사도 되니까 제시간에 왔으면 좋겠다니까?
#
# (O)(6/6) 아, 물 좀 마실까봐 정말. 근데 진짜 왜 그렇게 지저분하게 쓰는거지?
#
# (O)(2/2) 거의 항상 그래. 그래서 원래 쟤는 늦게 오는구나 생각하고 기다리는 건데 오늘은 너무 늦잖아. 그러니까 내가 화가 나지.
#
# (O)(2/2) 만날 때마다 한번씩 얘기하고 한달 전에도 얘기했었고. 근데 고칠 생각이 없는거 같애. 나도 이제 그냥 늦게 나올 거야.
#
# (O)(2/2) 룸메이트하고 너무 자주 싸우게 된다. 너무 힘들어.
#
# (O)(2/2) 맞아. 엄청 불편해. 자주 싸우는 이유는 그 친구가 청소를 전혀 안해! 나는 정말 이렇게 더러운 사람인지 몰랐다니까?
#
# (O)(2/2) 화를 내도 그 때만 항상 치우고 며칠 지나면 다시 원래대로 돌아가. 그게 뭐야. 내가 엄마도 아니고.
#
# (X)(6/2) 원래 어릴 때 기숙사에서 같이살던 고등학교 친군데 이제 성인이 되고나서까지 같이 살아보니까 얘가 나이가 들어도 청소를 안하더라고. 어떻게 이럴수가 있지?
#
# (O)(2/2) 진짜 친구만 아니면 벌써 나가라그랬어. 근데 얘가 사정이 있어서 같이 사는거라서 내가 방법을 좀 찾아봐야 될 거 같아.
#
# (O)(3/3) 나는 정말 잘하는게 없나봐.
#
# (O)(3/3) 밤 새서 기획안을 제출했는데 상사가 보자마자 말도 안된다고 했어.
#
# (O)(3/3) 쉬고 싶은데 마음이 너무 무겁다. 지금 빨리 수정해서 다시 보내드려야 돼.
#
# (O)(3/3) 안그래도 어제 밤 새서 퇴근은 일찍 할거야. 근데 진짜 걱정이 많이 돼.
#
# (X)(4/3) 그래. 조금 더 수정하면 상사도 좀 마음에 들어하겠지? 다시 한 번 해봐야겠다.
#
# (X)(3/2) 우리 아빠가 어제 또 다쳤어.
#
# (X)(3/2) 정말 많이 놀랐지. 근데 또 술 먹고 다쳤다는 소식 들으니까 화가 더 많이 났어. 지금은 허리를 다치셔서 병원에 계셔.
#
# (X)(4/2) 응. 다행히도 크게 다치신 건 아니라서, 그냥 병원 조금 다니시면 된대. 근데 지금은 놀라셔서 잠깐 입원하신 거야.
#
# (O)(2/2) 진짜 매일 드셔. 나는 술 저렇게 먹으라고 해도 못 먹을 거 같애. 근데 가족 회의에서 얘기를 해도 안 고치니까! 우리 가족은 다 포기 상태야.
#
# (O)(2/2) 한 달 전에도 했었고 정말 자주 하는데, 우리 아빠는 고집이 너무 세다니까?
#
# (O)(2/2) 나 회사에서 퇴근한 지 얼마 안 됐는데, 회사에서 일하라고 또 연락 왔다.
#
# (O)(2/2) 그러니까. 아니 밤에 일을 시키면 그걸 어떻게 하라는 거야. 내일 얘기하면 되잖아. 나 퇴근했는데 왜 얘기해?
#
# (X)(4/2) 그래. 여기선 딱 2년만 버티고 나도 복지가 좋은 회사로 이직할거야.
#
# (X)(3/2) 아니. 내가 공채로 들어간 것도 아니고 어떻게 있겠어. 다들 자기 일 아니면 다행이다, 이게 다지 뭐.
#
# (X)(4/2) 그래. 너한테라도 얘기 할 수 있어서 정말 다행이다.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어!
#
# (O)(0/0) 지진이 왔다니까! 밥을 먹고 있는데, 갑자기 땅이 다 흔들렸어.
#
# (X)(4/0) 응. 다행히도 다치지도 않았고 지금은 뭐 지진이 안 오니까 잘 집에 돌아왔지.
#
# (O)(0/0) 그러니까. 우리나라는 지진 안 오는 줄 알았는데. 아니 무슨 서울에 지진이 와? 내 친구는 발목도 다쳤어.
#
# (X)(4/0) 그래. 병원이 뭐 먼 것도 아니고. 어디 아프면 바로 갈게.
#
# (O)(6/6) 우리 층 기숙사 화장실에 누가 토하고 도망갔어.
#
# (O)(6/6) 지금 그대로 있어서 엄청 냄새나고 더러워.
#
# (X)(2/6) 어. 아침부터 나는 졸린데 씻으러 간거거든. 근데 입구부터 그렇게 돼있더라고. 진짜 나 밟을 뻔 했어.
#
# (X)(4/6) 그래. 아침부터 놀랬는데 따뜻한 물 한잔이라도 해야겠다.
#
# (X)(4/6) 안 그래도 나보다 먼저 발견한 학생이 가서 말했나 보더라고. 관리하시는 분이 벌써 알고 계셔.
#
# (O)(3/3) 아니야. 나 진짜 일 못하나봐. 선배가 하나하나 집어서 얘기해주는데 틀린 말 하나도 없더라. 나 진짜 어떡해야되냐.
#
# (O)(3/3) 우리 해피 어제 죽었어.
#
# (O)(3/3) 그저께 갑자기 애가 의식이 없어서 응급실 데려갔었거든. 근데 어제는 밥도 먹고 기운차리나 싶었는데 그게 마지막 모습 우리한테 잘보여주고 싶어서 그랬나 봐.
#
# (O)(3/3) 아니, 다들 밥도 잘 못 먹고, 기운도 없어.
#
# (X)(4/3) 아직. 지금 알아보는 중이야.
#
# (O)(3/3) 아직 실감이 안나. 집에 가면 해피가 달려나올 것 같아.
#
# (O)(2/2) 아 나 밖에서 친구 기다리는데 안와.
#
# (O)(2/2) 지금 한 시간도 넘었어.
#
# (O)(2/2) 연락이 안 돼. 아 그래서 가지도 못하고 지금 계속 기다리는 중이야.
#
# (O)(2/2) 어. 맨날 늦어. 일찍 온 적이 없어.
#
# (O)(2/2) 뭐 크게 얘기한 적은 없었어. 근데 너무 당연하게 늦으니까 나도 짜증나.
#
# (O)(2/2) 아 우리아빠 또 다치셨어.
#
# (X)(3/2) 술 드시고 들어오시다가 취해서 계단에서 넘어지시면서 허리 다치셨어.
#
# (X)(4/2) 지금 병원에 입원 중이신데, 며칠 치료 받으면 된대.
#
# (O)(2/2) 어 맨날 드셔. 하 우리 아빠 중독인가 봐.
#
# (O)(2/2) 한 두 번 한게 아니야. 맨날 다치고 들어오시니까 너무 걱정돼서. 근데 아빠가 들어야 말이지. 이제는 다 포기했어.
#
# (O)(2/2) 아! 우리 회사 진짜 미쳤나봐. 아 퇴근한 지 얼마나 됐다고, 또 전화야!
#
# (X)(6/2) 어, 그만두고 싶어. 지들이 할 수 있는 일을 왜 다 나한테 미뤄?
#
# (X)(3/2) 지금 고민 중이야. 하. 도저히 버티기가 힘들 거 같다.
#
# (X)(3/2) 없어. 회사에 친한 사람 하나도 없어.
#
# (X)(4/2) 그래. 너라도 들어주니까 진짜 다행이다.
#
# (X)(2/0) 나 어제 진짜 죽는 줄 알았어!
#
# (O)(0/0) 어제 식당에서 친구랑 밥 먹는데 지진 난거야. 와, 막 흔들리는데 진짜 딱 죽겠더라.
#
# (X)(1/0) 어 지금 많이 괜찮아졌어. 아 어제는 진짜 너무 놀랬어.
#
# (X)(4/0) 어. 다들 막 우르르 뛰어가니까, 막 서로 엉키고 난리도 아니었어. 내 친구는 그래서 발목 다쳤잖아.
#
# (O)(0/0) 어. 그래야지. 아. 생각하면 너무 무서워.
#
# (O)(6/6) 아, 씨! 화장실에 누가 토 해놨어!
#
# (O)(6/6) 어, 조금도 아니야. 완전 많아!
#
# (O)(6/6) 으. 나도 속 안 좋아. 아침부터 이게 뭐야.
#
# (X)(2/6) 그래야겠다. 아, 나 진짜 사람들 이해 안돼. 본인이 한건 본인이 좀 치우지!
#
# (X)(2/6) 어. 나가면서 말씀 드리려고.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (O)(3/3) 권태기가 왔다며 잠깐 시간을 갖자더니 다른 남자가 있더라고.
#
# (X)(4/3) 대학교 동창이었어. 재밌게 만났었는데.
#
# (O)(3/3) 아니야. 3년 만나면서 싸운 날도 없었거든. 그 정도로 잘 만났는데 너무 충격이야.
#
# (X)(2/3) 두달쯤 됐는데 다른 사람 만나고 싶은 생각도 없고 배신감에 너무 화가 난다.
#
# (O)(2/2) 요즘 룸메랑 너무 자주 싸우게 돼.
#
# (O)(2/2) 아, 룸메가 정리정돈을 너무 안 해. 옷도 막 이리저리 벌려놓고.
#
# (X)(4/2) 어, 한달 전쯤에 보다보다 못해서 한 번 크게 얘기하긴 했어.
#
# (X)(4/2) 고등학교 동창인데, 같은 대학교 오면서 같이 살기 시작했지.
#
# (X)(6/2) 그러게. 아, 요즘, 그 때 얘기하고 다시 또 음식물도 막 버리고, 아무 데나 버리고. 그게 좋은 방법이긴 한데, 의 상할까봐.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (X)(4/3) 지금 집 근처 공원이야. 좀 걷고 있어.
#
# (O)(3/3) 이게 마지막 회사였으니까. 다음 시즌 공채 준비해야지, 뭐. 방법이 없다.
#
# (O)(3/3) 어떻게 부모님한테 말할 수 있겠어. 떨어졌는데. 합격 소식이면 모를까.
#
# (O)(3/3) 아니, 밥 안 먹었는데 밥 생각 없다, 야.
#
# (O)(3/3) 아 난 정말 잘하는게 없나봐.
#
# (O)(3/3) 어, 어제 밤 새서 기획안 만들어 제출했는데, 너무 지적을 많이 받아서 너무 속상하다.
#
# (X)(4/3) 안그래도 잠깐 나와서 차한잔 하면서 너한테 전화하는 거야.
#
# (O)(3/3) 그러게. 어제도 감기기운 있는데 밤샌거라. 나도 지금 너무 피곤한데, 이거 마무리 해야 퇴근할 수 있을 거 같애.
#
# (O)(3/3) 아니야. 내 잘못인거 같애. 내가 더 잘했으면 이런 일 없었을텐데.
#
# (O)(3/3) 그저께 갑자기 의식을 잃어서 병원에 데려갔는데, 밥도 먹고 나아지는 듯 싶더니 결국 어제.
#
# (O)(3/3) 어, 지금 묻어주고 그러고 들어오는 길이야. 아, 집에 있으니까 또 해피 생각 난다.
#
# (X)(4/3) 그래. 우리 해피 좋은 곳 갔을거야. 고마워.
#
# (O)(2/2) 약속 있어서 친구 기다리고 있는데 친구가 너무 안온다.
#
# (O)(2/2) 벌써 한시간도 더 된 거 같애. 한시간 반?
#
# (O)(2/2) 어. 연락해봤는데 연락이 잘 안돼. 자기도 미안한거겠지.
#
# (O)(2/2) 고등학교 동창인데 약속마다 이래. 자기도 매번 그러면 고칠만도 한데 말이야.
#
# (X)(4/2) 안그래도 오늘 오면 제대로 얘기해볼려고. 아, 이제는 인내심이 바닥을 드러낸다.
#
# (X)(3/2) 우리 아빠 어제 또 다치셨어.
#
# (X)(3/2) 어제 친구들이랑 술 먹고 들어오시다가 계단에서 구르셨나 봐. 지금 허리 많이 다치셔서 병원에 입원해있어.
#
# (X)(4/2) 어, 다행히도. 근데 재활치료다 뭐다 되게 오래 치료하셔야 될 거 같애.
#
# (X)(3/2) 거의 매일 드시지. 일주일에 5일은 드시는 거 같애. 거의 일주일이지, 뭐.
#
# (O)(2/2) 저녁마다 반주 드시니까, 그때마다 엄마가 얘기하시지. 근데 이제 우리들도 포기야. 말을 안들으셔서.
#
# (O)(2/2) 그러니까 말이야. 나 안그래도 야근하고 있는데 회사에 사람도 많은데 왜 꼭 나한테 일을 맡기는지 모르겠어.
#
# (X)(3/2) 아. 그러고 싶은데 날 받아줄 회사가 있을까?
#
# (X)(4/2) 동기들이지 뭐. 동기들 빼고 누구한테 얘기하겠어, 상사들한테 얘기할 것도 아니고.
#
# (X)(4/2) 그래. 지금처럼 들어줘서 고마워. 너 땜에 속이 좀 풀리는 거 같애.
#
# (O)(0/0) 어제 저녁에 정말 무서웠어.
#
# (O)(0/0) 어제 저녁에 밥 먹는데 지진이 와서 너무 놀랐어.
#
# (X)(4/0) 어. 지금은 괜찮아. 어제 일이니까.
#
# (X)(3/0) 어제 식당에 있던 사람들 많이 넘어지고, 내 친구는 발목도 다쳤어.
#
# (X)(3/0) 그럴까봐. 내 친구 병원가는데 같이 가기로 했는데 나도 검사 좀 받아봐야겠어.
#
# (O)(6/6) 으, 누가 화장실에 토하고 안 치웠어.
#
# (O)(6/6) 아, 지금은 잘 모르겠어. 보자마자 바로 나와버렸거든.
#
# (O)(6/6) 어. 누가 토하고 그걸 치우질 않냐. 아, 너무하네.
#
# (O)(6/6) 어, 좀 있다가. 지금은 못 마실 것 같애. 아, 조금 아직도 역하다.
#
# (X)(4/6) 그러게. 나 지금 나가야 되니까 나가면서 말씀 드리고 가야겠다.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (O)(3/3) 다른 여자가 생겼대. 나쁜 놈.
#
# (O)(3/3) 같은 학원에서 만났어. 나 좋다고 할 땐 언제고.
#
# (O)(3/3) 아니야. 항상 나한테 다 맞춰줬어.
#
# (O)(3/3) 두달 지났는데 연락하고 싶어.
#
# (O)(3/3) 해피가 어제 세상을 떠났어.
#
# (O)(3/3) 평소에 조금 아프긴 ?는데 갑자기 떠날줄은 몰랐어.
#
# (O)(3/3) 우리 가족 모두 힘들어 해.
#
# (O)(3/3) 장례는 내일 할 예정이야. 엄마가 걱정이야.
#
# (O)(3/3) 집안이 텅 빈 것 같아. 해피가 보고 싶어.
#
# (O)(2/2) 룸메와 너무 자주 싸우게 돼.
#
# (O)(2/2) 청소를 안 해. 음식물 쓰레기를 아무데나 버려!
#
# (O)(2/2) 화 내면 조금 치우고 나중에 또 그래.
#
# (X)(6/2) 고등학교 동창인데 깨끗한줄 알았어.
#
# (O)(2/2) 오늘 다시 진지하게 얘기해봐야겠어. 더 이상 못 참겠어.
#
# (X)(3/2) 우리 아빠 어제 또 다쳤어.
#
# (O)(2/2) 술 먹고 계단에서 굴렀대. 어이없어.
#
# (X)(3/2) 허리 다치셨어. 지금 못 움직이셔.
#
# (X)(3/2) 많이 드셔. 끊어야 할텐데 걱정이야.
#
# (O)(2/2) 독불 장군이야. 말 안 들어.
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어!
#
# (O)(0/0) 너도 지진 느꼈어? 완전 공포였어.
#
# (O)(0/0) 아직도 심장이 두근두근 거려.
#
# (X)(5/0) 친구가 발목을 조금 다쳤는데, 크게 다치진 않아서 다행이야.
#
# (X)(3/0) 난 병원 갈 정도는 아니야. 괜찮아.
#
# (O)(2/2) 약속 있어서 친구 기다리고 있는데 아직도 안왔어!
#
# (O)(2/2) 한시간 넘게 기다렸어. 춥고 배고파.
#
# (O)(2/2) 전화를 안 받아. 그냥 갈까 말까 고민 중이야.
#
# (O)(2/2) 한 번도 약속 시간에 맞춰서 나온적이 없어!
#
# (O)(2/2) 다신 안그런다면서 매번 똑같아.
#
# (O)(6/6) 화장실에 누가 토하고 안치웠어!
#
# (O)(6/6) 그대로 있어. 자기가 치워야 되는 거 아니야?
#
# (O)(6/6) 생각만 해도 너무 더러워.
#
# (O)(6/6) 정말 양심이 없는 것 같아! 아, 물 좀 마셔야겠어.
#
# (X)(4/6) 관리 아저씨께 말씀 드렸어. 치우실 거야.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (O)(3/3) 벤치에 그냥 앉아 있어. 집에 갈 힘도 없어.
#
# (O)(3/3) 내가 갈 회사가 있을까? 자신 없어.
#
# (O)(3/3) 부모님께 말씀 드리기 겁 나. 많이 속상하실 텐데.
#
# (O)(3/3) 아무것도 먹고싶지 않아.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (X)(2/3) 요새 말 수가 줄어들더니 권태기가 왔다고 그랬다? 근데 알고보니 새로운 남자가 생긴 거였어. 어이없지?
#
# (X)(4/3) 그냥 친하게 지내던 오빠동생 사이였는데 어쩌다 보니까 사귀게 됐어.
#
# (O)(3/3) 아니. 서로 잘 이해를 해줬으니까 그런 일은 별로 없었는데. 내가 보기에 새로운 사람이 정말 좋은가봐.
#
# (O)(3/3) 그러고보니 벌써 두달이나 지났네. 시간 참 빠르다.
#
# (O)(2/2) 룸메이트하고 너무 자주 싸우게 된다.
#
# (X)(6/2) 방 청소 안하는 거 때문이지 뭐. 맨날 자기 방에 쓰레기 널부러놓고 그냥 자고. 빨래도 하나도 안하고.
#
# (X)(6/2) 화를 내면 뭐해. 자기는 청소 이렇게 많이 안 해도 된다고, 그냥 자기 거 신경 쓰지 말라는데. 냄새 나서 어떻게 그래.
#
# (X)(4/2) 고등학교 때부터 친하게 지내던 사이라서 원래는 편하게 잘 지낼 줄 알았지.
#
# (O)(2/2) 그러려면 그 친구가 바뀌거나, 내가 더러워지거나 해야 되는데 그게 안 되니까. 계약 종료되면 따로 살아야겠어.
#
# (O)(3/3) 해피가 어제 세상을 떠났어. 우리 집 강아지 말이야.
#
# (O)(3/3) 나이가 많아서 항상 걱정했는데 결국 어젯밤에 의식을 잃어버렸어. 그리고 병원에 갔지만 그냥 떠나버렸네.
#
# (X)(6/3) 괜찮을 리가 없잖아. 다들 너무 충격적이고 강아지가 자꾸 생각 난다고 하셔.
#
# (O)(3/3) 응. 장례는 진행했어. 양지바른 곳에 잘 묻어두고 왔지. 그래도 마음이 편하지 않더라.
#
# (X)(4/3) 그래. 꼭 좋은 곳으로 갔을 거라고 나도 믿고 있어. 고마워.
#
# (O)(2/2) 약속 있어서 친구 기다리는데 너무 늦는다.
#
# (O)(2/2) 벌써 30분이나 지났어. 이게 뭐 하는 걸까, 너무 짜증난다.
#
# (O)(2/2) 연락은 엄청 잘 돼. 왜 늦는지 이유도 엄청 다양하고. 근데 아무튼 늦은 건 계속 늦잖아. 너무 싫어.
#
# (O)(2/2) 이 친구는 정말 자주 이래. 그래서 원래는 맨날 이걸로 놀렸는데 그래도 안 고치더라? 아무 상관 없나봐. 놀림 받아도 계속 그럴건가봐.
#
# (X)(6/2) 늦을 때마다 그러지 말라고 말 하는데 소용이 없었어. 맨날 놀려도 자기는 괜찮대.
#
# (O)(6/6) 으 화장실에 누가 토하고 도망갔어.
#
# (O)(6/6) 지금도 변기통에 그대로 엄청 있지. 이걸 누가 치우겠어.
#
# (O)(6/6) 맞아. 많이 놀랬어. 아침부터 깜짝 놀랬다니까. 아니 왜 변기 물을 내리지도 않고 그냥 갔대?
#
# (X)(2/6) 아니야. 지금은 물 마셔도 진정이 안 될 것 같아. 범인을 진짜 잡고 싶다.
#
# (X)(2/6) 들어오는 길에 벌써 들러서 말씀 드리고 왔어. 엄청 화 많이 나셨더라고.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (X)(2/3) 지금 그냥 회사 근처야. 어떻게 면접을 보자마자 몇시간만에 떨어뜨릴 수가 있니.
#
# (O)(3/3) 면접 이번에 본게 마지막 기회였어. 다음 면접은 내년에 있어.
#
# (O)(3/3) 아니. 염치없어서 아직 말씀 못드렸어. 집에가서 말 해야지.
#
# (X)(4/3) 응. 밥은 먹었어. 간단하게 삼각김밥 같은 거 먹고 그냥 집에 가서 잘려고.
#
# (O)(2/2) 퇴근한지 한시간도 안됐는데 회사에서 또 일을 줬어. 어떻게 이럴수가 있지?
#
# (O)(2/2) 돈 주는데 다녀야지 그러면 어떡해.
#
# (O)(2/2) 내가 이직이 쉬우면 벌써 했지. 이직 하려면 최소 2년은 다녀야 돼.
#
# (O)(2/2) 회사 동기한테 자주 얘기하는데, 뭐 서로 도움이 되는 건 아니고.
#
# (O)(2/2) 얘기하면, 너가 뭐 해결해줄거야?
#
# (O)(0/0) 어제 저녁에 진짜 무서웠어.
#
# (O)(0/0) 다치진 않았는데 큰 지진이 왔다니까 우리 동네에?
#
# (X)(4/0) 응. 지금은 다들 수습하고 정상으로 돌아갔어.
#
# (X)(4/0) 친구가 떨어지는 물건을 피하다가 발목을 조금 다쳤어.
#
# (X)(4/0) 그래. 나도 아프면 병원에 가야겠어. 생각보다 다친 사람들이 많대.
#
# (O)(2/2) 우리 아빠가 어제 술 먹고 또 다쳤어!
#
# (X)(3/2) 계단에서 허리를 삐끗하셨대. 지금은 병원에 계시고. 하, 진짜 왜 그러는지 모르겠다.
#
# (X)(4/2) 응. 다행히도 생명에는 지장이 없으시대.
#
# (X)(4/2) 일주일에 주말 빼고 5일은 드시는 것 같아.
#
# (O)(2/2) 가족 회의 때마다 금주하기를 목표로 세우는데 일주일도 안가서 자꾸 술을 다시 마시셔. 나는 이제 포기했어.
#
# (O)(3/3) 나는 잘하는게 없나봐.
#
# (O)(3/3) 이번에 기획안을 제출할 수 있는 기회가 있었는데, 제출 하자마자 엄청 욕 먹었어.
#
# (X)(4/3) 그래. 밖에 나가서 커피 한 잔이라도 하고 와야겠다.
#
# (X)(2/3) 일도 못하는데 어떻게 칼퇴를 해. 눈치 봐야지.
#
# (X)(4/3) 그래. 열심히 노력하면 다음에는 성공할 수 있을거야. 걱정해줘서 고마워.
#
# (O)(3/3) 나 면접 또 떨어졌어.
#
# (X)(4/3) 아, 집 앞 공원이야. 좀 걷고 있어. 머리도 식힐 겸.
#
# (O)(3/3) 어. 여기가 마지막 희망이었거든. 아 다른 친구는 다 붙는데, 나만 떨어진 거 같아서 속상하다.
#
# (O)(3/3) 아, 부끄러워서 어떻게 부모님한테 말씀드려. 그냥 조용히 넘어가려고.
#
# (O)(3/3) 아니 밥 생각 없어. 조금 이렇게 걷다가 다음 시즌 준비해야지.
#
# (O)(2/2) 아, 어제 아빠가 또 다치셨어.
#
# (X)(4/2) 아, 친구들이랑 술 드시고 계단 올라오시다가 허리를 삐끗하신 모양이야.
#
# (X)(3/2) 일단은. 일단은 입원해서 치료 받으셔야 한대. 끝나면 통원 치료도 하셔야되고.
#
# (X)(4/2) 한 일주일에 다섯번은 드시는 거 같애. 친구들이 워낙 술을 좋아하셔서.
#
# (X)(3/2) 그 문제 때문에 부모님이 많이 다투시지. 아 근데 이제 포기야 포기. 거의 뭐 말을 안들으시니까.
#
# (O)(3/3) 나 결국 헤어졌어.
#
# (X)(2/3) 얼마 전부터 권태기 왔다며 잠깐 시간을 갖자더니, 다른 남자랑 놀아났지 뭐야?
#
# (X)(4/3) 입사 동기였어.
#
# (O)(3/3) 아니야. 3년 만났는데 전혀 싸운적도 없고 너무 잘 만났었거든. 근데 이렇게 되니까 너무 충격이다.
#
# (X)(2/3) 이제 두달 넘어가. 근데 그 때 생각만 하면 너무 화가 나고 잊혀지지가 않는다.
#
# (O)(2/2) 아, 요즘 룸메랑 너무 자주 싸우게 돼.
#
# (O)(2/2) 아, 룸메가 방을 너무 지저분하게 써. 음식물도 막 버리고.
#
# (O)(2/2) 뭐 화를 낸 것까진 아니지만, 한 달 전 쯤에 좀 확실하게 얘기를 해뒀거든. 근데 요즘 들어서 다시 좀.
#
# (O)(2/2) 어. 고등학교 동창인데, 같은 동네 오게 돼서 같이 룸메로 살게 됐지.
#
# (X)(4/2) 그게 확실한 방법이겠지?

# %% [markdown]
# #F1 score

# %%
with open('pred.csv', 'w') as f:
  for d in p:
    f.write('%d,' % (d))
len(p)
# Out:
# 14606

# %%
with open('label.csv', 'w') as f:
  for d in y:
    f.write('%d,' % (d))
len(y)
# Out:
# 14606

# %%
p
# Out:
# [4,
#  3,
#  2,
#  3,
#  3,
#  4,
#  2,
#  4,
#  4,
#  3,
#  2,
#  3,
#  3,
#  0,
#  3,
#  2,
#  3,
#  3,
#  5,
#  2,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  4,
#  3,
#  2,
#  4,
#  3,
#  3,
#  0,
#  3,
#  4,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  2,
#  1,
#  4,
#  3,
#  3,
#  2,
#  2,
#  2,
#  6,
#  4,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  2,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  4,
#  3,
#  2,
#  2,
#  3,
#  3,
#  6,
#  6,
#  4,
#  2,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  0,
#  6,
#  6,
#  4,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  2,
#  2,
#  4,
#  2,
#  2,
#  4,
#  3,
#  4,
#  3,
#  4,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  4,
#  2,
#  2,
#  2,
#  3,
#  2,
#  4,
#  2,
#  5,
#  0,
#  0,
#  4,
#  4,
#  4,
#  6,
#  4,
#  6,
#  3,
#  4,
#  4,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  0,
#  2,
#  2,
#  2,
#  2,
#  3,
#  2,
#  2,
#  6,
#  6,
#  1,
#  6,
#  5,
#  0,
#  4,
#  3,
#  2,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  4,
#  3,
#  3,
#  3,
#  6,
#  4,
#  2,
#  4,
#  2,
#  4,
#  4,
#  3,
#  3,
#  3,
#  6,
#  6,
#  6,
#  2,
#  3,
#  3,
#  3,
#  0,
#  0,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  2,
#  4,
#  3,
#  2,
#  2,
#  2,
#  4,
#  3,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  2,
#  2,
#  2,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  4,
#  2,
#  3,
#  3,
#  4,
#  2,
#  3,
#  2,
#  2,
#  3,
#  2,
#  0,
#  0,
#  3,
#  4,
#  6,
#  6,
#  4,
#  4,
#  3,
#  4,
#  2,
#  4,
#  2,
#  3,
#  4,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  2,
#  0,
#  3,
#  0,
#  3,
#  6,
#  6,
#  1,
#  4,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  5,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  6,
#  2,
#  0,
#  3,
#  3,
#  3,
#  0,
#  0,
#  4,
#  0,
#  2,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  2,
#  4,
#  3,
#  3,
#  3,
#  4,
#  2,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  0,
#  0,
#  3,
#  4,
#  6,
#  3,
#  2,
#  2,
#  3,
#  3,
#  4,
#  4,
#  3,
#  2,
#  4,
#  2,
#  3,
#  2,
#  4,
#  3,
#  6,
#  6,
#  1,
#  2,
#  6,
#  0,
#  3,
#  4,
#  3,
#  4,
#  4,
#  6,
#  2,
#  1,
#  4,
#  3,
#  3,
#  4,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  6,
#  3,
#  4,
#  3,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  0,
#  3,
#  3,
#  3,
#  3,
#  2,
#  4,
#  3,
#  2,
#  2,
#  2,
#  6,
#  3,
#  3,
#  4,
#  4,
#  3,
#  3,
#  1,
#  0,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  6,
#  6,
#  3,
#  4,
#  4,
#  3,
#  2,
#  4,
#  2,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  6,
#  1,
#  3,
#  4,
#  3,
#  2,
#  2,
#  2,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  4,
#  0,
#  3,
#  4,
#  6,
#  6,
#  4,
#  6,
#  6,
#  6,
#  6,
#  4,
#  6,
#  6,
#  1,
#  2,
#  4,
#  3,
#  5,
#  4,
#  2,
#  5,
#  3,
#  3,
#  3,
#  3,
#  6,
#  6,
#  1,
#  4,
#  4,
#  1,
#  0,
#  4,
#  3,
#  2,
#  6,
#  2,
#  2,
#  4,
#  3,
#  2,
#  2,
#  6,
#  2,
#  3,
#  4,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  0,
#  3,
#  3,
#  5,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  2,
#  4,
#  3,
#  3,
#  4,
#  4,
#  3,
#  2,
#  4,
#  4,
#  0,
#  0,
#  4,
#  4,
#  2,
#  3,
#  2,
#  3,
#  3,
#  4,
#  5,
#  6,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  6,
#  4,
#  2,
#  3,
#  4,
#  3,
#  5,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  2,
#  4,
#  2,
#  4,
#  2,
#  2,
#  3,
#  5,
#  0,
#  4,
#  0,
#  0,
#  4,
#  2,
#  4,
#  2,
#  2,
#  2,
#  3,
#  3,
#  4,
#  4,
#  2,
#  4,
#  6,
#  2,
#  4,
#  4,
#  0,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  2,
#  3,
#  4,
#  4,
#  3,
#  4,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  6,
#  6,
#  6,
#  6,
#  6,
#  4,
#  0,
#  0,
#  2,
#  2,
#  5,
#  5,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  5,
#  4,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  4,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  5,
#  3,
#  3,
#  4,
#  2,
#  2,
#  3,
#  2,
#  3,
#  4,
#  3,
#  0,
#  0,
#  6,
#  6,
#  3,
#  3,
#  5,
#  2,
#  2,
#  6,
#  2,
#  2,
#  2,
#  6,
#  6,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  6,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  2,
#  2,
#  4,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  5,
#  3,
#  3,
#  4,
#  4,
#  3,
#  3,
#  6,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  4,
#  4,
#  3,
#  3,
#  2,
#  6,
#  2,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  0,
#  3,
#  2,
#  3,
#  5,
#  3,
#  3,
#  3,
#  3,
#  6,
#  1,
#  2,
#  2,
#  6,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  4,
#  3,
#  4,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  2,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  4,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  2,
#  3,
#  6,
#  4,
#  6,
#  4,
#  1,
#  1,
#  4,
#  3,
#  4,
#  2,
#  2,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  4,
#  3,
#  3,
#  3,
#  3,
#  5,
#  3,
#  3,
#  5,
#  3,
#  6,
#  3,
#  3,
#  1,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  2,
#  2,
#  2,
#  3,
#  0,
#  3,
#  0,
#  0,
#  4,
#  4,
#  4,
#  4,
#  2,
#  6,
#  2,
#  3,
#  2,
#  4,
#  5,
#  3,
#  3,
#  1,
#  0,
#  3,
#  2,
#  3,
#  3,
#  3,
#  4,
#  2,
#  2,
#  0,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  6,
#  4,
#  4,
#  3,
#  2,
#  2,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  ...]

# %%
print(metrics.precision_score(y, p, average=None)) #
print(metrics.precision_score(y, p, average=None).mean()) #
print(metrics.precision_score(y, p, average='macro')) #1.0
print(metrics.precision_score(y, p, average='micro')) #1.0
# Out:
# [0.93203883 0.         0.88199276 0.75765625 0.00183688 0.
#  0.87878788]
# 0.4931875160128841
# 0.4931875160128841
# 0.6429549500205395

# %%
import sklearn.metrics as metrics

# sklearn 을 이용하면 전부 계산해준다.
print('accuracy', metrics.accuracy_score(y,p) )
print('precision1', metrics.precision_score(y, p, average=None)) #
print('precision2', metrics.precision_score(y, p, average=None).mean()) #
print('precision3', metrics.precision_score(y, p, average='macro')) #1.0
print('precision4', metrics.precision_score(y, p, average='micro')) #1.0
print('recall1', metrics.recall_score(y, p, average=None)) #
print('recall2', metrics.recall_score(y, p, average=None).mean()) #
print('recall3', metrics.recall_score(y, p, average='macro')) #1.0
print('recall4', metrics.recall_score(y, p, average='micro')) #1.0
print('f1_score1', metrics.f1_score(y, p, average=None)) #
print('f1_score2', metrics.f1_score(y, p, average=None).mean()) #
print('f1_score3', metrics.f1_score(y, p, average='macro')) #1.0
print('f1_score4', metrics.f1_score(y, p, average='micro')) #1.0

print(metrics.classification_report(y,p))
print(metrics.confusion_matrix(y,p))
# Out:
# accuracy 0.6429549500205395
# precision1 [0.93203883 0.         0.88199276 0.75765625 0.00183688 0.
#  0.87878788]
# precision2 0.4931875160128841
# precision3 0.4931875160128841
# precision4 0.6429549500205395
# recall1 [0.42504744 0.         0.60790332 0.77066116 1.         0.
#  0.45940594]
# recall2 0.4661454077965049
# recall3 0.4661454077965049
# recall4 0.6429549500205395
# f1_score1 [0.58384014 0.         0.71973654 0.76410337 0.00366703 0.
#  0.60338101]
# f1_score2 0.38210401459325277
# f1_score3 0.38210401459325277
# f1_score4 0.6429549500205395
#               precision    recall  f1-score   support
#
#            0       0.93      0.43      0.58      1581
#            1       0.00      0.00      0.00         0
#            2       0.88      0.61      0.72      5213
#            3       0.76      0.77      0.76      6292
#            4       0.00      1.00      0.00         5
#            5       0.00      0.00      0.00         0
#            6       0.88      0.46      0.60      1515
#
#     accuracy                           0.64     14606
#    macro avg       0.49      0.47      0.38     14606
# weighted avg       0.83      0.64      0.71     14606
#
# [[ 672   47    7  242  543   66    4]
#  [   0    0    0    0    0    0    0]
#  [  15    4 3169 1144  720   76   85]
#  [  26    5  172 4849 1125  108    7]
#  [   0    0    0    0    5    0    0]
#  [   0    0    0    0    0    0    0]
#  [   8   55  245  165  329   17  696]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
