# %% [markdown]
# <a href="https://colab.research.google.com/github/BrotherKim/Colab/blob/main/SEP592/BK_resnet50_JT_BRCA_classification_ROC_300_300.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.environ['ROOTDIR'] = "/content/jt_breast_aug"

# %%
# !mkdir -p $ROOTDIR
# !unzip /content/gdrive/MyDrive/breast_aug.zip -d $ROOTDIR
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__2090_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__292_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__2524_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__593_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4396-01Z-00-DX1_azhao__580_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__645_2_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__119_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__181_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1561_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__18_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1443_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__1086_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__335_2_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1991_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__3704_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__358_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__709_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__3273_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__943_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4403-01Z-00-DX1_azhao__533_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1559_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2281_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__85_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2269_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__464_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__959_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2421_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1069_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__25_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__57_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1710_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4403-01Z-00-DX1_azhao__437_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__215_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__823_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__249_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__113_1_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1385_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__270_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__1693_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A0CO-01Z-00-DX1_agreement__30_2_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2419_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1906_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1822_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__107_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__215_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1900_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1585_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALI-01Z-00-DX1_agreement__129_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__915_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1514_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__850_1_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1142_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__58_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__1690_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__223_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__512_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__84_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__12_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2364_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1848_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4402-01Z-00-DX1_azhao__1151_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__38_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__339_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1482_2_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4398-01Z-00-DX1_azhao__170_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1667_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__179_2_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__314_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__765_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2795_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4415-01Z-00-DX1_azhao__1287_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__843_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__685_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2128_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__60_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1446_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__887_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__585_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__169_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2561_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__1693_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2078_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2823_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2918_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__445_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A0CW-01Z-00-DX1_agreement__1087_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__578_1_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1996_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4396-01Z-00-DX1_azhao__53_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1567_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__551_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__185_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1097_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__352_1_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2680_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1849_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__624_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1922_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1473_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__939_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1646_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1629_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__2099_1_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__113_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1632_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__834_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__1182_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__531_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__322_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__2539_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__215_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1325_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1211_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1112_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__819_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1595_2_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1970_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2821_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_5__1865_2_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4396-01Z-00-DX1_azhao__662_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2035_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__226_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2096_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__3122_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__0_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__86_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__182_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__761_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2192_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1886_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__26_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1981_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__358_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__424_1_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__210_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__272_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__319_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__2162_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1667_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__101_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__910_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__1182_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_3__914_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__1982_1_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2261_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4415-01Z-00-DX1_azhao__1187_1_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__119_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__261_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__2189_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2273_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__415_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__767_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__265_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__226_1_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_3__371_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1289_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__664_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__2734_1_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__308_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1424_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1019_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__341_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__1182_1_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1208_2_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_6__1286_2_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1832_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__287_1_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__301_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__136_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__7_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__124_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__182_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1746_2_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__118_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__63_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__540_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2787_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2240_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2306_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1723_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__199_2_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__386_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2583_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__13_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__993_1_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2348_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__280_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__946_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__339_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1618_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4415-01Z-00-DX1_azhao__1239_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__252_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__887_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1178_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__167_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1290_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__1507_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__2531_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4402-01Z-00-DX1_azhao__1265_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__916_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4245-01Z-00-DX1_azhao__847_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__255_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__425_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__49_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__2030_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1584_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4402-01Z-00-DX1_azhao__908_1_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1415_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__883_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2482_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__446_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1759_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1009_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__104_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__172_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1879_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__60_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__787_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__854_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__118_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1029_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1131_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__652_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-A2-A0CO-01Z-00-DX1_agreement__41_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__1328_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__586_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__191_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2171_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__103_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A0CW-01Z-00-DX1_agreement__79_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2397_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__777_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__78_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_6__2068_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__503_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1855_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__767_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2825_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1235_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1024_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__938_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__120_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2791_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__196_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1042_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__86_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__991_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4415-01Z-00-DX1_azhao__1221_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2170_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__104_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__443_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__99_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2149_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1994_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__292_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__389_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1447_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__630_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__224_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2558_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2722_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALI-01Z-00-DX1_agreement__959_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__332_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__137_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2092_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2720_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__174_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2502_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__3755_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__302_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1792_2_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2160_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1715_2_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__97_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__207_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__229_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1622_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__299_1_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_4__2644_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__445_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2421_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__2426_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__1775_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A1-A0SK-01Z-00-DX1_agreement__127_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__396_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1031_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__15_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__1118_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1059_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2658_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__375_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__516_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1528_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__661_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__368_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4415-01Z-00-DX1_azhao__1233_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__255_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__339_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__734_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2501_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__398_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__776_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__882_1_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2527_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__236_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__92_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1050_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__732_2_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2680_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1030_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__101_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2926_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1589_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__716_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2186_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__1768_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__1456_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__967_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2050_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1587_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2086_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__761_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__288_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__244_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__1798_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__836_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A0CW-01Z-00-DX1_agreement__427_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__353_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__233_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4417-01Z-00-DX1_azhao__239_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__426_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__187_2_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_6__1586_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2326_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__765_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1106_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__74_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1580_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__502_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2070_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2663_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1059_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1335_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1829_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__91_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__132_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__778_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__791_2_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1397_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__843_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__950_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_3__699_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__383_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__189_1_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2586_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__1288_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__150_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__86_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__321_2_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2411_1_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4397-01Z-00-DX1_azhao__2015_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__402_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2927_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__3794_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__292_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__211_1_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__871_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1413_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__74_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1810_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__679_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1157_2_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__1167_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__2180_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__155_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_6__1551_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__611_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__242_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__84_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2510_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1755_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1831_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2393_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1462_2_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4417-01Z-00-DX1_azhao__197_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__748_1_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_3__371_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__50_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__266_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2130_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1548_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__634_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_3__429_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__198_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1130_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1870_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1293_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__569_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1479_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__246_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__228_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2465_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1620_2_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__164_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2515_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__132_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__943_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__31_1_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1088_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__301_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__117_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1747_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__515_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2425_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__673_1_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4245-01Z-00-DX1_azhao__885_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1921_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1045_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__98_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__161_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__891_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1886_1_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2873_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__292_1_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__253_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__790_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2113_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__559_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__928_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2087_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__1020_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_4__680_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__301_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__295_2_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__685_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__143_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__242_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_2__1610_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__71_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__573_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1320_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__449_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__818_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__433_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2838_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__202_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2290_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4245-01Z-00-DX1_azhao__720_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2138_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2235_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__178_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__247_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__302_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__467_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__218_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__29_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__933_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2793_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__104_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1154_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2790_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__1899_1_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_6__104_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__888_2_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__848_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__733_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1688_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__753_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1958_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__888_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__422_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1602_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2212_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__178_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1161_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1847_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__391_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__728_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2410_2_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_2__3205_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__405_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__2162_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2372_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1366_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__36_1_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_4__3845_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1051_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__147_1_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__163_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__761_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__294_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1177_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1103_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__680_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__101_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1073_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__650_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__268_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__214_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2827_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1340_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A0CO-01Z-00-DX1_agreement__44_1_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1657_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__229_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2619_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__302_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__724_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1064_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1511_1_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__138_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__750_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1280_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1233_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__620_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1106_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__838_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2340_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2107_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A0CT-01Z-00-DX1_agreement__229_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1891_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__359_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__973_1_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__317_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__390_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__217_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1748_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1564_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__667_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__631_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2743_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__648_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__95_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__16_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1407_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__715_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1407_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__475_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4398-01Z-00-DX1_azhao__1955_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1204_2_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1174_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2752_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__68_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__224_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2134_1_2.png
# ...
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__102_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__2122_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2317_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__255_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__32_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1303_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1239_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__188_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_5__715_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__924_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1011_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__904_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1079_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2162_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2754_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__156_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__554_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__387_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2222_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__478_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__333_2_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1670_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1643_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1278_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__76_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__3122_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4396-01Z-00-DX1_azhao__53_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__173_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2194_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1813_1_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__44_2_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__83_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__144_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__181_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__235_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1703_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2409_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__140_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__31_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2640_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALI-01Z-00-DX1_agreement__739_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__992_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__83_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2056_2_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__1609_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1596_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_6__2124_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__403_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1826_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__320_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__824_2_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__1812_2_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1921_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1093_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1331_2_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__1378_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__802_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__304_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__652_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1155_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__469_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__83_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__113_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4403-01Z-00-DX1_azhao__437_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__289_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__515_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__513_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1863_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2587_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__131_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__2283_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1037_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__360_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__661_2_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2187_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1784_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2177_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__377_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__320_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A0CT-01Z-00-DX1_agreement__119_1_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2187_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1980_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__574_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1932_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__524_1_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-05-4245-01Z-00-DX1_azhao__780_2_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2643_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__311_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__72_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__3233_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2027_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__921_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__233_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__789_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__2145_1_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__790_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__437_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2122_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__3012_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__4015_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4403-01Z-00-DX1_azhao__719_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2003_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__2265_1_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__TCGA-05-4396-01Z-00-DX1_azhao__201_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2311_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__545_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__482_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__37_1_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_4__927_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__307_2_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__142_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__223_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__955_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__752_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__518_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__149_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__227_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__804_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__1665_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1265_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__2320_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__305_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04Y-01Z-00-DX1_agreement__227_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2309_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1553_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__182_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__294_2_2.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_4__3318_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4415-01Z-00-DX1_azhao__1207_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2882_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1262_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1567_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__156_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1190_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1935_2.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1657_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__296_2_1.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__858_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__763_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2092_1_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__1412_1_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_3__431_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__826_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__418_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2208_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__365_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2103_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__160_2_3.png
#   inflating: /content/jt_breast_aug/TIL/valid___TIL__luad_batch_1__2861_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__65_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_2__105_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-A2-A04P-01Z-00-DX1_agreement__330_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1487_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_3__764_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__239_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2013_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__2071_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2264_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__3300_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1687_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2836_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4245-01Z-00-DX1_azhao__793_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_5__2252_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__930_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2662_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1622_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1291_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__790_1.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1632_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__282_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__446_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__141_2_3.png
#   inflating: /content/jt_breast_aug/TIL/test___TIL__luad_batch_1__1605_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__1510_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_6__90_1_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2461_1_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2634_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4396-01Z-00-DX1_azhao__540_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-3C-AALJ-01Z-00-DX1_agreement__73_1_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__TCGA-05-4417-01Z-00-DX1_azhao__1739_2_1.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_4__1664_2_3.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__2389_2_2.png
#   inflating: /content/jt_breast_aug/TIL/train___TIL__luad_batch_1__82_2_2.png

# %%
# !ls -1 $ROOTDIR
# Out:
# Normal
# TIL

# %%
# !mkdir -p $ROOTDIR/train_set/
# !mkdir -p $ROOTDIR/test_set/TIL
# !mkdir -p $ROOTDIR/test_set/Normal
# !mkdir -p $ROOTDIR/valid_set/TIL
# !mkdir -p $ROOTDIR/valid_set/Normal

# %%
# !cd $ROOTDIR/TIL && ls -1 | wc -l
# Out:
# 48712

# %%
# !cd $ROOTDIR/TIL && ls -1 | head -4800 | xargs -i mv "{}" $ROOTDIR/test_set/TIL

# %%
# !cd $ROOTDIR/TIL && ls -1 | head -4800 | xargs -i mv "{}" $ROOTDIR/valid_set/TIL

# %%
# !cd $ROOTDIR/TIL && ls -1 | wc -l
# Out:
# 48712

# %%
# !mv $ROOTDIR/TIL $ROOTDIR/train_set/TIL

# %%
# !cd $ROOTDIR/Normal && ls -1 | wc -l
# Out:
# 52888

# %%
# !cd $ROOTDIR/Normal && ls -1 | head -5280 | xargs -i mv "{}" $ROOTDIR/test_set/Normal

# %%
# !cd $ROOTDIR/Normal && ls -1 | head -5280 | xargs -i mv "{}" $ROOTDIR/valid_set/Normal

# %%
# !cd $ROOTDIR/Normal && ls -1 | wc -l
# Out:
# 42328

# %%
# !mv $ROOTDIR/Normal $ROOTDIR/train_set/Normal

# %%
# !cd $ROOTDIR/train_set/TIL && ls -1 | wc -l
# !cd $ROOTDIR/train_set/Normal && ls -1 | wc -l
# !cd $ROOTDIR/test_set/TIL && ls -1 | wc -l
# !cd $ROOTDIR/test_set/Normal && ls -1 | wc -l
# !cd $ROOTDIR/valid_set/TIL && ls -1 | wc -l
# !cd $ROOTDIR/valid_set/Normal && ls -1 | wc -l
# Out:
# 39112
# 42328
# 4800
# 5280
# 4800
# 5280

# %% [markdown]
# # Dataset 형태
# datasets<br>
#     &emsp;&emsp;└── test_set<br>
#     &emsp;&emsp;│   &emsp;&emsp;├── class1<br>
#     &emsp;&emsp;│   &emsp;&emsp;│   &emsp;&emsp;└── datas...<br>
#     &emsp;&emsp;│   &emsp;&emsp;└── class2<br>
#     &emsp;&emsp;│       &emsp;&emsp;&emsp;&emsp;&emsp;└── datas...<br>
#     &emsp;&emsp;└── training_set<br>
#         &emsp;&emsp;&emsp;&emsp;├── class1<br>
#         &emsp;&emsp;&emsp;&emsp;│   &emsp;&emsp;└── datas...<br>
#         &emsp;&emsp;&emsp;&emsp;└── class2<br>
#             &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;└── datas...<br>

# %% [markdown]
# # Parameter 및 Basemodel 설정

# %%
IMAGE_SIZE = 224
INPUT_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 3)
NUM_CLASSES = 2
WEIGHT_DIR_PATH = '/content/gdrive/MyDrive/KAIST/SEP592/checkpoints'
WEIGHT_FILE_PATH = '20210608_resnet50_jt_brca.h5'

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

baseModel = ResNet50(include_top=False, weights='imagenet', input_shape=INPUT_SHAPE, pooling='avg', classes=NUM_CLASSES)
#baseModel = ResNet50(include_top=False, weights='imagenet', input_shape=INPUT_SHAPE, classes=NUM_CLASSES)
#baseMode =ResNet50(include_top=True, weights=None, input_shape=INPUT_SHAPE, classes=NUM_CLASSES)

baseModel.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           conv5_block3_out[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 위노그라드 알고리즘 설정
os.environ['TF_ENABLE_WINOGRAD_NONFUSED'] = '1'

#rootPath = '/content/datasets'
#rootPath = '/content/gdrive/MyDrive/KAIST/SEP592/jt_breast_aug'
rootPath = os.environ['ROOTDIR']

imageGenerator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=[.2, .2],
    horizontal_flip=True,
    validation_split=.1
)

# %%
#!find /content/gdrive/MyDrive/KAIST/lym_augmentation -type f | wc -l

# %%
#!cp -r /content/gdrive/MyDrive/KAIST/lym_aug1mentation/* /content/gdrive/MyDrive/KAIST/dataset_augmentation/train_set/lym/

# %%
#!find /content/gdrive/MyDrive/KAIST/dataset_augmentation/train_set/lym -type f | wc -l

# %%
#!cd /content/gdrive/MyDrive/KAIST/lym_aug1mentation/ && find ./ -name "*aug*" | sed -e 'p' -e "s/aug/aug1/g" |xargs -n 2 mv

# %%
#!find /content/gdrive/MyDrive/KAIST/dataset_augmentation/train_set/normal -type f | wc -l

# %% [markdown]
# # Data Load

# %%
trainGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'train_set'),
    target_size=(IMAGE_SIZE, IMAGE_SIZE)
)

validationGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'valid_set'),
    target_size=(IMAGE_SIZE, IMAGE_SIZE)
)
# Out:
# Found 81440 images belonging to 2 classes.
# Found 10080 images belonging to 2 classes.

# %% [markdown]
# # Model setting

# %%
for i, l in enumerate(baseModel.layers):
  print(i, l.name)
# Out:
# 0 input_2
# 1 conv1_pad
# 2 conv1_conv
# 3 conv1_bn
# 4 conv1_relu
# 5 pool1_pad
# 6 pool1_pool
# 7 conv2_block1_1_conv
# 8 conv2_block1_1_bn
# 9 conv2_block1_1_relu
# 10 conv2_block1_2_conv
# 11 conv2_block1_2_bn
# 12 conv2_block1_2_relu
# 13 conv2_block1_0_conv
# 14 conv2_block1_3_conv
# 15 conv2_block1_0_bn
# 16 conv2_block1_3_bn
# 17 conv2_block1_add
# 18 conv2_block1_out
# 19 conv2_block2_1_conv
# 20 conv2_block2_1_bn
# 21 conv2_block2_1_relu
# 22 conv2_block2_2_conv
# 23 conv2_block2_2_bn
# 24 conv2_block2_2_relu
# 25 conv2_block2_3_conv
# 26 conv2_block2_3_bn
# 27 conv2_block2_add
# 28 conv2_block2_out
# 29 conv2_block3_1_conv
# 30 conv2_block3_1_bn
# 31 conv2_block3_1_relu
# 32 conv2_block3_2_conv
# 33 conv2_block3_2_bn
# 34 conv2_block3_2_relu
# 35 conv2_block3_3_conv
# 36 conv2_block3_3_bn
# 37 conv2_block3_add
# 38 conv2_block3_out
# 39 conv3_block1_1_conv
# 40 conv3_block1_1_bn
# 41 conv3_block1_1_relu
# 42 conv3_block1_2_conv
# 43 conv3_block1_2_bn
# 44 conv3_block1_2_relu
# 45 conv3_block1_0_conv
# 46 conv3_block1_3_conv
# 47 conv3_block1_0_bn
# 48 conv3_block1_3_bn
# 49 conv3_block1_add
# 50 conv3_block1_out
# 51 conv3_block2_1_conv
# 52 conv3_block2_1_bn
# 53 conv3_block2_1_relu
# 54 conv3_block2_2_conv
# 55 conv3_block2_2_bn
# 56 conv3_block2_2_relu
# 57 conv3_block2_3_conv
# 58 conv3_block2_3_bn
# 59 conv3_block2_add
# 60 conv3_block2_out
# 61 conv3_block3_1_conv
# 62 conv3_block3_1_bn
# 63 conv3_block3_1_relu
# 64 conv3_block3_2_conv
# 65 conv3_block3_2_bn
# 66 conv3_block3_2_relu
# 67 conv3_block3_3_conv
# 68 conv3_block3_3_bn
# 69 conv3_block3_add
# 70 conv3_block3_out
# 71 conv3_block4_1_conv
# 72 conv3_block4_1_bn
# 73 conv3_block4_1_relu
# 74 conv3_block4_2_conv
# 75 conv3_block4_2_bn
# 76 conv3_block4_2_relu
# 77 conv3_block4_3_conv
# 78 conv3_block4_3_bn
# 79 conv3_block4_add
# 80 conv3_block4_out
# 81 conv4_block1_1_conv
# 82 conv4_block1_1_bn
# 83 conv4_block1_1_relu
# 84 conv4_block1_2_conv
# 85 conv4_block1_2_bn
# 86 conv4_block1_2_relu
# 87 conv4_block1_0_conv
# 88 conv4_block1_3_conv
# 89 conv4_block1_0_bn
# 90 conv4_block1_3_bn
# 91 conv4_block1_add
# 92 conv4_block1_out
# 93 conv4_block2_1_conv
# 94 conv4_block2_1_bn
# 95 conv4_block2_1_relu
# 96 conv4_block2_2_conv
# 97 conv4_block2_2_bn
# 98 conv4_block2_2_relu
# 99 conv4_block2_3_conv
# 100 conv4_block2_3_bn
# 101 conv4_block2_add
# 102 conv4_block2_out
# 103 conv4_block3_1_conv
# 104 conv4_block3_1_bn
# 105 conv4_block3_1_relu
# 106 conv4_block3_2_conv
# 107 conv4_block3_2_bn
# 108 conv4_block3_2_relu
# 109 conv4_block3_3_conv
# 110 conv4_block3_3_bn
# 111 conv4_block3_add
# 112 conv4_block3_out
# 113 conv4_block4_1_conv
# 114 conv4_block4_1_bn
# 115 conv4_block4_1_relu
# 116 conv4_block4_2_conv
# 117 conv4_block4_2_bn
# 118 conv4_block4_2_relu
# 119 conv4_block4_3_conv
# 120 conv4_block4_3_bn
# 121 conv4_block4_add
# 122 conv4_block4_out
# 123 conv4_block5_1_conv
# 124 conv4_block5_1_bn
# 125 conv4_block5_1_relu
# 126 conv4_block5_2_conv
# 127 conv4_block5_2_bn
# 128 conv4_block5_2_relu
# 129 conv4_block5_3_conv
# 130 conv4_block5_3_bn
# 131 conv4_block5_add
# 132 conv4_block5_out
# 133 conv4_block6_1_conv
# 134 conv4_block6_1_bn
# 135 conv4_block6_1_relu
# 136 conv4_block6_2_conv
# 137 conv4_block6_2_bn
# 138 conv4_block6_2_relu
# 139 conv4_block6_3_conv
# 140 conv4_block6_3_bn
# 141 conv4_block6_add
# 142 conv4_block6_out
# 143 conv5_block1_1_conv
# 144 conv5_block1_1_bn
# 145 conv5_block1_1_relu
# 146 conv5_block1_2_conv
# 147 conv5_block1_2_bn
# 148 conv5_block1_2_relu
# 149 conv5_block1_0_conv
# 150 conv5_block1_3_conv
# 151 conv5_block1_0_bn
# 152 conv5_block1_3_bn
# 153 conv5_block1_add
# 154 conv5_block1_out
# 155 conv5_block2_1_conv
# 156 conv5_block2_1_bn
# 157 conv5_block2_1_relu
# 158 conv5_block2_2_conv
# 159 conv5_block2_2_bn
# 160 conv5_block2_2_relu
# 161 conv5_block2_3_conv
# 162 conv5_block2_3_bn
# 163 conv5_block2_add
# 164 conv5_block2_out
# 165 conv5_block3_1_conv
# 166 conv5_block3_1_bn
# 167 conv5_block3_1_relu
# 168 conv5_block3_2_conv
# 169 conv5_block3_2_bn
# 170 conv5_block3_2_relu
# 171 conv5_block3_3_conv
# 172 conv5_block3_3_bn
# 173 conv5_block3_add
# 174 conv5_block3_out
# 175 avg_pool

# %%
from keras.models import Model
from tensorflow.keras.layers import Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization

#x = baseModel.output
#x = MaxPooling2D(pool_size=(2, 2))(x)
#x = Flatten()(x)
#x = Dropout(0.5)(x)
#x = Dense(512, activation='relu', input_dim=INPUT_SHAPE)(x)
#x = BatchNormalization()(x)
#x = Dense(256, activation ='relu')(x)
#x = BatchNormalization()(x)
#x = Dense(NUM_CLASSES, activation='softmax')(x)

#model = Model(
#    inputs=baseModel.input
#    , outputs=x
#    )

model = Sequential()

model.add(baseModel)
model.add(Dense(NUM_CLASSES, activation='softmax'))
#model.layers[0].trainable = False

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# _________________________________________________________________

# %% [markdown]
# # Finetuning

# %%
NUM_FREEZE = 60

for l in baseModel.layers:
  l.trainable = False

for l in baseModel.layers[NUM_FREEZE:]:
  l.trainable = True

# %%
from keras import optimizers

sgd = optimizers.SGD(lr=0.01, decay=12-6, momentum=0.9, nesterov=True)

model.compile(
    optimizer=sgd, #optimizer='adam',
    loss='categorical_crossentropy', 
    metrics=['acc'],
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
#epochs = 32
#history = model.fit_generator(
#    trainGen, 
#    epochs=epochs,
#    steps_per_epoch=trainGen.samples / epochs, 
#    validation_data=validationGen,
#    validation_steps=trainGen.samples / epochs,
#)
from keras.callbacks import ModelCheckpoint,ReduceLROnPlateau,EarlyStopping

model_ckpt = ModelCheckpoint('%s/%s' % (WEIGHT_DIR_PATH, WEIGHT_FILE_PATH),save_best_only=True)
reduce_lr = ReduceLROnPlateau(patience=8,verbose=1)
early_stop = EarlyStopping(patience=10,verbose=2,monitor='loss')

epochs = 32
history = model.fit_generator(
    trainGen,  
    epochs=epochs,
    steps_per_epoch=300, 
    validation_data=validationGen,
    validation_steps=300,
    callbacks=[reduce_lr,early_stop],
    workers=1000,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/32
# 300/300 [==============================] - 144s 469ms/step - loss: 0.6201 - acc: 0.6528 - val_loss: 0.4789 - val_acc: 0.8084
# Epoch 2/32
# 300/300 [==============================] - 147s 470ms/step - loss: 0.6227 - acc: 0.6492 - val_loss: 0.4989 - val_acc: 0.7763
# Epoch 3/32
# 300/300 [==============================] - 147s 471ms/step - loss: 0.6240 - acc: 0.6450 - val_loss: 0.5092 - val_acc: 0.7581
# Epoch 4/32
# 300/300 [==============================] - 147s 471ms/step - loss: 0.6168 - acc: 0.6549 - val_loss: 0.4948 - val_acc: 0.7859
# Epoch 5/32
# 300/300 [==============================] - 147s 472ms/step - loss: 0.6276 - acc: 0.6413 - val_loss: 0.5210 - val_acc: 0.7378
# Epoch 6/32
# 300/300 [==============================] - 145s 470ms/step - loss: 0.6171 - acc: 0.6514 - val_loss: 0.4988 - val_acc: 0.7713
# Epoch 7/32
# 300/300 [==============================] - 146s 466ms/step - loss: 0.6194 - acc: 0.6519 - val_loss: 0.4784 - val_acc: 0.7994
# Epoch 8/32
# 300/300 [==============================] - 146s 470ms/step - loss: 0.6195 - acc: 0.6502 - val_loss: 0.4664 - val_acc: 0.8172
# Epoch 9/32
# 300/300 [==============================] - 147s 472ms/step - loss: 0.6095 - acc: 0.6648 - val_loss: 0.4852 - val_acc: 0.8031
# Epoch 10/32
# 300/300 [==============================] - 145s 469ms/step - loss: 0.6105 - acc: 0.6632 - val_loss: 0.4648 - val_acc: 0.8178
# Epoch 11/32
# 300/300 [==============================] - 145s 471ms/step - loss: 0.6165 - acc: 0.6550 - val_loss: 0.4824 - val_acc: 0.7953
# Epoch 12/32
# 300/300 [==============================] - 146s 471ms/step - loss: 0.6207 - acc: 0.6504 - val_loss: 0.4797 - val_acc: 0.7978
# Epoch 13/32
# 300/300 [==============================] - 146s 469ms/step - loss: 0.6149 - acc: 0.6618 - val_loss: 0.4640 - val_acc: 0.8166
# Epoch 14/32
# 300/300 [==============================] - 147s 472ms/step - loss: 0.6250 - acc: 0.6459 - val_loss: 0.4671 - val_acc: 0.8150
# Epoch 15/32
# 300/300 [==============================] - 148s 474ms/step - loss: 0.6192 - acc: 0.6540 - val_loss: 0.4916 - val_acc: 0.7772
# Epoch 16/32
# 300/300 [==============================] - 147s 472ms/step - loss: 0.6163 - acc: 0.6578 - val_loss: 0.4764 - val_acc: 0.8056
# Epoch 17/32
# 300/300 [==============================] - 147s 472ms/step - loss: 0.6183 - acc: 0.6551 - val_loss: 0.4720 - val_acc: 0.7972
# Epoch 18/32
# 300/300 [==============================] - 146s 469ms/step - loss: 0.6152 - acc: 0.6542 - val_loss: 0.4746 - val_acc: 0.8000
# Epoch 19/32
# 300/300 [==============================] - 146s 470ms/step - loss: 0.6191 - acc: 0.6538 - val_loss: 0.4886 - val_acc: 0.7881
# Epoch 00019: early stopping

# %%
#epochs = 32
#history = model.fit_generator(
#    trainGen, 
#    epochs=epochs,
#    steps_per_epoch=trainGen.samples / epochs, 
#    validation_data=validationGen,
#    validation_steps=trainGen.samples / epochs,
#)
from keras.callbacks import ModelCheckpoint,ReduceLROnPlateau,EarlyStopping

model_ckpt = ModelCheckpoint('%s/%s' % (WEIGHT_DIR_PATH, WEIGHT_FILE_PATH),save_best_only=True)
reduce_lr = ReduceLROnPlateau(patience=8,verbose=1)
early_stop = EarlyStopping(patience=10,verbose=2,monitor='loss')

epochs = 32
history = model.fit_generator(
    trainGen,  
    epochs=epochs,
    steps_per_epoch=trainGen.samples//epochs, 
    validation_data=validationGen,
    validation_steps=validationGen.samples//epochs,
    callbacks=[reduce_lr,early_stop],
    workers=1000,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/32
# 2637/2637 [==============================] - 964s 357ms/step - loss: 0.6306 - acc: 0.6405 - val_loss: 0.5576 - val_acc: 0.7234
# Epoch 2/32
# 2637/2637 [==============================] - 1050s 396ms/step - loss: 0.6222 - acc: 0.6492 - val_loss: 0.5503 - val_acc: 0.7269
# Epoch 3/32
# 2637/2637 [==============================] - 1081s 408ms/step - loss: 0.6194 - acc: 0.6542 - val_loss: 0.5300 - val_acc: 0.7639
# Epoch 4/32
# 2637/2637 [==============================] - 1098s 415ms/step - loss: 0.6182 - acc: 0.6538 - val_loss: 0.5374 - val_acc: 0.7470
# Epoch 5/32
# 2637/2637 [==============================] - 1133s 428ms/step - loss: 0.6173 - acc: 0.6548 - val_loss: 0.5326 - val_acc: 0.7519
# Epoch 6/32
# 2637/2637 [==============================] - 881s 332ms/step - loss: 0.6162 - acc: 0.6568 - val_loss: 0.5275 - val_acc: 0.7575
# Epoch 7/32
# 2637/2637 [==============================] - 880s 332ms/step - loss: 0.6159 - acc: 0.6567 - val_loss: 0.5318 - val_acc: 0.7533
# Epoch 8/32
# 2637/2637 [==============================] - 891s 337ms/step - loss: 0.6154 - acc: 0.6569 - val_loss: 0.5258 - val_acc: 0.7600
# Epoch 9/32
# 2637/2637 [==============================] - 915s 346ms/step - loss: 0.6148 - acc: 0.6571 - val_loss: 0.5236 - val_acc: 0.7650
# Epoch 10/32
# 2637/2637 [==============================] - 892s 337ms/step - loss: 0.6152 - acc: 0.6574 - val_loss: 0.5289 - val_acc: 0.7557
# Epoch 11/32
# 2637/2637 [==============================] - 883s 333ms/step - loss: 0.6138 - acc: 0.6586 - val_loss: 0.5241 - val_acc: 0.7573
# Epoch 12/32
# 2637/2637 [==============================] - 880s 332ms/step - loss: 0.6137 - acc: 0.6577 - val_loss: 0.5218 - val_acc: 0.7610
# Epoch 13/32
#  717/2637 [=======>......................] - ETA: 9:39 - loss: 0.6171 - acc: 0.6542
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-28-48608bbf7c53> in <module>()
#      21     validation_steps=validationGen.samples//epochs,
#      22     callbacks=[reduce_lr,early_stop],
# ---> 23     workers=1000,
#      24 )
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1955         use_multiprocessing=use_multiprocessing,
#    1956         shuffle=shuffle,
# -> 1957         initial_epoch=initial_epoch)
#    1958
#    1959   def evaluate_generator(self,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# UnknownError: 2 root error(s) found.
#   (0) Unknown:  FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/KAIST/SEP592/jt_breast_aug/train_set/Normal/train___Normal__TCGA-05-4403-01Z-00-DX1_azhao__2639_2.png'
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 645, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 961, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/data_adapter.py", line 837, in wrapped_generator
#     for data in generator_fn():
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/data_utils.py", line 766, in get
#     raise e
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/data_utils.py", line 757, in get
#     inputs = self.queue.get(block=True, timeout=5).get()
#
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 657, in get
#     raise self._value
#
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/data_utils.py", line 547, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#
#   File "/usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/iterator.py", line 65, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#
#   File "/usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/iterator.py", line 230, in _get_batches_of_transformed_samples
#     interpolation=self.interpolation)
#
#   File "/usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py", line 113, in load_img
#     with open(path, 'rb') as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/KAIST/SEP592/jt_breast_aug/train_set/Normal/train___Normal__TCGA-05-4403-01Z-00-DX1_azhao__2639_2.png'
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
#   (1) Unknown:  FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/KAIST/SEP592/jt_breast_aug/train_set/Normal/train___Normal__TCGA-05-4403-01Z-00-DX1_azhao__2639_2.png'
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 645, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 961, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/data_adapter.py", line 837, in wrapped_generator
#     for data in generator_fn():
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/data_utils.py", line 766, in get
#     raise e
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/data_utils.py", line 757, in get
#     inputs = self.queue.get(block=True, timeout=5).get()
#
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 657, in get
#     raise self._value
#
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/data_utils.py", line 547, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#
#   File "/usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/iterator.py", line 65, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#
#   File "/usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/iterator.py", line 230, in _get_batches_of_transformed_samples
#     interpolation=self.interpolation)
#
#   File "/usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py", line 113, in load_img
#     with open(path, 'rb') as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/KAIST/SEP592/jt_breast_aug/train_set/Normal/train___Normal__TCGA-05-4403-01Z-00-DX1_azhao__2639_2.png'
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 	 [[IteratorGetNext/_2]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_14579]
#
# Function call stack:
# train_function -> train_function

# %%
#model.save_weights("/content/gdrive/MyDrive/KAIST/SEP592/checkpoints/resnet50_brca_ckpt")
# !mkdir -p WEIGHT_DIR_PATH
WEIGHT_FILE_PATH = '210608_0741_resnet50_brca_12_300_300_aug_unfreeze.h5'

model.save_weights('%s/%s' % (WEIGHT_DIR_PATH, WEIGHT_FILE_PATH))

# `assert_consumed` can be used as validation that all variable values have been
# restored from the checkpoint. See `tf.train.Checkpoint.restore` for other
# methods in the Status object.
#load_status.assert_consumed()

# %% [markdown]
# #학습 결과 시각화

# %%
import matplotlib.pyplot as plt

def show_graph(history_dict):
    accuracy = history_dict['acc']
    val_accuracy = history_dict['val_acc']
    loss = history_dict['loss']
    val_loss = history_dict['val_loss']

    epochs = range(1, len(loss) + 1)
    
    plt.figure(figsize=(16, 1))
    
    plt.subplot(121)
    plt.subplots_adjust(top=2)
    plt.plot(epochs, accuracy, 'ro', label='Training accuracy')
    plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')
    plt.title('Trainging and validation accuracy and loss')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy and Loss')

    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
              fancybox=True, shadow=True, ncol=5)
#     plt.legend(bbox_to_anchor=(1, -0.1))

    plt.subplot(122)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          fancybox=True, shadow=True, ncol=5)
#     plt.legend(bbox_to_anchor=(1, 0))

    plt.show()
show_graph(history.history)

# %%
def smooth_curve(points, factor=.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points
smooth_data = {}
for key, val in history.history.items():
    smooth_data[key] = smooth_curve(val)
show_graph(smooth_data)

# %% [markdown]
# #모델 평가

# %%
# !ls -l /content/gdrive/MyDrive/KAIST/SEP592/checkpoints | grep resnet50 | grep brca
# Out:
# -rw------- 1 root root 6144 Jun  7 23:29 210608_0741_resnet50_brca_12_300_300_aug.h5
# -rw------- 1 root root 6144 Jun  7 12:31 resnet50_brca_32_100_100_aug.h5
# -rw------- 1 root root 6144 Jun  7 17:16 resnet50_brca_32_100_100_aug_test.h5
# -rw------- 1 root root 6144 Jun  6 12:36 resnet50_brca_32_100_10_2.h5
# -rw------- 1 root root 6144 Jun  7 04:24 resnet50_brca_32_100_10_aug.h5
# -rw------- 1 root root 6144 Jun  6 04:07 resnet50_brca_32_100_10.h5
# -rw------- 1 root root 6144 Jun  5 06:01 resnet50_brca_32_100.h5

# %%
load_status = model.load_weights('%s/%s' % (WEIGHT_DIR_PATH, '210608_0741_resnet50_brca_12_300_300_aug.h5'))

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy', 
    metrics=['acc'],
)

# %%
testGenerator = ImageDataGenerator(
    rescale=1./255
)

testGen = testGenerator.flow_from_directory(
    os.path.join(rootPath, 'test_set'),
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    shuffle = False,  
)
# Out:
# Found 10080 images belonging to 2 classes.

# %%
#model.evaluate_generator(testGen)
testevaluation = model.evaluate_generator(testGen, verbose=1, steps=testGen.samples//32, workers = 300)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1973: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# 315/315 [==============================] - 29s 89ms/step - loss: 1.0890 - acc: 0.5284

# %%
testevaluation
# Out:
# [1.0889679193496704, 0.5283730030059814]

# %%
#Predicting the classes of images
testprediction = model.predict_generator(testGen, verbose=1, steps=testGen.samples//32)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2001: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# 315/315 [==============================] - 39s 123ms/step

# %%
print(testGen.class_indices)
print(testprediction)
# Out:
# {'Normal': 0, 'TIL': 1}
# [[0.8522474  0.14775263]
#  [0.8522474  0.14775263]
#  [0.90057737 0.0994226 ]
#  ...
#  [0.8497625  0.15023755]
#  [0.85247207 0.147528  ]
#  [0.8221902  0.17780975]]

# %%
testGen.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
testprediction[:,0]
# Out:
# array([0.8522474 , 0.8522474 , 0.90057737, ..., 0.8497625 , 0.85247207,
#        0.8221902 ], dtype=float32)

# %%
testprediction[:,1]
# Out:
# array([0.14775263, 0.14775263, 0.0994226 , ..., 0.15023755, 0.147528  ,
#        0.17780975], dtype=float32)

# %%
from sklearn.metrics import roc_curve, auc
from matplotlib import pyplot as plt

nn_fpr, nn_tpr, nn_th = roc_curve(testGen.classes, testprediction[:,0])
auc_pred = auc(nn_fpr, nn_tpr)

plt.figure()
plt.plot(nn_fpr, nn_tpr, label='ROC curve of label "normal"(area = %0.2f)' % auc_pred)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from matplotlib import pyplot as plt

nn_fpr, nn_tpr, nn_th = roc_curve(testGen.classes, testprediction[:,1])
auc_pred = auc(nn_fpr, nn_tpr)

plt.figure()
plt.plot(nn_fpr, nn_tpr, label='ROC curve of label "lym"(area = %0.2f)' % auc_pred)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
len(testGen.labels)
#for i in range(100):

# answer가 0인데 predict가 1이면 failCntArr[0]++
failCntArr = [0, 0]
allCntArr = [0, 0]
for i in range(len(testprediction)):
  prdIdx = 1 if testprediction[i][0] < testprediction[i][1] else 0
  ansIdx = testGen.labels[i]
  allCntArr[ansIdx] += 1

  if prdIdx == ansIdx : continue
  #print('[FAIL] predict[%d], answer[%d]' % (prdIdx, ansIdx))
  failCntArr[ansIdx] += 1

print('Pass cnt : lym[%d/%d], normal[%d/%d]' % (failCntArr[0], allCntArr[0], failCntArr[1], allCntArr[1]))
# Out:
# Pass cnt : lym[30/5280], normal[4724/4800]
