# %% [markdown]
# <a href="https://colab.research.google.com/github/BrotherKim/Colab/blob/main/SEP592/BK_resnet50_BRCA_classification_ipynb_32_100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Dataset download
# datasets<br>
#     &emsp;&emsp;└── test_set<br>
#     &emsp;&emsp;│   &emsp;&emsp;├── cats<br>
#     &emsp;&emsp;│   &emsp;&emsp;│   &emsp;&emsp;└── datas...<br>
#     &emsp;&emsp;│   &emsp;&emsp;└── dogs<br>
#     &emsp;&emsp;│       &emsp;&emsp;&emsp;&emsp;&emsp;└── datas...<br>
#     &emsp;&emsp;└── training_set<br>
#         &emsp;&emsp;&emsp;&emsp;├── cats<br>
#         &emsp;&emsp;&emsp;&emsp;│   &emsp;&emsp;└── datas...<br>
#         &emsp;&emsp;&emsp;&emsp;└── dogs<br>
#             &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;└── datas...<br>

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
# !mkdir -p ~/.kaggle
# !cp /content/gdrive/MyDrive/KAIST/kaggle.json ~/.kaggle

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tongpython/cat-and-dog
# !mkdir datasets
# !unzip /content/cat-and-dog.zip -d /content/datasets
# !mv /content/datasets/test_set /content/datasets/test_set_legacy
# !mv /content/datasets/test_set_legacy/test_set /content/datasets/test_set
# !mv /content/datasets/training_set /content/datasets/training_set_legacy
# !mv /content/datasets/training_set_legacy/training_set /content/datasets/training_set
# !rm -rf /content/datasets/*_set_legacy
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/datasets/training_set/training_set/cats/cat.3704.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3705.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3706.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3707.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3708.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3709.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.371.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3710.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3711.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3712.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3713.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3714.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3715.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3716.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3717.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3718.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3719.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.372.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3720.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3721.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3722.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3723.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3724.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3725.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3726.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3727.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3728.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3729.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.373.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3730.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3731.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3732.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3733.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3734.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3735.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3736.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3737.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3738.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3739.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.374.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3740.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3741.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3742.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3743.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3744.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3745.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3746.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3747.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3748.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3749.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.375.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3750.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3751.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3752.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3753.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3754.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3755.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3756.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3757.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3758.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3759.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.376.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3760.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3761.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3762.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3763.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3764.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3765.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3766.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3767.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3768.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3769.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.377.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3770.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3771.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3772.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3773.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3774.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3775.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3776.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3777.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3778.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3779.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.378.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3780.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3781.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3782.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3783.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3784.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3785.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3786.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3787.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3788.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3789.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.379.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3790.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3791.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3792.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3793.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3794.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3795.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3796.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3797.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3798.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3799.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.38.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.380.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3800.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3801.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3802.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3803.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3804.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3805.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3806.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3807.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3808.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3809.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.381.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3810.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3811.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3812.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3813.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3814.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3815.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3816.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3817.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3818.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3819.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.382.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3820.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3821.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3822.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3823.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3824.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3825.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3826.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3827.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3828.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3829.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.383.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3830.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3831.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3832.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3833.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3834.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3835.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3836.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3837.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3838.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3839.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.384.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3840.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3841.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3842.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3843.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3844.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3845.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3846.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3847.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3848.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3849.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.385.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3850.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3851.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3852.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3853.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3854.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3855.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3856.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3857.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3858.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3859.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.386.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3860.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3861.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3862.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3863.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3864.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3865.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3866.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3867.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3868.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3869.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.387.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3870.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3871.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3872.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3873.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3874.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3875.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3876.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3877.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3878.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3879.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.388.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3880.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3881.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3882.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3883.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3884.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3885.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3886.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3887.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3888.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3889.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.389.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3890.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3891.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3892.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3893.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3894.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3895.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3896.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3897.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3898.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3899.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.39.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.390.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3900.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3901.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3902.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3903.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3904.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3905.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3906.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3907.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3908.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3909.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.391.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3910.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3911.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3912.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3913.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3914.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3915.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3916.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3917.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3918.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3919.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.392.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3920.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3921.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3922.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3923.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3924.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3925.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3926.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3927.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3928.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3929.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.393.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3930.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3931.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3932.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3933.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3934.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3935.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3936.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3937.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3938.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3939.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.394.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3940.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3941.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3942.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3943.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3944.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3945.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3946.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3947.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3948.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3949.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.395.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3950.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3951.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3952.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3953.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3954.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3955.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3956.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3957.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3958.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3959.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.396.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3960.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3961.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3962.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3963.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3964.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3965.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3966.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3967.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3968.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3969.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.397.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3970.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3971.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3972.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3973.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3974.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3975.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3976.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3977.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3978.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3979.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.398.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3980.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3981.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3982.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3983.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3984.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3985.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3986.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3987.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3988.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3989.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.399.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3990.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3991.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3992.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3993.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3994.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3995.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3996.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3997.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3998.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.3999.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.4.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.40.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.400.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.4000.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.401.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.402.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.403.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.404.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.405.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.406.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.407.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.408.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.409.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.41.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.410.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.411.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.412.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.413.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.414.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.415.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.416.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.417.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.418.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.419.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.42.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.420.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.421.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.422.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.423.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.424.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.425.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.426.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.427.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.428.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.429.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.43.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.430.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.431.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.432.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.433.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.434.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.435.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.436.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.437.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.438.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.439.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.44.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.440.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.441.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.442.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.443.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.444.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.445.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.446.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.447.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.448.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.449.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.45.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.450.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.451.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.452.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.453.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.454.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.455.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.456.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.457.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.458.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.459.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.46.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.460.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.461.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.462.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.463.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.464.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.465.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.466.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.467.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.468.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.469.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.47.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.470.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.471.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.472.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.473.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.474.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.475.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.476.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.477.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.478.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.479.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.48.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.480.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.481.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.482.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.483.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.484.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.485.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.486.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.487.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.488.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.489.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.49.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.490.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.491.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.492.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.493.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.494.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.495.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.496.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.497.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.498.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.499.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.5.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.50.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.500.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.501.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.502.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.503.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.504.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.505.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.506.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.507.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.508.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.509.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.51.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.510.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.511.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.512.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.513.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.514.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.515.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.516.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.517.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.518.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.519.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.52.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.520.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.521.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.522.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.523.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.524.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.525.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.526.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.527.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.528.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.529.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.53.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.530.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.531.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.532.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.533.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.534.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.535.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.536.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.537.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.538.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.539.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.54.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.540.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.541.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.542.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.543.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.544.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.545.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.546.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.547.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.548.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.549.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.55.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.550.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.551.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.552.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.553.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.554.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.555.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.556.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.557.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.558.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.559.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.56.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.560.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.561.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.562.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.563.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.564.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.565.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.566.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.567.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.568.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.569.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.57.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.570.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.571.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.572.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.573.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.574.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.575.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.576.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.577.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.578.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.579.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.58.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.580.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.581.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.582.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.583.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.584.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.585.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.586.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.587.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.588.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.589.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.59.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.590.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.591.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.592.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.593.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.594.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.595.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.596.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.597.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.598.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.599.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.6.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.60.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.600.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.601.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.602.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.603.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.604.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.605.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.606.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.607.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.608.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.609.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.61.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.610.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.611.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.612.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.613.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.614.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.615.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.616.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.617.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.618.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.619.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.62.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.620.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.621.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.622.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.623.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.624.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.625.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.626.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.627.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.628.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.629.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.63.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.630.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.631.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.632.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.633.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.634.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.635.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.636.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.637.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.638.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.639.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.64.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.640.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.641.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.642.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.643.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.644.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.645.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.646.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.647.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.648.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.649.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.65.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.650.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.651.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.652.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.653.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.654.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.655.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.656.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.657.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.658.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.659.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.66.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.660.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.661.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.662.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.663.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.664.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.665.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.666.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.667.jpg
#   inflating: /content/datasets/training_set/training_set/cats/cat.668.jpg
# ...
#   inflating: /content/datasets/training_set/training_set/dogs/dog.811.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.812.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.813.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.814.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.815.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.816.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.817.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.818.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.819.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.82.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.820.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.821.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.822.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.823.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.824.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.825.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.826.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.827.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.828.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.829.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.83.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.830.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.831.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.832.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.833.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.834.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.835.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.836.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.837.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.838.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.839.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.84(1).jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.84.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.840.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.841.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.842.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.843.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.844.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.845.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.846.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.847.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.848.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.849.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.85.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.850.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.851.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.852.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.853.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.854.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.855.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.856.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.857.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.858.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.859.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.86.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.860.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.861.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.862.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.863.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.864.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.865.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.866.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.867.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.868.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.869.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.87.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.870.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.871.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.872.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.873.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.874.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.875.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.876.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.877.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.878.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.879.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.88.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.880.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.881.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.882.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.883.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.884.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.885.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.886.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.887.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.888.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.889.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.89.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.890.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.891.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.892.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.893.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.894.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.895.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.896.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.897.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.898.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.899.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.9.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.90(1).jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.90.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.900.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.901.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.902.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.903.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.904.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.905.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.906.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.907.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.908.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.909.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.91.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.910.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.911.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.912.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.913.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.914.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.915.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.916.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.917.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.918.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.919.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.92.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.920.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.921.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.922.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.923.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.924.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.925.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.926.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.927.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.928.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.929.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.93.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.930.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.931.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.932.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.933.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.934.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.935.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.936.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.937.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.938.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.939.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.94.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.940.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.941.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.942.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.943.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.944.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.945.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.946.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.947.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.948.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.949.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.95.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.950.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.951.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.952.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.953.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.954.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.955.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.956.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.957.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.958.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.959.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.96.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.960.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.961.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.962.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.963.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.964.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.965.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.966.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.967.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.968.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.969.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.97.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.970.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.971.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.972.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.973.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.974.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.975.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.976.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.977.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.978.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.979.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.98.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.980.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.981.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.982.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.983.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.984.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.985.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.986.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.987.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.988.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.989.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.99.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.990.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.991.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.992.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.993.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.994.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.995.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.996.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.997.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.998.jpg
#   inflating: /content/datasets/training_set/training_set/dogs/dog.999.jpg

# %% [markdown]
# # Data Load

# %%
# !ls -l /content/gdrive/MyDrive/KAIST/dataset/test_set
# Out:
# total 8
# drwx------ 2 root root 4096 May 30 05:32 lym
# drwx------ 2 root root 4096 May 30 05:32 normal

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 위노그라드 알고리즘 설정
os.environ['TF_ENABLE_WINOGRAD_NONFUSED'] = '1'

#rootPath = '/content/datasets'
rootPath = '/content/gdrive/MyDrive/KAIST/dataset'

imageGenerator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=[.2, .2],
    horizontal_flip=True,
    validation_split=.1
)

trainGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'train_set'),
    target_size=(224, 224),
    subset='training'
)

validationGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'train_set'),
    target_size=(224, 224),
    subset='validation'
)
# Out:
# Found 21181 images belonging to 2 classes.
# Found 2352 images belonging to 2 classes.

# %% [markdown]
# # 모델 구성 및 finetuning

# %%
INPUT_SHAPE = (224, 224, 3)
NUM_CLASSES = 2

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

baseModel = ResNet50(include_top=False, weights='imagenet', input_shape=INPUT_SHAPE, classes=NUM_CLASSES)
#baseMode =ResNet50(include_top=True, weights=None, input_shape=INPUT_SHAPE, classes=NUM_CLASSES)

baseModel.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
for i, l in enumerate(baseModel.layers):
  print(i, l.name)
# Out:
# 0 input_1
# 1 conv1_pad
# 2 conv1_conv
# 3 conv1_bn
# 4 conv1_relu
# 5 pool1_pad
# 6 pool1_pool
# 7 conv2_block1_1_conv
# 8 conv2_block1_1_bn
# 9 conv2_block1_1_relu
# 10 conv2_block1_2_conv
# 11 conv2_block1_2_bn
# 12 conv2_block1_2_relu
# 13 conv2_block1_0_conv
# 14 conv2_block1_3_conv
# 15 conv2_block1_0_bn
# 16 conv2_block1_3_bn
# 17 conv2_block1_add
# 18 conv2_block1_out
# 19 conv2_block2_1_conv
# 20 conv2_block2_1_bn
# 21 conv2_block2_1_relu
# 22 conv2_block2_2_conv
# 23 conv2_block2_2_bn
# 24 conv2_block2_2_relu
# 25 conv2_block2_3_conv
# 26 conv2_block2_3_bn
# 27 conv2_block2_add
# 28 conv2_block2_out
# 29 conv2_block3_1_conv
# 30 conv2_block3_1_bn
# 31 conv2_block3_1_relu
# 32 conv2_block3_2_conv
# 33 conv2_block3_2_bn
# 34 conv2_block3_2_relu
# 35 conv2_block3_3_conv
# 36 conv2_block3_3_bn
# 37 conv2_block3_add
# 38 conv2_block3_out
# 39 conv3_block1_1_conv
# 40 conv3_block1_1_bn
# 41 conv3_block1_1_relu
# 42 conv3_block1_2_conv
# 43 conv3_block1_2_bn
# 44 conv3_block1_2_relu
# 45 conv3_block1_0_conv
# 46 conv3_block1_3_conv
# 47 conv3_block1_0_bn
# 48 conv3_block1_3_bn
# 49 conv3_block1_add
# 50 conv3_block1_out
# 51 conv3_block2_1_conv
# 52 conv3_block2_1_bn
# 53 conv3_block2_1_relu
# 54 conv3_block2_2_conv
# 55 conv3_block2_2_bn
# 56 conv3_block2_2_relu
# 57 conv3_block2_3_conv
# 58 conv3_block2_3_bn
# 59 conv3_block2_add
# 60 conv3_block2_out
# 61 conv3_block3_1_conv
# 62 conv3_block3_1_bn
# 63 conv3_block3_1_relu
# 64 conv3_block3_2_conv
# 65 conv3_block3_2_bn
# 66 conv3_block3_2_relu
# 67 conv3_block3_3_conv
# 68 conv3_block3_3_bn
# 69 conv3_block3_add
# 70 conv3_block3_out
# 71 conv3_block4_1_conv
# 72 conv3_block4_1_bn
# 73 conv3_block4_1_relu
# 74 conv3_block4_2_conv
# 75 conv3_block4_2_bn
# 76 conv3_block4_2_relu
# 77 conv3_block4_3_conv
# 78 conv3_block4_3_bn
# 79 conv3_block4_add
# 80 conv3_block4_out
# 81 conv4_block1_1_conv
# 82 conv4_block1_1_bn
# 83 conv4_block1_1_relu
# 84 conv4_block1_2_conv
# 85 conv4_block1_2_bn
# 86 conv4_block1_2_relu
# 87 conv4_block1_0_conv
# 88 conv4_block1_3_conv
# 89 conv4_block1_0_bn
# 90 conv4_block1_3_bn
# 91 conv4_block1_add
# 92 conv4_block1_out
# 93 conv4_block2_1_conv
# 94 conv4_block2_1_bn
# 95 conv4_block2_1_relu
# 96 conv4_block2_2_conv
# 97 conv4_block2_2_bn
# 98 conv4_block2_2_relu
# 99 conv4_block2_3_conv
# 100 conv4_block2_3_bn
# 101 conv4_block2_add
# 102 conv4_block2_out
# 103 conv4_block3_1_conv
# 104 conv4_block3_1_bn
# 105 conv4_block3_1_relu
# 106 conv4_block3_2_conv
# 107 conv4_block3_2_bn
# 108 conv4_block3_2_relu
# 109 conv4_block3_3_conv
# 110 conv4_block3_3_bn
# 111 conv4_block3_add
# 112 conv4_block3_out
# 113 conv4_block4_1_conv
# 114 conv4_block4_1_bn
# 115 conv4_block4_1_relu
# 116 conv4_block4_2_conv
# 117 conv4_block4_2_bn
# 118 conv4_block4_2_relu
# 119 conv4_block4_3_conv
# 120 conv4_block4_3_bn
# 121 conv4_block4_add
# 122 conv4_block4_out
# 123 conv4_block5_1_conv
# 124 conv4_block5_1_bn
# 125 conv4_block5_1_relu
# 126 conv4_block5_2_conv
# 127 conv4_block5_2_bn
# 128 conv4_block5_2_relu
# 129 conv4_block5_3_conv
# 130 conv4_block5_3_bn
# 131 conv4_block5_add
# 132 conv4_block5_out
# 133 conv4_block6_1_conv
# 134 conv4_block6_1_bn
# 135 conv4_block6_1_relu
# 136 conv4_block6_2_conv
# 137 conv4_block6_2_bn
# 138 conv4_block6_2_relu
# 139 conv4_block6_3_conv
# 140 conv4_block6_3_bn
# 141 conv4_block6_add
# 142 conv4_block6_out
# 143 conv5_block1_1_conv
# 144 conv5_block1_1_bn
# 145 conv5_block1_1_relu
# 146 conv5_block1_2_conv
# 147 conv5_block1_2_bn
# 148 conv5_block1_2_relu
# 149 conv5_block1_0_conv
# 150 conv5_block1_3_conv
# 151 conv5_block1_0_bn
# 152 conv5_block1_3_bn
# 153 conv5_block1_add
# 154 conv5_block1_out
# 155 conv5_block2_1_conv
# 156 conv5_block2_1_bn
# 157 conv5_block2_1_relu
# 158 conv5_block2_2_conv
# 159 conv5_block2_2_bn
# 160 conv5_block2_2_relu
# 161 conv5_block2_3_conv
# 162 conv5_block2_3_bn
# 163 conv5_block2_add
# 164 conv5_block2_out
# 165 conv5_block3_1_conv
# 166 conv5_block3_1_bn
# 167 conv5_block3_1_relu
# 168 conv5_block3_2_conv
# 169 conv5_block3_2_bn
# 170 conv5_block3_2_relu
# 171 conv5_block3_3_conv
# 172 conv5_block3_3_bn
# 173 conv5_block3_add
# 174 conv5_block3_out

# %%
from keras.models import Model
from tensorflow.keras.layers import Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization

x = baseModel.output
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', input_dim=INPUT_SHAPE)(x)
x = BatchNormalization()(x)
x = Dense(256, activation ='relu')(x)
x = BatchNormalization()(x)
x = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(
    inputs=baseModel.input
    , outputs=x
    )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Total params: 33,160,322
# Trainable params: 33,105,666
# Non-trainable params: 54,656
# __________________________________________________________________________________________________

# %%
NUM_FREEZE = 100

for l in baseModel.layers:
  l.trainable = False

for l in baseModel.layers[NUM_FREEZE:]:
  l.trainable = True

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy', 
    metrics=['acc'],
)

# %%
#epochs = 32
#history = model.fit_generator(
#    trainGen, 
#    epochs=epochs,
#    steps_per_epoch=trainGen.samples / epochs, 
#    validation_data=validationGen,
#    validation_steps=trainGen.samples / epochs,
#)
epochs = 32
steps = 100
history = model.fit_generator(
    trainGen, 
    epochs=epochs,
    steps_per_epoch=steps, 
    validation_data=validationGen,
    validation_steps=steps,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/32
# 100/100 [==============================] - 1093s 11s/step - loss: 0.8307 - acc: 0.7546 - val_loss: 0.5575 - val_acc: 0.7877
# Epoch 2/32
# 100/100 [==============================] - 658s 7s/step - loss: 0.5284 - acc: 0.7857 - val_loss: 0.5325 - val_acc: 0.7798
# Epoch 3/32
# 100/100 [==============================] - 647s 7s/step - loss: 0.5164 - acc: 0.8017 - val_loss: 0.5072 - val_acc: 0.7955
# Epoch 4/32
# 100/100 [==============================] - 651s 7s/step - loss: 0.5316 - acc: 0.7783 - val_loss: 0.5185 - val_acc: 0.7867
# Epoch 5/32
# 100/100 [==============================] - 646s 7s/step - loss: 0.5153 - acc: 0.7902 - val_loss: 0.5224 - val_acc: 0.7871
# Epoch 6/32
# 100/100 [==============================] - 648s 7s/step - loss: 0.5141 - acc: 0.7928 - val_loss: 0.5178 - val_acc: 0.7872
# Epoch 7/32
# 100/100 [==============================] - 443s 4s/step - loss: 0.5294 - acc: 0.7782 - val_loss: 0.5216 - val_acc: 0.7842
# Epoch 8/32
# 100/100 [==============================] - 111s 1s/step - loss: 0.5153 - acc: 0.7900 - val_loss: 0.5154 - val_acc: 0.7893
# Epoch 9/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.5145 - acc: 0.7900 - val_loss: 0.5110 - val_acc: 0.7923
# Epoch 10/32
# 100/100 [==============================] - 113s 1s/step - loss: 0.5339 - acc: 0.7760 - val_loss: 0.5263 - val_acc: 0.7805
# Epoch 11/32
# 100/100 [==============================] - 111s 1s/step - loss: 0.5239 - acc: 0.7825 - val_loss: 0.5148 - val_acc: 0.7898
# Epoch 12/32
# 100/100 [==============================] - 110s 1s/step - loss: 0.5179 - acc: 0.7877 - val_loss: 0.5174 - val_acc: 0.7874
# Epoch 13/32
# 100/100 [==============================] - 110s 1s/step - loss: 0.5344 - acc: 0.7748 - val_loss: 0.5178 - val_acc: 0.7874
# Epoch 14/32
# 100/100 [==============================] - 110s 1s/step - loss: 0.5093 - acc: 0.7942 - val_loss: 0.5203 - val_acc: 0.7869
# Epoch 15/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.5071 - acc: 0.7960 - val_loss: 0.5124 - val_acc: 0.7918
# Epoch 16/32
# 100/100 [==============================] - 114s 1s/step - loss: 0.5291 - acc: 0.7790 - val_loss: 0.5246 - val_acc: 0.7820
# Epoch 17/32
# 100/100 [==============================] - 113s 1s/step - loss: 0.5187 - acc: 0.7871 - val_loss: 0.5154 - val_acc: 0.7895
# Epoch 18/32
# 100/100 [==============================] - 114s 1s/step - loss: 0.4915 - acc: 0.8069 - val_loss: 0.5171 - val_acc: 0.7899
# Epoch 19/32
# 100/100 [==============================] - 110s 1s/step - loss: 0.5236 - acc: 0.7836 - val_loss: 0.5199 - val_acc: 0.7855
# Epoch 20/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.5348 - acc: 0.7743 - val_loss: 0.5173 - val_acc: 0.7879
# Epoch 21/32
# 100/100 [==============================] - 114s 1s/step - loss: 0.5051 - acc: 0.7970 - val_loss: 0.5275 - val_acc: 0.7798
# Epoch 22/32
# 100/100 [==============================] - 113s 1s/step - loss: 0.4980 - acc: 0.8022 - val_loss: 0.5127 - val_acc: 0.7926
# Epoch 23/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.5478 - acc: 0.7683 - val_loss: 0.5158 - val_acc: 0.7886
# Epoch 24/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.5216 - acc: 0.7844 - val_loss: 0.5153 - val_acc: 0.7893
# Epoch 25/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.5252 - acc: 0.7817 - val_loss: 0.5184 - val_acc: 0.7869
# Epoch 26/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.5335 - acc: 0.7755 - val_loss: 0.5240 - val_acc: 0.7827
# Epoch 27/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.5273 - acc: 0.7803 - val_loss: 0.5165 - val_acc: 0.7905
# Epoch 28/32
# 100/100 [==============================] - 110s 1s/step - loss: 0.5407 - acc: 0.7696 - val_loss: 0.5180 - val_acc: 0.7888
# Epoch 29/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.5141 - acc: 0.7901 - val_loss: 0.5161 - val_acc: 0.7899
# Epoch 30/32
# 100/100 [==============================] - 112s 1s/step - loss: 0.4952 - acc: 0.8064 - val_loss: 0.5410 - val_acc: 0.7836
# Epoch 31/32
# 100/100 [==============================] - 110s 1s/step - loss: 0.5322 - acc: 0.7820 - val_loss: 0.5198 - val_acc: 0.7857
# Epoch 32/32
# 100/100 [==============================] - 110s 1s/step - loss: 0.5172 - acc: 0.7883 - val_loss: 0.5200 - val_acc: 0.7855
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-8024e1bc7ec8> in <module>()
#      17 )
#      18
# ---> 19 model.save('/content/gdrive/MyDrive/KAIST/BRCA_resnet50_32_100_model.h5')
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2085     # pylint: enable=line-too-long
#    2086     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 2087                     signatures, options, save_traces)
#    2088
#    2089   def save_weights(self,
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     145           'or using `save_weights`.')
#     146     hdf5_format.save_model_to_hdf5(
# --> 147         model, filepath, overwrite, include_optimizer)
#     148   else:
#     149     with generic_utils.SharedObjectSavingScope():
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     108
#     109   try:
# --> 110     model_metadata = saving_utils.model_metadata(model, include_optimizer)
#     111     for k, v in model_metadata.items():
#     112       if isinstance(v, (dict, list, tuple)):
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     147   model_config = {'class_name': model.__class__.__name__}
#     148   try:
# --> 149     model_config['config'] = model.get_config()
#     150   except NotImplementedError as e:
#     151     if require_config:
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in get_config(self)
#     642
#     643   def get_config(self):
# --> 644     return copy.deepcopy(get_network_config(self))
#     645
#     646   @classmethod
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in get_network_config(network, serialize_layer_fn)
#    1361     if node_key not in network._network_nodes:
#    1362       continue
# -> 1363     new_node_index = node_conversion_map[node_key]
#    1364     model_inputs.append(
#    1365         tf_utils.ListWrapper([layer.name, new_node_index, tensor_index]))
#
# KeyError: 'input_1_ib-0'

# %%
#model.save('/content/gdrive/MyDrive/KAIST/BRCA_resnet50_32_100_model.h5')
from keras.models import load_model
model.save('BRCA_resnet50_32_100_model.h5')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-48c097b37973> in <module>()
#       1 #model.save('/content/gdrive/MyDrive/KAIST/BRCA_resnet50_32_100_model.h5')
#       2 from keras.models import load_model
# ----> 3 model.save('BRCA_resnet50_32_100_model.h5')
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2085     # pylint: enable=line-too-long
#    2086     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 2087                     signatures, options, save_traces)
#    2088
#    2089   def save_weights(self,
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     145           'or using `save_weights`.')
#     146     hdf5_format.save_model_to_hdf5(
# --> 147         model, filepath, overwrite, include_optimizer)
#     148   else:
#     149     with generic_utils.SharedObjectSavingScope():
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     108
#     109   try:
# --> 110     model_metadata = saving_utils.model_metadata(model, include_optimizer)
#     111     for k, v in model_metadata.items():
#     112       if isinstance(v, (dict, list, tuple)):
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     147   model_config = {'class_name': model.__class__.__name__}
#     148   try:
# --> 149     model_config['config'] = model.get_config()
#     150   except NotImplementedError as e:
#     151     if require_config:
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in get_config(self)
#     642
#     643   def get_config(self):
# --> 644     return copy.deepcopy(get_network_config(self))
#     645
#     646   @classmethod
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in get_network_config(network, serialize_layer_fn)
#    1361     if node_key not in network._network_nodes:
#    1362       continue
# -> 1363     new_node_index = node_conversion_map[node_key]
#    1364     model_inputs.append(
#    1365         tf_utils.ListWrapper([layer.name, new_node_index, tensor_index]))
#
# KeyError: 'input_1_ib-0'

# %% [markdown]
# #학습 결과 시각화

# %%
import matplotlib.pyplot as plt

def show_graph(history_dict):
    accuracy = history_dict['acc']
    val_accuracy = history_dict['val_acc']
    loss = history_dict['loss']
    val_loss = history_dict['val_loss']

    epochs = range(1, len(loss) + 1)
    
    plt.figure(figsize=(16, 1))
    
    plt.subplot(121)
    plt.subplots_adjust(top=2)
    plt.plot(epochs, accuracy, 'ro', label='Training accuracy')
    plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')
    plt.title('Trainging and validation accuracy and loss')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy and Loss')

    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
              fancybox=True, shadow=True, ncol=5)
#     plt.legend(bbox_to_anchor=(1, -0.1))

    plt.subplot(122)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          fancybox=True, dshadow=True, ncol=5)
#     plt.legend(bbox_to_anchor=(1, 0))

    plt.show()
show_graph(history.history)

# %%
def smooth_curve(points, factor=.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points
smooth_data = {}
for key, val in history.history.items():
    smooth_data[key] = smooth_curve(val)
show_graph(smooth_data)

# %% [markdown]
# #모델 중간평가

# %%
testGenerator = ImageDataGenerator(
    rescale=1./255
)

testGen = imageGenerator.flow_from_directory(
    os.path.join(rootPath, 'test_set'),
    target_size=(224, 224),
)

#model.evaluate_generator(testGen)
model.evaluate(testGen)
# Out:
# Found 9816 images belonging to 2 classes.
#     138/Unknown - 1552s 11s/step - loss: 0.5186 - acc: 0.8191
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-05451f1f4c61> in <module>()
#       9
#      10 #model.evaluate_generator(testGen)
# ---> 11 model.evaluate(testGen)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1462             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1463               callbacks.on_test_batch_begin(step)
# -> 1464               tmp_logs = self.test_function(iterator)
#    1465               if data_handler.should_sync:
#    1466                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     922       # In this case we have not created variables on the first call. So we can
#     923       # run the first trace but we should fail if variables are created.
# --> 924       results = self._stateful_fn(*args, **kwds)
#     925       if self._created_variables:
#     926         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# #모델 추가 학습

# %%
#epochs = 32
#history = model.fit_generator(
#    trainGen, 
#    epochs=epochs,
#    steps_per_epoch=trainGen.samples / epochs, 
#    validation_data=validationGen,
#    validation_steps=trainGen.samples / epochs,
#)

#from keras.callbacks import EarlyStopping
#early_stopping = EarlyStopping(patience=1, min_delta=-0.02)

epochs = 10
steps = 20
history = model.fit_generator(
    trainGen, 
    epochs=epochs,
    steps_per_epoch=steps, 
    validation_data=validationGen,
    validation_steps=steps,
#    callbacks=[early_stopping],
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 20/20 [==============================] - 280s 15s/step - loss: 0.5165 - acc: 0.7906 - val_loss: 0.5329 - val_acc: 0.7899
# Epoch 2/10
# 20/20 [==============================] - 285s 15s/step - loss: 0.5487 - acc: 0.7734 - val_loss: 0.5164 - val_acc: 0.7937
# Epoch 3/10
# 20/20 [==============================] - 285s 15s/step - loss: 0.5210 - acc: 0.8078 - val_loss: 0.5534 - val_acc: 0.7750
# Epoch 4/10
# 20/20 [==============================] - 288s 15s/step - loss: 0.4674 - acc: 0.8250 - val_loss: 0.5047 - val_acc: 0.7997
# Epoch 5/10
# 20/20 [==============================] - 284s 15s/step - loss: 0.5483 - acc: 0.7672 - val_loss: 0.4991 - val_acc: 0.8031
# Epoch 6/10
# 20/20 [==============================] - 286s 15s/step - loss: 0.5489 - acc: 0.7672 - val_loss: 0.5131 - val_acc: 0.8000
# Epoch 7/10
# 20/20 [==============================] - 284s 15s/step - loss: 0.5403 - acc: 0.7750 - val_loss: 0.7939 - val_acc: 0.7500
# Epoch 8/10
# 20/20 [==============================] - 285s 15s/step - loss: 0.5301 - acc: 0.7953 - val_loss: 0.5503 - val_acc: 0.7638
# Epoch 9/10
# 20/20 [==============================] - 287s 15s/step - loss: 0.5391 - acc: 0.7719 - val_loss: 0.5070 - val_acc: 0.7969
# Epoch 10/10
# 20/20 [==============================] - 285s 15s/step - loss: 0.5191 - acc: 0.7875 - val_loss: 0.4950 - val_acc: 0.8047

# %%
#epochs = 32
#history = model.fit_generator(
#    trainGen, 
#    epochs=epochs,
#    steps_per_epoch=trainGen.samples / epochs, 
#    validation_data=validationGen,
#    validation_steps=trainGen.samples / epochs,
#)

#from keras.callbacks import EarlyStopping
#early_stopping = EarlyStopping(patience=1, min_delta=-0.02)

epochs = 20
steps = 20
history = model.fit_generator(
    trainGen, 
    epochs=epochs,
    steps_per_epoch=steps, 
    validation_data=validationGen,
    validation_steps=steps,
#    callbacks=[early_stopping],
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 20/20 [==============================] - 281s 15s/step - loss: 0.5227 - acc: 0.7844 - val_loss: 0.5404 - val_acc: 0.7720
# Epoch 2/20
# 20/20 [==============================] - 291s 15s/step - loss: 0.4906 - acc: 0.8109 - val_loss: 0.5210 - val_acc: 0.7859
# Epoch 3/20
# 20/20 [==============================] - 297s 15s/step - loss: 0.5085 - acc: 0.7953 - val_loss: 0.5151 - val_acc: 0.7937
# Epoch 4/20
# 20/20 [==============================] - 305s 16s/step - loss: 0.4994 - acc: 0.8031 - val_loss: 0.5139 - val_acc: 0.7906
# Epoch 5/20
# 20/20 [==============================] - 309s 16s/step - loss: 0.5198 - acc: 0.7891 - val_loss: 0.5490 - val_acc: 0.7671
# Epoch 6/20
# 20/20 [==============================] - 303s 16s/step - loss: 0.5298 - acc: 0.7875 - val_loss: 0.5352 - val_acc: 0.7734
# Epoch 7/20
# 20/20 [==============================] - 304s 16s/step - loss: 0.5200 - acc: 0.7875 - val_loss: 0.5478 - val_acc: 0.7703
# Epoch 8/20
# 20/20 [==============================] - 310s 16s/step - loss: 0.5276 - acc: 0.7828 - val_loss: 0.4758 - val_acc: 0.8192
# Epoch 9/20
# 20/20 [==============================] - 236s 12s/step - loss: 0.4851 - acc: 0.8222 - val_loss: 0.5211 - val_acc: 0.7875
# Epoch 10/20
# 20/20 [==============================] - 19s 1s/step - loss: 7.1290 - acc: 0.7594 - val_loss: 0.5726 - val_acc: 0.7906
# Epoch 11/20
# 20/20 [==============================] - 19s 1s/step - loss: 1.9739 - acc: 0.7375 - val_loss: 0.5536 - val_acc: 0.7719
# Epoch 12/20
# 20/20 [==============================] - 19s 986ms/step - loss: 1.5694 - acc: 0.7344 - val_loss: 0.5493 - val_acc: 0.7671
# Epoch 13/20
# 20/20 [==============================] - 19s 1s/step - loss: 0.5260 - acc: 0.7953 - val_loss: 0.5727 - val_acc: 0.8156
# Epoch 14/20
# 20/20 [==============================] - 19s 1s/step - loss: 0.5221 - acc: 0.7969 - val_loss: 0.5227 - val_acc: 0.7844
# Epoch 15/20
# 20/20 [==============================] - 19s 982ms/step - loss: 0.5319 - acc: 0.7797 - val_loss: 0.5452 - val_acc: 0.7671
# Epoch 16/20
# 20/20 [==============================] - 19s 1s/step - loss: 0.5265 - acc: 0.7828 - val_loss: 0.5214 - val_acc: 0.7844
# Epoch 17/20
# 20/20 [==============================] - 19s 1s/step - loss: 0.5224 - acc: 0.7844 - val_loss: 0.5051 - val_acc: 0.7969
# Epoch 18/20
# 20/20 [==============================] - 19s 1s/step - loss: 0.5043 - acc: 0.7984 - val_loss: 0.5154 - val_acc: 0.7891
# Epoch 19/20
# 20/20 [==============================] - 19s 994ms/step - loss: 0.4798 - acc: 0.8156 - val_loss: 0.5212 - val_acc: 0.7850
# Epoch 20/20
# 20/20 [==============================] - 19s 1s/step - loss: 0.5023 - acc: 0.8031 - val_loss: 0.5034 - val_acc: 0.8094

# %% [markdown]
# #추가 학습 결과 시각화

# %%
smooth_data = {}
for key, val in history.history.items():
    smooth_data[key] = smooth_curve(val)
show_graph(smooth_data)
